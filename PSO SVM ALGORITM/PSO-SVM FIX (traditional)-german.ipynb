# %%
import pandas as pd
import numpy as np
import random
import csv
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix  
import matplotlib.pyplot as plt

# %%
url = "D:\\TUGAS AKHIR\\Data TA\\German fraud dataset\\german.csv"
colnames = ['x1', 'x2', 'x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13','x14','x15','x16','x17','x18','x19','x20','x21','x22','x23','x24','y']
data = pd.read_csv(url, header = None, names = colnames)
X = data.drop('y', axis = 1)
X = (X-X.mean())/X.std()
y = data['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)  
data.head()
# Out:
#    x1  x2  x3  x4  x5  x6  x7  x8  x9  x10 ...  x16  x17  x18  x19  x20  x21  \
# 0   1   6   4  12   5   5   3   4   1   67 ...    0    0    1    0    0    1
# 1   2  48   2  60   1   3   2   2   1   22 ...    0    0    1    0    0    1
# 2   4  12   4  21   1   4   3   3   1   49 ...    0    0    1    0    0    1
# 3   1  42   2  79   1   4   3   4   2   45 ...    0    0    0    0    0    0
# 4   1  24   3  49   1   3   3   4   4   53 ...    1    0    1    0    0    0
#
#    x22  x23  x24  y
# 0    0    0    1  1
# 1    0    0    1  2
# 2    0    1    0  1
# 3    0    0    1  1
# 4    0    0    1  2
#
# [5 rows x 25 columns]

# %%
#################### I N P U T ####################
W = 0.5
c1 = 0.2
c2 = 0.5

n_iterations = int(input("Inform the number of iterations: "))
n_particles = int(input("Inform the number of particles: "))
# Out:
# Inform the number of iterations: 10
# Inform the number of particles: 100

# %%
#mencari nilai 0-1 loss dari tiap partikel
#partikle = (gamma,C) untuk rbf
def fitness_function(position):
    svclassifier = SVC(kernel='sigmoid', gamma = position[0], C = position[1] )  
    svclassifier.fit(X_train, y_train)
    y_train_pred = svclassifier.predict(X_train)
    y_test_pred = svclassifier.predict(X_test)   
    return confusion_matrix(y_train,y_train_pred)[0][1] + confusion_matrix(y_train,y_train_pred)[1][0], confusion_matrix(y_test,y_test_pred)[0][1] + confusion_matrix(y_test,y_test_pred)[1][0]

#plotting (x axis = gamma, y axis = C)
def plot(position):
    x = []
    y = []
    for i in range(0,len(particle_position_vector)):
        x.append(particle_position_vector[i][0])
        y.append(particle_position_vector[i][1])
    colors = (0,0,0)
    plt.scatter(x, y, c = colors, alpha = 0.1)
    plt.xlabel('C')
    plt.ylabel('gamma')
    plt.axis([0,10,0,10])
    plt.gca().set_aspect('equal', adjustable='box')
    return plt.show()

# %%
particle_position_vector = np.array([np.array([random.random()*10, random.random()*10]) for _ in range(n_particles)])
pbest_position = particle_position_vector
pbest_fitness_value = np.array([float('inf') for _ in range(n_particles)])
gbest_fitness_value = np.array([float('inf'), float('inf')])
gbest_position = np.array([float('inf'), float('inf')])

velocity_vector = ([np.array([0, 0]) for _ in range(n_particles)])
iteration = 0
while iteration < n_iterations:
    plot(particle_position_vector)
    for i in range(n_particles):
        fitness_cadidate = fitness_function(particle_position_vector[i])
        print("error of particle-",i,"is (training, test)", fitness_cadidate, " At (gamma, c): ", particle_position_vector[i])
        
        if(pbest_fitness_value[i] > fitness_cadidate[1]):
            pbest_fitness_value[i] = fitness_cadidate[1]
            pbest_position[i] = particle_position_vector[i]

        if(gbest_fitness_value[1] > fitness_cadidate[1]):
            gbest_fitness_value = fitness_cadidate
            gbest_position = particle_position_vector[i]
        elif(gbest_fitness_value[1] == fitness_cadidate[1] and gbest_fitness_value[0] > fitness_cadidate[0]):
            gbest_fitness_value = fitness_cadidate
            gbest_position = particle_position_vector[i]
            
    for i in range(n_particles):
        new_velocity = (W*velocity_vector[i]) + (c1*random.random()) * (pbest_position[i] - particle_position_vector[i]) + (c2*random.random()) * (gbest_position-particle_position_vector[i])
        new_position = new_velocity + particle_position_vector[i]
        particle_position_vector[i] = new_position
        
    iteration = iteration + 1
    
print("The best position is ", gbest_position, "in iteration number", iteration, "with error (train, test):", fitness_function(gbest_position))
# Out:
# error of particle- 0 is (training, test) (307, 61)  At (gamma, c):  [ 8.65329577  7.00911352]
# error of particle- 1 is (training, test) (314, 66)  At (gamma, c):  [ 3.16977502  9.32920437]
# error of particle- 2 is (training, test) (318, 62)  At (gamma, c):  [ 4.41370761  1.85268739]
# error of particle- 3 is (training, test) (321, 60)  At (gamma, c):  [ 4.59619327  1.05672856]
# error of particle- 4 is (training, test) (312, 72)  At (gamma, c):  [ 5.06097226  2.46413643]
# error of particle- 5 is (training, test) (318, 71)  At (gamma, c):  [ 1.89398226  5.9646491 ]
# error of particle- 6 is (training, test) (313, 61)  At (gamma, c):  [ 7.4856459  6.5816656]
# error of particle- 7 is (training, test) (323, 71)  At (gamma, c):  [ 0.46760734  5.97425249]
# error of particle- 8 is (training, test) (311, 63)  At (gamma, c):  [ 1.71572021  2.0665073 ]
# error of particle- 9 is (training, test) (328, 70)  At (gamma, c):  [ 1.43568002  0.82551746]
# error of particle- 10 is (training, test) (321, 62)  At (gamma, c):  [ 8.92642002  1.77735798]
# error of particle- 11 is (training, test) (312, 60)  At (gamma, c):  [ 8.6521488   8.90228749]
# error of particle- 12 is (training, test) (313, 61)  At (gamma, c):  [ 7.41576816  8.52181358]
# error of particle- 13 is (training, test) (305, 60)  At (gamma, c):  [ 4.33592345  8.64729532]
# error of particle- 14 is (training, test) (311, 61)  At (gamma, c):  [ 2.14014203  4.34123798]
# error of particle- 15 is (training, test) (310, 62)  At (gamma, c):  [ 9.93655557  4.99415026]
# error of particle- 16 is (training, test) (316, 70)  At (gamma, c):  [ 3.38366985  1.48387239]
# error of particle- 17 is (training, test) (315, 65)  At (gamma, c):  [ 6.3807889  7.1705616]
# error of particle- 18 is (training, test) (310, 61)  At (gamma, c):  [ 8.53120999  6.86455056]
# error of particle- 19 is (training, test) (314, 65)  At (gamma, c):  [ 3.90391651  2.66802185]
# error of particle- 20 is (training, test) (320, 69)  At (gamma, c):  [ 0.6128955   6.23805435]
# error of particle- 21 is (training, test) (314, 71)  At (gamma, c):  [ 6.55214941  2.27650408]
# error of particle- 22 is (training, test) (318, 61)  At (gamma, c):  [ 9.05965967  9.51663164]
# error of particle- 23 is (training, test) (300, 61)  At (gamma, c):  [ 3.67127767  7.42755143]
# error of particle- 24 is (training, test) (312, 67)  At (gamma, c):  [ 6.0909473   9.60058702]
# error of particle- 25 is (training, test) (313, 64)  At (gamma, c):  [ 3.80849209  5.99474613]
# error of particle- 26 is (training, test) (312, 71)  At (gamma, c):  [ 1.78101423  7.80221438]
# error of particle- 27 is (training, test) (304, 71)  At (gamma, c):  [ 5.38512564  8.74386792]
# error of particle- 28 is (training, test) (305, 65)  At (gamma, c):  [ 7.62061159  0.09262995]
# error of particle- 29 is (training, test) (324, 64)  At (gamma, c):  [ 1.11354958  4.04368562]
# error of particle- 30 is (training, test) (318, 66)  At (gamma, c):  [ 0.35422903  4.91018572]
# error of particle- 31 is (training, test) (310, 60)  At (gamma, c):  [ 8.13041669  6.42813216]
# error of particle- 32 is (training, test) (308, 57)  At (gamma, c):  [ 2.16461103  8.40108037]
# error of particle- 33 is (training, test) (316, 61)  At (gamma, c):  [ 9.22327747  9.98600364]
# error of particle- 34 is (training, test) (310, 77)  At (gamma, c):  [ 4.81967883  3.98762376]
# error of particle- 35 is (training, test) (308, 65)  At (gamma, c):  [ 6.37261359  3.8297037 ]
# error of particle- 36 is (training, test) (314, 63)  At (gamma, c):  [ 4.54154945  6.23055208]
# error of particle- 37 is (training, test) (323, 65)  At (gamma, c):  [ 0.38255354  8.56701683]
# error of particle- 38 is (training, test) (317, 70)  At (gamma, c):  [ 1.89653255  4.92334246]
# error of particle- 39 is (training, test) (326, 62)  At (gamma, c):  [ 1.26189522  1.02171401]
# error of particle- 40 is (training, test) (309, 61)  At (gamma, c):  [ 8.39719276  6.17795774]
# error of particle- 41 is (training, test) (310, 77)  At (gamma, c):  [ 4.79438304  3.76954127]
# error of particle- 42 is (training, test) (318, 72)  At (gamma, c):  [ 7.703603    1.84532059]
# error of particle- 43 is (training, test) (314, 58)  At (gamma, c):  [ 8.19739877  4.17590718]
# error of particle- 44 is (training, test) (315, 69)  At (gamma, c):  [ 7.17128232  9.20332327]
# error of particle- 45 is (training, test) (323, 63)  At (gamma, c):  [ 1.76134518  7.66219316]
# error of particle- 46 is (training, test) (321, 76)  At (gamma, c):  [ 1.01218243  3.89710859]
# error of particle- 47 is (training, test) (316, 61)  At (gamma, c):  [ 4.59008134  1.55768365]
# error of particle- 48 is (training, test) (311, 61)  At (gamma, c):  [ 9.3316022   8.73537702]
# error of particle- 49 is (training, test) (315, 60)  At (gamma, c):  [ 7.9093243   2.92786784]
# error of particle- 50 is (training, test) (322, 75)  At (gamma, c):  [ 1.02399877  2.84282744]
# error of particle- 51 is (training, test) (327, 69)  At (gamma, c):  [ 1.27961876  1.18137864]
# error of particle- 52 is (training, test) (308, 72)  At (gamma, c):  [ 4.6926886   6.34893411]
# error of particle- 53 is (training, test) (320, 74)  At (gamma, c):  [ 1.88107293  7.8462003 ]
# error of particle- 54 is (training, test) (321, 62)  At (gamma, c):  [ 4.41841113  0.77915786]
# error of particle- 55 is (training, test) (313, 70)  At (gamma, c):  [ 2.01919684  6.36896893]
# error of particle- 56 is (training, test) (312, 57)  At (gamma, c):  [ 4.55139236  4.2515862 ]
# error of particle- 57 is (training, test) (309, 74)  At (gamma, c):  [ 4.71313294  8.14135871]
# error of particle- 58 is (training, test) (314, 58)  At (gamma, c):  [ 8.19160885  4.65703084]
# error of particle- 59 is (training, test) (325, 70)  At (gamma, c):  [ 0.9636645   8.88318128]
# error of particle- 60 is (training, test) (310, 73)  At (gamma, c):  [ 7.63181864  6.0574044 ]
# error of particle- 61 is (training, test) (308, 73)  At (gamma, c):  [ 5.3639681   9.62411613]
# error of particle- 62 is (training, test) (312, 61)  At (gamma, c):  [ 2.25016132  6.40103902]
# error of particle- 63 is (training, test) (306, 70)  At (gamma, c):  [ 7.57582402  9.09268831]
# error of particle- 64 is (training, test) (310, 75)  At (gamma, c):  [ 6.7168289   3.16136548]
# error of particle- 65 is (training, test) (316, 73)  At (gamma, c):  [ 7.01738385  7.10794277]
# error of particle- 66 is (training, test) (322, 68)  At (gamma, c):  [ 0.86983851  6.94059243]
# error of particle- 67 is (training, test) (302, 59)  At (gamma, c):  [ 8.61121506  9.68770783]
# error of particle- 68 is (training, test) (302, 73)  At (gamma, c):  [ 4.6801775  2.6359814]
# error of particle- 69 is (training, test) (313, 61)  At (gamma, c):  [ 7.44100681  7.73118505]
# error of particle- 70 is (training, test) (303, 74)  At (gamma, c):  [ 5.62270083  7.90666325]
# error of particle- 71 is (training, test) (316, 60)  At (gamma, c):  [ 5.89401677  3.22250485]
# error of particle- 72 is (training, test) (306, 61)  At (gamma, c):  [ 8.50426056  8.88139135]
# error of particle- 73 is (training, test) (316, 64)  At (gamma, c):  [ 7.30747905  6.23316514]
# error of particle- 74 is (training, test) (328, 60)  At (gamma, c):  [ 6.09061481  0.22563928]
# error of particle- 75 is (training, test) (304, 71)  At (gamma, c):  [ 5.39483007  9.17931979]
# error of particle- 76 is (training, test) (320, 72)  At (gamma, c):  [ 0.27491617  6.59118174]
# error of particle- 77 is (training, test) (315, 62)  At (gamma, c):  [ 3.02970082  5.96253496]
# error of particle- 78 is (training, test) (316, 61)  At (gamma, c):  [ 9.28333835  5.27889975]
# error of particle- 79 is (training, test) (319, 64)  At (gamma, c):  [ 0.93376313  2.54375443]
# error of particle- 80 is (training, test) (314, 63)  At (gamma, c):  [ 4.26152727  5.24821143]
# error of particle- 81 is (training, test) (324, 67)  At (gamma, c):  [ 0.47815941  4.13522469]
# error of particle- 82 is (training, test) (318, 62)  At (gamma, c):  [ 4.37001122  2.36392361]
# error of particle- 83 is (training, test) (308, 73)  At (gamma, c):  [ 4.90550605  5.24623335]
# error of particle- 84 is (training, test) (313, 63)  At (gamma, c):  [ 6.41996989  4.77522347]
# error of particle- 85 is (training, test) (316, 72)  At (gamma, c):  [ 7.84466041  0.34150384]
# error of particle- 86 is (training, test) (310, 59)  At (gamma, c):  [ 4.09681169  4.11356866]
# error of particle- 87 is (training, test) (309, 63)  At (gamma, c):  [ 8.13142145  0.09148404]
# error of particle- 88 is (training, test) (320, 62)  At (gamma, c):  [ 8.98966793  3.20234887]
# error of particle- 89 is (training, test) (314, 60)  At (gamma, c):  [ 4.00910002  1.18609251]
# error of particle- 90 is (training, test) (315, 72)  At (gamma, c):  [ 1.93679843  1.26792535]
# error of particle- 91 is (training, test) (310, 61)  At (gamma, c):  [ 2.98948632  5.10813632]
# error of particle- 92 is (training, test) (322, 64)  At (gamma, c):  [ 2.34603226  1.05540854]
# error of particle- 93 is (training, test) (317, 72)  At (gamma, c):  [ 2.58855159  8.36390833]
# error of particle- 94 is (training, test) (315, 75)  At (gamma, c):  [ 0.10174589  6.57973389]
# error of particle- 95 is (training, test) (313, 62)  At (gamma, c):  [ 6.23486575  0.73508924]
# error of particle- 96 is (training, test) (311, 75)  At (gamma, c):  [ 5.39582888  2.61948983]
# error of particle- 97 is (training, test) (315, 71)  At (gamma, c):  [ 1.84863988  7.40901414]
# error of particle- 98 is (training, test) (314, 66)  At (gamma, c):  [ 8.90874538  5.44983147]
# error of particle- 99 is (training, test) (317, 69)  At (gamma, c):  [ 0.92500198  3.41740612]
# error of particle- 0 is (training, test) (315, 73)  At (gamma, c):  [ 7.16822177  7.32769485]
# error of particle- 1 is (training, test) (317, 64)  At (gamma, c):  [ 3.02814223  9.19842692]
# error of particle- 2 is (training, test) (318, 61)  At (gamma, c):  [ 4.28140834  2.23788542]
# error of particle- 3 is (training, test) (320, 59)  At (gamma, c):  [ 3.70121322  3.7599266 ]
# error of particle- 4 is (training, test) (313, 72)  At (gamma, c):  [ 5.03918339  2.50879912]
# error of particle- 5 is (training, test) (318, 71)  At (gamma, c):  [ 2.01387868  7.044059  ]
# error of particle- 6 is (training, test) (311, 70)  At (gamma, c):  [ 6.24797389  7.00486123]
# error of particle- 7 is (training, test) (320, 63)  At (gamma, c):  [ 1.09423701  6.87037451]
# error of particle- 8 is (training, test) (322, 68)  At (gamma, c):  [ 1.8110091  3.4111871]
# error of particle- 9 is (training, test) (325, 72)  At (gamma, c):  [ 1.73266773  3.91202226]
# error of particle- 10 is (training, test) (308, 64)  At (gamma, c):  [ 5.84654891  4.79433336]
# error of particle- 11 is (training, test) (319, 70)  At (gamma, c):  [ 6.76862653  8.75677238]
# error of particle- 12 is (training, test) (296, 71)  At (gamma, c):  [ 5.49645457  8.47768523]
# error of particle- 13 is (training, test) (306, 59)  At (gamma, c):  [ 4.10653912  8.62128439]
# error of particle- 14 is (training, test) (315, 59)  At (gamma, c):  [ 2.14227342  4.69487383]
# error of particle- 15 is (training, test) (310, 70)  At (gamma, c):  [ 6.5086282   6.49682554]
# error of particle- 16 is (training, test) (312, 66)  At (gamma, c):  [ 3.14606285  2.83210678]
# error of particle- 17 is (training, test) (310, 56)  At (gamma, c):  [ 5.89375355  7.31270601]
# error of particle- 18 is (training, test) (314, 60)  At (gamma, c):  [ 5.79609987  7.52464841]
# error of particle- 19 is (training, test) (306, 61)  At (gamma, c):  [ 3.62205951  3.5970724 ]
# error of particle- 20 is (training, test) (321, 64)  At (gamma, c):  [ 1.19208605  7.04542155]
# error of particle- 21 is (training, test) (312, 64)  At (gamma, c):  [ 6.12597343  2.87140424]
# error of particle- 22 is (training, test) (307, 60)  At (gamma, c):  [ 8.97708976  9.50327264]
# error of particle- 23 is (training, test) (317, 68)  At (gamma, c):  [ 3.38811434  7.61051672]
# error of particle- 24 is (training, test) (312, 73)  At (gamma, c):  [ 5.10898637  9.30059523]
# error of particle- 25 is (training, test) (309, 62)  At (gamma, c):  [ 3.61766704  6.27407829]
# error of particle- 26 is (training, test) (325, 66)  At (gamma, c):  [ 1.82056875  7.86396636]
# error of particle- 27 is (training, test) (310, 77)  At (gamma, c):  [ 4.75206769  8.67648603]
# error of particle- 28 is (training, test) (309, 73)  At (gamma, c):  [ 5.38156975  3.50226452]
# error of particle- 29 is (training, test) (323, 71)  At (gamma, c):  [ 1.42239784  5.32408058]
# error of particle- 30 is (training, test) (327, 68)  At (gamma, c):  [ 1.0315882   6.21631311]
# error of particle- 31 is (training, test) (310, 58)  At (gamma, c):  [ 6.29335745  7.03566498]
# error of particle- 32 is (training, test) (308, 57)  At (gamma, c):  [ 2.16461103  8.40108037]
# error of particle- 33 is (training, test) (315, 64)  At (gamma, c):  [ 8.67856039  9.86369516]
# error of particle- 34 is (training, test) (319, 68)  At (gamma, c):  [ 4.62671094  4.30838972]
# error of particle- 35 is (training, test) (314, 73)  At (gamma, c):  [ 5.20253389  5.10082343]
# error of particle- 36 is (training, test) (319, 60)  At (gamma, c):  [ 4.37363418  6.38388582]
# error of particle- 37 is (training, test) (324, 62)  At (gamma, c):  [ 1.23424255  8.48771173]
# error of particle- 38 is (training, test) (320, 70)  At (gamma, c):  [ 1.94523248  5.5551186 ]
# error of particle- 39 is (training, test) (315, 60)  At (gamma, c):  [ 1.68317323  4.46550528]
# error of particle- 40 is (training, test) (314, 61)  At (gamma, c):  [ 5.79551334  7.10596039]
# error of particle- 41 is (training, test) (312, 62)  At (gamma, c):  [ 3.83056543  5.46701121]
# error of particle- 42 is (training, test) (313, 67)  At (gamma, c):  [ 6.09283218  3.75177336]
# error of particle- 43 is (training, test) (309, 70)  At (gamma, c):  [ 5.3614063   6.16214635]
# error of particle- 44 is (training, test) (311, 74)  At (gamma, c):  [ 4.91745965  8.84218248]
# error of particle- 45 is (training, test) (313, 70)  At (gamma, c):  [ 1.78319661  7.70223063]
# error of particle- 46 is (training, test) (322, 72)  At (gamma, c):  [ 1.38379962  5.34947916]
# error of particle- 47 is (training, test) (313, 72)  At (gamma, c):  [ 3.93261537  3.41270551]
# error of particle- 48 is (training, test) (309, 61)  At (gamma, c):  [ 8.43547851  8.69357829]
# error of particle- 49 is (training, test) (318, 58)  At (gamma, c):  [ 7.23251644  3.57268911]
# error of particle- 50 is (training, test) (324, 73)  At (gamma, c):  [ 1.16115864  3.51121342]
# error of particle- 51 is (training, test) (316, 58)  At (gamma, c):  [ 1.5494681   3.38278966]
# error of particle- 52 is (training, test) (315, 66)  At (gamma, c):  [ 3.90020147  6.99222905]
# error of particle- 53 is (training, test) (321, 74)  At (gamma, c):  [ 1.89401358  7.87152497]
# error of particle- 54 is (training, test) (310, 63)  At (gamma, c):  [ 3.53190472  3.77715364]
# error of particle- 55 is (training, test) (309, 74)  At (gamma, c):  [ 2.03707419  6.61879852]
# error of particle- 56 is (training, test) (305, 57)  At (gamma, c):  [ 4.0396562   5.14125557]
# error of particle- 57 is (training, test) (313, 67)  At (gamma, c):  [ 3.78892425  8.23554547]
# error of particle- 58 is (training, test) (313, 62)  At (gamma, c):  [ 7.4424589   5.12241254]
# error of particle- 59 is (training, test) (326, 70)  At (gamma, c):  [ 1.44156225  8.69133682]
# error of particle- 60 is (training, test) (310, 62)  At (gamma, c):  [ 5.99598509  6.75865156]
# error of particle- 61 is (training, test) (311, 74)  At (gamma, c):  [ 4.93539207  9.46028203]
# error of particle- 62 is (training, test) (314, 59)  At (gamma, c):  [ 2.24005192  6.63738222]
# error of particle- 63 is (training, test) (313, 61)  At (gamma, c):  [ 7.44817938  9.07637403]
# error of particle- 64 is (training, test) (315, 69)  At (gamma, c):  [ 6.45245422  3.46566725]
# error of particle- 65 is (training, test) (304, 70)  At (gamma, c):  [ 5.43275902  7.53020403]
# error of particle- 66 is (training, test) (320, 72)  At (gamma, c):  [ 1.37718831  7.51287695]
# error of particle- 67 is (training, test) (314, 57)  At (gamma, c):  [ 6.28686106  9.22380813]
# error of particle- 68 is (training, test) (321, 68)  At (gamma, c):  [ 3.74296788  4.78385   ]
# error of particle- 69 is (training, test) (315, 65)  At (gamma, c):  [ 6.41472282  7.86148287]
# error of particle- 70 is (training, test) (308, 74)  At (gamma, c):  [ 5.09166703  7.98258731]
# error of particle- 71 is (training, test) (310, 77)  At (gamma, c):  [ 4.7514708   4.80902051]
# error of particle- 72 is (training, test) (303, 74)  At (gamma, c):  [ 5.56111204  8.65840954]
# error of particle- 73 is (training, test) (315, 65)  At (gamma, c):  [ 6.39199003  6.61907872]
# error of particle- 74 is (training, test) (314, 63)  At (gamma, c):  [ 4.19611179  4.17071899]
# error of particle- 75 is (training, test) (308, 74)  At (gamma, c):  [ 5.05729114  9.09799834]
# error of particle- 76 is (training, test) (318, 72)  At (gamma, c):  [ 0.95806285  7.24548115]
# error of particle- 77 is (training, test) (317, 73)  At (gamma, c):  [ 2.59891554  7.1768476 ]
# error of particle- 78 is (training, test) (314, 58)  At (gamma, c):  [ 8.15050855  5.77574407]
# error of particle- 79 is (training, test) (323, 68)  At (gamma, c):  [ 1.15345111  3.58919969]
# error of particle- 80 is (training, test) (314, 63)  At (gamma, c):  [ 4.21468741  5.31863862]
# error of particle- 81 is (training, test) (323, 69)  At (gamma, c):  [ 0.99643041  5.4461839 ]
# error of particle- 82 is (training, test) (319, 71)  At (gamma, c):  [ 3.27982499  5.34824599]
# error of particle- 83 is (training, test) (315, 74)  At (gamma, c):  [ 3.95569797  6.33948908]
# error of particle- 84 is (training, test) (312, 74)  At (gamma, c):  [ 4.98301197  5.99960994]
# error of particle- 85 is (training, test) (320, 79)  At (gamma, c):  [ 6.75807467  1.8832899 ]
# error of particle- 86 is (training, test) (317, 71)  At (gamma, c):  [ 3.78491935  4.80565105]
# error of particle- 87 is (training, test) (318, 72)  At (gamma, c):  [ 6.72996253  2.04320649]
# error of particle- 88 is (training, test) (314, 71)  At (gamma, c):  [ 6.61610214  5.01032372]
# error of particle- 89 is (training, test) (318, 74)  At (gamma, c):  [ 3.94632615  1.43164166]
# error of particle- 90 is (training, test) (311, 70)  At (gamma, c):  [ 1.96082098  2.02010769]
# error of particle- 91 is (training, test) (314, 59)  At (gamma, c):  [ 2.89520371  5.48451728]
# error of particle- 92 is (training, test) (315, 57)  At (gamma, c):  [ 2.29974     2.92976312]
# error of particle- 93 is (training, test) (312, 57)  At (gamma, c):  [ 2.44379907  8.37660055]
# error of particle- 94 is (training, test) (323, 69)  At (gamma, c):  [ 0.44562278  6.88334994]
# error of particle- 95 is (training, test) (314, 74)  At (gamma, c):  [ 4.84812603  3.34689983]
# error of particle- 96 is (training, test) (307, 68)  At (gamma, c):  [ 5.08784782  3.17055773]
# error of particle- 97 is (training, test) (313, 72)  At (gamma, c):  [ 1.9328997   7.67356779]
# error of particle- 98 is (training, test) (311, 62)  At (gamma, c):  [ 6.03209173  6.70866181]
# error of particle- 99 is (training, test) (320, 66)  At (gamma, c):  [ 1.07537183  4.02194699]
# error of particle- 0 is (training, test) (315, 73)  At (gamma, c):  [ 7.16405082  7.32764579]
# error of particle- 1 is (training, test) (316, 67)  At (gamma, c):  [ 3.36602274  8.97608401]
# error of particle- 2 is (training, test) (301, 62)  At (gamma, c):  [ 4.42422968  2.68741241]
# error of particle- 3 is (training, test) (313, 63)  At (gamma, c):  [ 3.84709996  3.99632061]
# error of particle- 4 is (training, test) (314, 73)  At (gamma, c):  [ 5.20069725  3.41673806]
# error of particle- 5 is (training, test) (314, 66)  At (gamma, c):  [ 3.17307328  7.12432297]
# error of particle- 6 is (training, test) (311, 70)  At (gamma, c):  [ 6.23329829  7.01761546]
# error of particle- 7 is (training, test) (303, 70)  At (gamma, c):  [ 1.98616351  6.95257595]
# error of particle- 8 is (training, test) (315, 59)  At (gamma, c):  [ 3.33608979  4.86857226]
# error of particle- 9 is (training, test) (306, 59)  At (gamma, c):  [ 3.7045628   5.52357074]
# error of particle- 10 is (training, test) (309, 64)  At (gamma, c):  [ 5.85001568  4.97928569]
# error of particle- 11 is (training, test) (318, 70)  At (gamma, c):  [ 6.66359064  8.58340001]
# error of particle- 12 is (training, test) (311, 62)  At (gamma, c):  [ 5.6845187   7.92623452]
# error of particle- 13 is (training, test) (325, 56)  At (gamma, c):  [ 4.58511824  8.27087412]
# error of particle- 14 is (training, test) (314, 56)  At (gamma, c):  [ 2.15928499  4.70674473]
# error of particle- 15 is (training, test) (310, 70)  At (gamma, c):  [ 6.43994413  6.58796281]
# error of particle- 16 is (training, test) (315, 60)  At (gamma, c):  [ 4.3760436   4.83780953]
# error of particle- 17 is (training, test) (310, 56)  At (gamma, c):  [ 5.89375355  7.31270601]
# error of particle- 18 is (training, test) (316, 63)  At (gamma, c):  [ 5.83425629  7.44183573]
# error of particle- 19 is (training, test) (313, 65)  At (gamma, c):  [ 3.80342692  3.893721  ]
# error of particle- 20 is (training, test) (314, 62)  At (gamma, c):  [ 2.31470174  7.10924098]
# error of particle- 21 is (training, test) (308, 60)  At (gamma, c):  [ 6.01305886  5.03094239]
# error of particle- 22 is (training, test) (310, 76)  At (gamma, c):  [ 7.81725345  8.67926301]
# error of particle- 23 is (training, test) (322, 64)  At (gamma, c):  [ 3.62029573  7.58292053]
# error of particle- 24 is (training, test) (308, 73)  At (gamma, c):  [ 5.33106384  8.73805208]
# error of particle- 25 is (training, test) (304, 60)  At (gamma, c):  [ 4.002162    6.44953169]
# error of particle- 26 is (training, test) (316, 64)  At (gamma, c):  [ 3.81898832  7.59350245]
# error of particle- 27 is (training, test) (304, 75)  At (gamma, c):  [ 4.8558469   8.55251846]
# error of particle- 28 is (training, test) (302, 72)  At (gamma, c):  [ 5.54400549  4.71072108]
# error of particle- 29 is (training, test) (311, 55)  At (gamma, c):  [ 2.13824679  5.64245279]
# error of particle- 30 is (training, test) (318, 72)  At (gamma, c):  [ 1.83046358  6.39645534]
# error of particle- 31 is (training, test) (311, 70)  At (gamma, c):  [ 6.14100186  7.14129145]
# error of particle- 32 is (training, test) (320, 75)  At (gamma, c):  [ 2.54735761  8.28937331]
# error of particle- 33 is (training, test) (304, 61)  At (gamma, c):  [ 8.3539264   9.56631806]
# error of particle- 34 is (training, test) (310, 77)  At (gamma, c):  [ 4.80401196  4.7287926 ]
# error of particle- 35 is (training, test) (309, 70)  At (gamma, c):  [ 5.35162063  5.57789662]
# error of particle- 36 is (training, test) (310, 72)  At (gamma, c):  [ 5.04016291  6.79114682]
# error of particle- 37 is (training, test) (314, 60)  At (gamma, c):  [ 2.92506208  8.06133166]
# error of particle- 38 is (training, test) (310, 75)  At (gamma, c):  [ 2.51200358  5.80740287]
# error of particle- 39 is (training, test) (317, 72)  At (gamma, c):  [ 1.93481306  4.63566451]
# error of particle- 40 is (training, test) (316, 63)  At (gamma, c):  [ 5.81935087  7.15612625]
# error of particle- 41 is (training, test) (302, 57)  At (gamma, c):  [ 4.29507475  5.88255376]
# error of particle- 42 is (training, test) (308, 60)  At (gamma, c):  [ 6.02553654  4.95549498]
# error of particle- 43 is (training, test) (309, 73)  At (gamma, c):  [ 5.61087371  6.70131912]
# error of particle- 44 is (training, test) (308, 74)  At (gamma, c):  [ 5.04340099  8.64488092]
# error of particle- 45 is (training, test) (319, 60)  At (gamma, c):  [ 1.81163363  7.69953589]
# error of particle- 46 is (training, test) (318, 72)  At (gamma, c):  [ 3.43945541  6.24432614]
# error of particle- 47 is (training, test) (310, 77)  At (gamma, c):  [ 4.79506192  5.12780239]
# error of particle- 48 is (training, test) (311, 76)  At (gamma, c):  [ 7.85690686  8.37925098]
# error of particle- 49 is (training, test) (321, 71)  At (gamma, c):  [ 6.93407546  4.40642472]
# error of particle- 50 is (training, test) (321, 71)  At (gamma, c):  [ 1.38653143  3.69224582]
# error of particle- 51 is (training, test) (313, 75)  At (gamma, c):  [ 2.51936093  4.26017163]
# error of particle- 52 is (training, test) (312, 64)  At (gamma, c):  [ 4.48388317  7.08605982]
# error of particle- 53 is (training, test) (316, 62)  At (gamma, c):  [ 3.59613896  7.63371453]
# error of particle- 54 is (training, test) (320, 71)  At (gamma, c):  [ 3.98222752  4.45126107]
# error of particle- 55 is (training, test) (310, 58)  At (gamma, c):  [ 2.81648101  6.75903217]
# error of particle- 56 is (training, test) (310, 77)  At (gamma, c):  [ 4.8124888   6.04636861]
# error of particle- 57 is (training, test) (311, 64)  At (gamma, c):  [ 4.46807514  7.93777917]
# error of particle- 58 is (training, test) (319, 74)  At (gamma, c):  [ 7.18096164  5.49224128]
# error of particle- 59 is (training, test) (315, 64)  At (gamma, c):  [ 2.95633201  8.22228504]
# error of particle- 60 is (training, test) (309, 65)  At (gamma, c):  [ 5.95075344  7.00378917]
# error of particle- 61 is (training, test) (298, 75)  At (gamma, c):  [ 5.26781391  8.71536355]
# error of particle- 62 is (training, test) (306, 68)  At (gamma, c):  [ 3.55196287  6.87986635]
# error of particle- 63 is (training, test) (319, 62)  At (gamma, c):  [ 7.26762629  8.87151659]
# error of particle- 64 is (training, test) (310, 65)  At (gamma, c):  [ 6.39155691  3.88498718]
# error of particle- 65 is (training, test) (309, 73)  At (gamma, c):  [ 5.59291835  7.45464058]
# error of particle- 66 is (training, test) (317, 68)  At (gamma, c):  [ 3.39486354  7.42345503]
# error of particle- 67 is (training, test) (311, 70)  At (gamma, c):  [ 6.21266152  8.86308517]
# error of particle- 68 is (training, test) (317, 58)  At (gamma, c):  [ 4.60091856  5.79261335]
# error of particle- 69 is (training, test) (311, 70)  At (gamma, c):  [ 6.1656957   7.59916351]
# error of particle- 70 is (training, test) (312, 72)  At (gamma, c):  [ 5.17013169  7.91705571]
# error of particle- 71 is (training, test) (314, 73)  At (gamma, c):  [ 5.19119603  5.77282187]
# error of particle- 72 is (training, test) (303, 74)  At (gamma, c):  [ 5.58000335  8.58198461]
# error of particle- 73 is (training, test) (310, 58)  At (gamma, c):  [ 6.34754524  6.68095319]
# error of particle- 74 is (training, test) (310, 77)  At (gamma, c):  [ 4.84345605  5.36882056]
# error of particle- 75 is (training, test) (314, 70)  At (gamma, c):  [ 5.12618875  8.95094765]
# error of particle- 76 is (training, test) (321, 65)  At (gamma, c):  [ 2.56927137  7.26742606]
# error of particle- 77 is (training, test) (310, 60)  At (gamma, c):  [ 4.03306094  7.23598274]
# error of particle- 78 is (training, test) (309, 60)  At (gamma, c):  [ 8.04964534  5.84443691]
# error of particle- 79 is (training, test) (314, 73)  At (gamma, c):  [ 1.90111843  4.17649217]
# error of particle- 80 is (training, test) (304, 74)  At (gamma, c):  [ 4.63888866  5.82242216]
# error of particle- 81 is (training, test) (308, 62)  At (gamma, c):  [ 2.71805861  6.10234994]
# error of particle- 82 is (training, test) (310, 65)  At (gamma, c):  [ 4.04490452  5.92323039]
# error of particle- 83 is (training, test) (320, 71)  At (gamma, c):  [ 3.98871098  6.35606694]
# error of particle- 84 is (training, test) (298, 75)  At (gamma, c):  [ 5.26451487  6.40547738]
# error of particle- 85 is (training, test) (312, 68)  At (gamma, c):  [ 6.34446116  4.48149077]
# error of particle- 86 is (training, test) (313, 66)  At (gamma, c):  [ 3.84322592  4.87496791]
# error of particle- 87 is (training, test) (312, 68)  At (gamma, c):  [ 6.32084624  4.62131578]
# error of particle- 88 is (training, test) (313, 69)  At (gamma, c):  [ 6.54736894  5.22940092]
# error of particle- 89 is (training, test) (302, 64)  At (gamma, c):  [ 4.54114476  3.22794304]
# error of particle- 90 is (training, test) (310, 54)  At (gamma, c):  [ 2.32416663  2.50906663]
# error of particle- 91 is (training, test) (313, 64)  At (gamma, c):  [ 3.82048367  6.0486521 ]
# error of particle- 92 is (training, test) (305, 57)  At (gamma, c):  [ 4.03474723  5.04562537]
# error of particle- 93 is (training, test) (315, 67)  At (gamma, c):  [ 2.6620991   8.30928134]
# error of particle- 94 is (training, test) (315, 72)  At (gamma, c):  [ 0.83928429  6.9143736 ]
# error of particle- 95 is (training, test) (310, 74)  At (gamma, c):  [ 4.92004051  3.61965362]
# error of particle- 96 is (training, test) (299, 76)  At (gamma, c):  [ 5.40633044  4.80747652]
# error of particle- 97 is (training, test) (309, 68)  At (gamma, c):  [ 3.8020605   7.50327403]
# error of particle- 98 is (training, test) (310, 62)  At (gamma, c):  [ 6.00205825  6.83980092]
# error of particle- 99 is (training, test) (318, 62)  At (gamma, c):  [ 3.01044302  5.34352203]
# error of particle- 0 is (training, test) (298, 75)  At (gamma, c):  [ 5.28676584  5.45862456]
# error of particle- 1 is (training, test) (308, 64)  At (gamma, c):  [ 3.00278405  6.721386  ]
# error of particle- 2 is (training, test) (313, 62)  At (gamma, c):  [ 4.35671764  2.68167902]
# error of particle- 3 is (training, test) (312, 72)  At (gamma, c):  [ 3.78131963  3.93208138]
# error of particle- 4 is (training, test) (310, 64)  At (gamma, c):  [ 4.58386228  3.2220996 ]
# error of particle- 5 is (training, test) (308, 65)  At (gamma, c):  [ 2.96815097  6.01022048]
# error of particle- 6 is (training, test) (310, 74)  At (gamma, c):  [ 5.5210169  6.1961145]
# error of particle- 7 is (training, test) (325, 64)  At (gamma, c):  [ 2.05358255  6.06626128]
# error of particle- 8 is (training, test) (320, 62)  At (gamma, c):  [ 3.09176516  4.29887946]
# error of particle- 9 is (training, test) (315, 64)  At (gamma, c):  [ 3.0844924   4.16946327]
# error of particle- 10 is (training, test) (312, 62)  At (gamma, c):  [ 4.29458023  3.88954355]
# error of particle- 11 is (training, test) (311, 70)  At (gamma, c):  [ 6.54478614  8.41709727]
# error of particle- 12 is (training, test) (302, 57)  At (gamma, c):  [ 4.29756839  5.69035491]
# error of particle- 13 is (training, test) (321, 56)  At (gamma, c):  [ 4.02959872  6.85518857]
# error of particle- 14 is (training, test) (308, 55)  At (gamma, c):  [ 2.1764599   4.47782335]
# error of particle- 15 is (training, test) (311, 72)  At (gamma, c):  [ 5.07150141  5.23178265]
# error of particle- 16 is (training, test) (311, 64)  At (gamma, c):  [ 3.52141767  3.86786636]
# error of particle- 17 is (training, test) (310, 77)  At (gamma, c):  [ 4.74348644  5.76477666]
# error of particle- 18 is (training, test) (310, 72)  At (gamma, c):  [ 5.05183743  6.34229357]
# error of particle- 19 is (training, test) (322, 66)  At (gamma, c):  [ 3.50643308  3.61572136]
# error of particle- 20 is (training, test) (311, 64)  At (gamma, c):  [ 2.31853843  5.24451224]
# error of particle- 21 is (training, test) (307, 67)  At (gamma, c):  [ 5.47307708  4.66178903]
# error of particle- 22 is (training, test) (319, 62)  At (gamma, c):  [ 7.23966716  8.03048011]
# error of particle- 23 is (training, test) (314, 66)  At (gamma, c):  [ 3.2065831   5.96339248]
# error of particle- 24 is (training, test) (298, 75)  At (gamma, c):  [ 5.26399531  8.5991152 ]
# error of particle- 25 is (training, test) (315, 74)  At (gamma, c):  [ 3.87125978  6.1421318 ]
# error of particle- 26 is (training, test) (310, 63)  At (gamma, c):  [ 3.26184451  5.69845241]
# error of particle- 27 is (training, test) (305, 60)  At (gamma, c):  [ 4.10013048  6.74852455]
# error of particle- 28 is (training, test) (314, 63)  At (gamma, c):  [ 4.21522488  3.80213035]
# error of particle- 29 is (training, test) (308, 58)  At (gamma, c):  [ 2.21017268  4.43025511]
# error of particle- 30 is (training, test) (310, 67)  At (gamma, c):  [ 1.97250873  5.27800018]
# error of particle- 31 is (training, test) (311, 72)  At (gamma, c):  [ 5.07628987  5.84912529]
# error of particle- 32 is (training, test) (312, 61)  At (gamma, c):  [ 2.46236661  6.0882358 ]
# error of particle- 33 is (training, test) (309, 74)  At (gamma, c):  [ 5.61761331  6.36372787]
# error of particle- 34 is (training, test) (303, 58)  At (gamma, c):  [ 4.02754061  4.03376795]
# error of particle- 35 is (training, test) (320, 71)  At (gamma, c):  [ 3.98751555  4.19514842]
# error of particle- 36 is (training, test) (314, 65)  At (gamma, c):  [ 3.89963942  4.9929805 ]
# error of particle- 37 is (training, test) (313, 58)  At (gamma, c):  [ 2.69023257  5.89151043]
# error of particle- 38 is (training, test) (308, 55)  At (gamma, c):  [ 2.45069112  4.73078237]
# error of particle- 39 is (training, test) (309, 67)  At (gamma, c):  [ 1.98779458  4.34628643]
# error of particle- 40 is (training, test) (316, 62)  At (gamma, c):  [ 4.12169856  4.89899445]
# error of particle- 41 is (training, test) (300, 57)  At (gamma, c):  [ 3.72534036  4.90737301]
# error of particle- 42 is (training, test) (309, 74)  At (gamma, c):  [ 4.87726468  4.19654224]
# error of particle- 43 is (training, test) (317, 58)  At (gamma, c):  [ 4.59788278  5.40923143]
# error of particle- 44 is (training, test) (309, 68)  At (gamma, c):  [ 3.84258015  5.93528966]
# error of particle- 45 is (training, test) (309, 71)  At (gamma, c):  [ 2.02782005  5.51019593]
# error of particle- 46 is (training, test) (310, 69)  At (gamma, c):  [ 3.35116089  5.94861531]
# error of particle- 47 is (training, test) (320, 71)  At (gamma, c):  [ 3.97209131  4.25559118]
# error of particle- 48 is (training, test) (298, 75)  At (gamma, c):  [ 5.27156864  5.63623192]
# error of particle- 49 is (training, test) (310, 65)  At (gamma, c):  [ 6.41253662  4.19176843]
# error of particle- 50 is (training, test) (323, 68)  At (gamma, c):  [ 1.47586264  3.57952094]
# error of particle- 51 is (training, test) (308, 59)  At (gamma, c):  [ 2.50093918  4.09490846]
# error of particle- 52 is (training, test) (308, 70)  At (gamma, c):  [ 3.83675236  5.71462368]
# error of particle- 53 is (training, test) (314, 58)  At (gamma, c):  [ 3.35109593  6.64646093]
# error of particle- 54 is (training, test) (313, 66)  At (gamma, c):  [ 3.7910151   4.22728153]
# error of particle- 55 is (training, test) (312, 68)  At (gamma, c):  [ 2.7527868   6.20918387]
# error of particle- 56 is (training, test) (314, 63)  At (gamma, c):  [ 4.19557541  5.16938853]
# error of particle- 57 is (training, test) (316, 65)  At (gamma, c):  [ 3.40461713  5.24493674]
# error of particle- 58 is (training, test) (313, 67)  At (gamma, c):  [ 6.08099046  4.81660928]
# error of particle- 59 is (training, test) (315, 59)  At (gamma, c):  [ 2.77751647  6.60623286]
# error of particle- 60 is (training, test) (303, 72)  At (gamma, c):  [ 4.67453348  5.42206648]
# error of particle- 61 is (training, test) (314, 63)  At (gamma, c):  [ 4.04853384  6.14467031]
# error of particle- 62 is (training, test) (307, 67)  At (gamma, c):  [ 3.51853577  6.76087009]
# error of particle- 63 is (training, test) (309, 70)  At (gamma, c):  [ 5.24419448  6.26727087]
# error of particle- 64 is (training, test) (312, 59)  At (gamma, c):  [ 4.49733892  3.24420936]
# error of particle- 65 is (training, test) (310, 77)  At (gamma, c):  [ 4.84107888  6.31711836]
# error of particle- 66 is (training, test) (317, 68)  At (gamma, c):  [ 3.38798894  7.39190134]
# error of particle- 67 is (training, test) (313, 75)  At (gamma, c):  [ 4.95117909  6.8017522 ]
# error of particle- 68 is (training, test) (307, 67)  At (gamma, c):  [ 3.51124688  4.22108162]
# error of particle- 69 is (training, test) (308, 73)  At (gamma, c):  [ 4.88631595  5.90396175]
# error of particle- 70 is (training, test) (308, 72)  At (gamma, c):  [ 4.67059818  6.967827  ]
# error of particle- 71 is (training, test) (304, 60)  At (gamma, c):  [ 4.01063246  4.42889755]
# error of particle- 72 is (training, test) (309, 71)  At (gamma, c):  [ 5.50402765  8.44027166]
# error of particle- 73 is (training, test) (311, 58)  At (gamma, c):  [ 5.75834897  6.07000894]
# error of particle- 74 is (training, test) (318, 66)  At (gamma, c):  [ 3.59708706  3.95401344]
# error of particle- 75 is (training, test) (314, 63)  At (gamma, c):  [ 4.52640906  7.57204727]
# error of particle- 76 is (training, test) (312, 74)  At (gamma, c):  [ 2.5233495   6.37591834]
# error of particle- 77 is (training, test) (317, 71)  At (gamma, c):  [ 3.41486119  5.52600084]
# error of particle- 78 is (training, test) (297, 75)  At (gamma, c):  [ 5.26775834  4.2238522 ]
# error of particle- 79 is (training, test) (310, 59)  At (gamma, c):  [ 2.09577366  3.4092673 ]
# error of particle- 80 is (training, test) (312, 61)  At (gamma, c):  [ 4.25088444  5.26702246]
# error of particle- 81 is (training, test) (314, 62)  At (gamma, c):  [ 2.6317046   5.31458465]
# error of particle- 82 is (training, test) (312, 63)  At (gamma, c):  [ 3.54181832  4.92504312]
# error of particle- 83 is (training, test) (315, 74)  At (gamma, c):  [ 3.94152875  6.24702205]
# error of particle- 84 is (training, test) (304, 74)  At (gamma, c):  [ 4.64158693  5.58000267]
# error of particle- 85 is (training, test) (301, 73)  At (gamma, c):  [ 5.59208066  4.11236024]
# error of particle- 86 is (training, test) (306, 59)  At (gamma, c):  [ 3.70597231  4.66119845]
# error of particle- 87 is (training, test) (314, 63)  At (gamma, c):  [ 4.50585636  3.66209182]
# error of particle- 88 is (training, test) (303, 73)  At (gamma, c):  [ 5.04187231  4.25965005]
# error of particle- 89 is (training, test) (302, 62)  At (gamma, c):  [ 4.05137867  3.06913169]
# error of particle- 90 is (training, test) (310, 54)  At (gamma, c):  [ 2.32416663  2.50906663]
# error of particle- 91 is (training, test) (317, 70)  At (gamma, c):  [ 3.77189191  5.93370674]
# error of particle- 92 is (training, test) (314, 60)  At (gamma, c):  [ 3.21598891  3.83151796]
# error of particle- 93 is (training, test) (320, 68)  At (gamma, c):  [ 2.63604968  7.86217344]
# error of particle- 94 is (training, test) (318, 70)  At (gamma, c):  [ 0.85779106  6.85946824]
# error of particle- 95 is (training, test) (318, 60)  At (gamma, c):  [ 3.70205335  3.09856486]
# error of particle- 96 is (training, test) (302, 60)  At (gamma, c):  [ 4.4324822   4.08126514]
# error of particle- 97 is (training, test) (316, 62)  At (gamma, c):  [ 3.66475377  7.03927708]
# error of particle- 98 is (training, test) (310, 77)  At (gamma, c):  [ 4.81819981  5.44580217]
# error of particle- 99 is (training, test) (310, 58)  At (gamma, c):  [ 2.82581887  4.58098824]
# error of particle- 0 is (training, test) (313, 63)  At (gamma, c):  [ 3.8404505   4.01867586]
# error of particle- 1 is (training, test) (308, 62)  At (gamma, c):  [ 2.99127942  6.64997436]
# error of particle- 2 is (training, test) (304, 61)  At (gamma, c):  [ 4.04942995  2.65558292]
# error of particle- 3 is (training, test) (307, 62)  At (gamma, c):  [ 3.32450529  3.48596931]
# error of particle- 4 is (training, test) (313, 59)  At (gamma, c):  [ 4.36301989  3.15241416]
# error of particle- 5 is (training, test) (311, 58)  At (gamma, c):  [ 2.85793984  5.41103495]
# error of particle- 6 is (training, test) (308, 73)  At (gamma, c):  [ 4.90901388  5.49026836]
# error of particle- 7 is (training, test) (314, 61)  At (gamma, c):  [ 2.06305365  5.94175072]
# error of particle- 8 is (training, test) (313, 58)  At (gamma, c):  [ 2.91565805  3.88824975]
# error of particle- 9 is (training, test) (313, 62)  At (gamma, c):  [ 3.01614428  4.0202049 ]
# error of particle- 10 is (training, test) (309, 67)  At (gamma, c):  [ 3.79200374  3.53743715]
# error of particle- 11 is (training, test) (308, 73)  At (gamma, c):  [ 4.89909669  6.11345827]
# error of particle- 12 is (training, test) (309, 65)  At (gamma, c):  [ 3.34976112  4.16241052]
# error of particle- 13 is (training, test) (321, 64)  At (gamma, c):  [ 3.6973288   6.00843213]
# error of particle- 14 is (training, test) (311, 60)  At (gamma, c):  [ 2.18661535  4.3424632 ]
# error of particle- 15 is (training, test) (309, 71)  At (gamma, c):  [ 4.91877264  5.08042248]
# error of particle- 16 is (training, test) (311, 64)  At (gamma, c):  [ 3.52021039  3.86649618]
# error of particle- 17 is (training, test) (314, 65)  At (gamma, c):  [ 3.88752261  4.61289503]
# error of particle- 18 is (training, test) (318, 59)  At (gamma, c):  [ 4.23536263  5.1948922 ]
# error of particle- 19 is (training, test) (307, 62)  At (gamma, c):  [ 3.33187425  3.45232642]
# error of particle- 20 is (training, test) (311, 64)  At (gamma, c):  [ 2.31858032  5.22415604]
# error of particle- 21 is (training, test) (320, 71)  At (gamma, c):  [ 3.98793811  3.64648803]
# error of particle- 22 is (training, test) (314, 72)  At (gamma, c):  [ 7.22202725  8.0106658 ]
# error of particle- 23 is (training, test) (312, 60)  At (gamma, c):  [ 2.85605068  4.59119097]
# error of particle- 24 is (training, test) (309, 71)  At (gamma, c):  [ 5.24821871  8.56643293]
# error of particle- 25 is (training, test) (311, 60)  At (gamma, c):  [ 3.16387392  4.48096554]
# error of particle- 26 is (training, test) (313, 64)  At (gamma, c):  [ 3.01820834  4.86975657]
# error of particle- 27 is (training, test) (315, 74)  At (gamma, c):  [ 3.95941049  6.41260754]
# error of particle- 28 is (training, test) (321, 68)  At (gamma, c):  [ 3.75083135  3.48458835]
# error of particle- 29 is (training, test) (307, 60)  At (gamma, c):  [ 2.2139806   4.36607869]
# error of particle- 30 is (training, test) (316, 54)  At (gamma, c):  [ 2.09027461  4.35071859]
# error of particle- 31 is (training, test) (316, 63)  At (gamma, c):  [ 4.17290834  4.75275459]
# error of particle- 32 is (training, test) (316, 53)  At (gamma, c):  [ 2.41517544  4.86605633]
# error of particle- 33 is (training, test) (308, 73)  At (gamma, c):  [ 4.86753533  5.48583404]
# error of particle- 34 is (training, test) (314, 73)  At (gamma, c):  [ 3.8779099   3.89983251]
# error of particle- 35 is (training, test) (313, 66)  At (gamma, c):  [ 3.86548713  4.07145224]
# error of particle- 36 is (training, test) (315, 65)  At (gamma, c):  [ 3.41280972  4.22543754]
# error of particle- 37 is (training, test) (315, 74)  At (gamma, c):  [ 2.57892624  4.86304164]
# error of particle- 38 is (training, test) (313, 54)  At (gamma, c):  [ 2.40967094  4.0104856 ]
# error of particle- 39 is (training, test) (316, 67)  At (gamma, c):  [ 2.00829921  4.23429283]
# error of particle- 40 is (training, test) (314, 65)  At (gamma, c):  [ 3.87976355  4.57732717]
# error of particle- 41 is (training, test) (316, 60)  At (gamma, c):  [ 3.65379953  4.7849208 ]
# error of particle- 42 is (training, test) (310, 65)  At (gamma, c):  [ 4.12059891  3.69642238]
# error of particle- 43 is (training, test) (314, 63)  At (gamma, c):  [ 4.21722825  4.92369991]
# error of particle- 44 is (training, test) (306, 59)  At (gamma, c):  [ 3.7050676   5.62499956]
# error of particle- 45 is (training, test) (309, 58)  At (gamma, c):  [ 2.17104008  4.05979339]
# error of particle- 46 is (training, test) (312, 65)  At (gamma, c):  [ 3.24148232  5.58128632]
# error of particle- 47 is (training, test) (314, 74)  At (gamma, c):  [ 3.92173571  4.20222267]
# error of particle- 48 is (training, test) (318, 62)  At (gamma, c):  [ 4.35457779  4.66331341]
# error of particle- 49 is (training, test) (310, 74)  At (gamma, c):  [ 4.93028521  3.58169959]
# error of particle- 50 is (training, test) (314, 60)  At (gamma, c):  [ 1.56230675  3.47043921]
# error of particle- 51 is (training, test) (320, 50)  At (gamma, c):  [ 2.48868128  3.98494179]
# error of particle- 52 is (training, test) (309, 62)  At (gamma, c):  [ 3.64870509  5.31610329]
# error of particle- 53 is (training, test) (308, 62)  At (gamma, c):  [ 2.96585312  5.09435661]
# error of particle- 54 is (training, test) (308, 63)  At (gamma, c):  [ 3.54659845  3.94098044]
# error of particle- 55 is (training, test) (308, 62)  At (gamma, c):  [ 2.71029457  5.84236446]
# error of particle- 56 is (training, test) (320, 59)  At (gamma, c):  [ 4.08525434  5.0125604 ]
# error of particle- 57 is (training, test) (318, 65)  At (gamma, c):  [ 3.35542334  5.12037032]
# error of particle- 58 is (training, test) (312, 74)  At (gamma, c):  [ 5.06822987  4.19454437]
# error of particle- 59 is (training, test) (325, 69)  At (gamma, c):  [ 2.55120047  4.56089352]
# error of particle- 60 is (training, test) (312, 72)  At (gamma, c):  [ 3.92197545  4.48936042]
# error of particle- 61 is (training, test) (315, 74)  At (gamma, c):  [ 3.92511919  5.88446659]
# error of particle- 62 is (training, test) (319, 71)  At (gamma, c):  [ 3.28990246  5.94696436]
# error of particle- 63 is (training, test) (310, 72)  At (gamma, c):  [ 5.06997628  6.04304438]
# error of particle- 64 is (training, test) (315, 72)  At (gamma, c):  [ 3.7622314   2.99553651]
# error of particle- 65 is (training, test) (300, 57)  At (gamma, c):  [ 3.73156234  4.63843593]
# error of particle- 66 is (training, test) (320, 62)  At (gamma, c):  [ 3.09150737  6.03108148]
# error of particle- 67 is (training, test) (308, 72)  At (gamma, c):  [ 4.69610294  6.38494348]
# error of particle- 68 is (training, test) (324, 65)  At (gamma, c):  [ 3.04813533  3.55317909]
# error of particle- 69 is (training, test) (309, 74)  At (gamma, c):  [ 4.72906126  5.69559638]
# error of particle- 70 is (training, test) (321, 56)  At (gamma, c):  [ 4.03404906  5.75823705]
# error of particle- 71 is (training, test) (318, 61)  At (gamma, c):  [ 3.45443711  3.79573854]
# error of particle- 72 is (training, test) (314, 70)  At (gamma, c):  [ 5.12898594  7.74072874]
# error of particle- 73 is (training, test) (296, 71)  At (gamma, c):  [ 5.49202992  5.79385972]
# error of particle- 74 is (training, test) (317, 65)  At (gamma, c):  [ 3.00940624  3.28691163]
# error of particle- 75 is (training, test) (306, 68)  At (gamma, c):  [ 3.54737999  5.32124819]
# error of particle- 76 is (training, test) (319, 71)  At (gamma, c):  [ 2.50640264  6.04691926]
# error of particle- 77 is (training, test) (314, 64)  At (gamma, c):  [ 3.30102269  5.21111592]
# error of particle- 78 is (training, test) (314, 63)  At (gamma, c):  [ 4.51148363  3.78328534]
# error of particle- 79 is (training, test) (312, 55)  At (gamma, c):  [ 2.16276527  3.14522284]
# error of particle- 80 is (training, test) (316, 73)  At (gamma, c):  [ 3.41869438  4.07580317]
# error of particle- 81 is (training, test) (324, 73)  At (gamma, c):  [ 2.56385768  4.69565053]
# error of particle- 82 is (training, test) (309, 65)  At (gamma, c):  [ 3.34761574  4.53972038]
# error of particle- 83 is (training, test) (310, 63)  At (gamma, c):  [ 3.37482312  4.9372842 ]
# error of particle- 84 is (training, test) (317, 62)  At (gamma, c):  [ 3.71942459  4.35799664]
# error of particle- 85 is (training, test) (314, 64)  At (gamma, c):  [ 4.39521276  3.52515671]
# error of particle- 86 is (training, test) (316, 66)  At (gamma, c):  [ 3.18923054  3.85638455]
# error of particle- 87 is (training, test) (315, 66)  At (gamma, c):  [ 3.84426914  3.31244232]
# error of particle- 88 is (training, test) (309, 66)  At (gamma, c):  [ 4.32206901  3.79599582]
# error of particle- 89 is (training, test) (321, 69)  At (gamma, c):  [ 3.99149448  3.04971366]
# error of particle- 90 is (training, test) (310, 54)  At (gamma, c):  [ 2.32416663  2.50906663]
# error of particle- 91 is (training, test) (306, 68)  At (gamma, c):  [ 3.54476464  5.39642998]
# error of particle- 92 is (training, test) (316, 66)  At (gamma, c):  [ 3.19561207  3.80130188]
# error of particle- 93 is (training, test) (317, 72)  At (gamma, c):  [ 2.58974066  7.06733353]
# error of particle- 94 is (training, test) (325, 65)  At (gamma, c):  [ 1.06737752  6.23767306]
# error of particle- 95 is (training, test) (320, 68)  At (gamma, c):  [ 3.25544105  2.90749171]
# error of particle- 96 is (training, test) (310, 59)  At (gamma, c):  [ 4.08155888  3.81957703]
# error of particle- 97 is (training, test) (317, 65)  At (gamma, c):  [ 3.0574525   4.98704004]
# error of particle- 98 is (training, test) (316, 62)  At (gamma, c):  [ 4.1268377  4.6317201]
# error of particle- 99 is (training, test) (318, 65)  At (gamma, c):  [ 2.65075089  3.85792336]
# error of particle- 0 is (training, test) (325, 57)  At (gamma, c):  [ 3.66663629  4.01433824]
# error of particle- 1 is (training, test) (314, 59)  At (gamma, c):  [ 2.87121583  6.01333573]
# error of particle- 2 is (training, test) (315, 70)  At (gamma, c):  [ 3.74186227  2.91755195]
# error of particle- 3 is (training, test) (307, 62)  At (gamma, c):  [ 3.31016739  3.49452879]
# error of particle- 4 is (training, test) (311, 63)  At (gamma, c):  [ 4.32081462  3.17116053]
# ...
# error of particle- 33 is (training, test) (316, 57)  At (gamma, c):  [ 3.10305234  4.3725674 ]
# error of particle- 34 is (training, test) (302, 67)  At (gamma, c):  [ 2.72764241  3.97030215]
# error of particle- 35 is (training, test) (310, 60)  At (gamma, c):  [ 2.86016905  4.00828392]
# error of particle- 36 is (training, test) (318, 66)  At (gamma, c):  [ 2.718516    4.04475412]
# error of particle- 37 is (training, test) (313, 77)  At (gamma, c):  [ 2.50979921  4.19042309]
# error of particle- 38 is (training, test) (307, 53)  At (gamma, c):  [ 2.44739912  3.99828819]
# error of particle- 39 is (training, test) (318, 62)  At (gamma, c):  [ 2.35568871  4.053974  ]
# error of particle- 40 is (training, test) (314, 67)  At (gamma, c):  [ 2.65461972  4.05560584]
# error of particle- 41 is (training, test) (315, 58)  At (gamma, c):  [ 2.71663831  4.14145882]
# error of particle- 42 is (training, test) (313, 61)  At (gamma, c):  [ 2.9644506   3.90082683]
# error of particle- 43 is (training, test) (302, 59)  At (gamma, c):  [ 2.93616865  4.22796811]
# error of particle- 44 is (training, test) (311, 66)  At (gamma, c):  [ 2.74508743  4.33065507]
# error of particle- 45 is (training, test) (310, 57)  At (gamma, c):  [ 2.41497938  4.00230951]
# error of particle- 46 is (training, test) (329, 64)  At (gamma, c):  [ 2.60454257  4.23063027]
# error of particle- 47 is (training, test) (313, 59)  At (gamma, c):  [ 3.04236959  4.06889246]
# error of particle- 48 is (training, test) (311, 65)  At (gamma, c):  [ 3.1518365   4.22604074]
# error of particle- 49 is (training, test) (317, 73)  At (gamma, c):  [ 3.89112847  3.75332114]
# error of particle- 50 is (training, test) (310, 70)  At (gamma, c):  [ 1.97769638  3.70114399]
# error of particle- 51 is (training, test) (320, 50)  At (gamma, c):  [ 2.48868128  3.98494179]
# error of particle- 52 is (training, test) (310, 59)  At (gamma, c):  [ 2.87812739  4.43184267]
# error of particle- 53 is (training, test) (316, 60)  At (gamma, c):  [ 2.6236577   4.29875923]
# error of particle- 54 is (training, test) (309, 60)  At (gamma, c):  [ 2.8079817   3.97167338]
# error of particle- 55 is (training, test) (325, 69)  At (gamma, c):  [ 2.55270785  4.52157208]
# error of particle- 56 is (training, test) (310, 61)  At (gamma, c):  [ 2.9899871   4.30760237]
# error of particle- 57 is (training, test) (316, 60)  At (gamma, c):  [ 2.62680191  4.16587925]
# error of particle- 58 is (training, test) (313, 62)  At (gamma, c):  [ 3.02044662  4.02815066]
# error of particle- 59 is (training, test) (316, 75)  At (gamma, c):  [ 2.50211063  4.1086583 ]
# error of particle- 60 is (training, test) (310, 63)  At (gamma, c):  [ 2.75477305  4.07858736]
# error of particle- 61 is (training, test) (306, 59)  At (gamma, c):  [ 2.88771813  4.51262237]
# error of particle- 62 is (training, test) (316, 60)  At (gamma, c):  [ 2.61981364  4.30605742]
# error of particle- 63 is (training, test) (320, 66)  At (gamma, c):  [ 3.01392743  4.40372789]
# error of particle- 64 is (training, test) (316, 65)  At (gamma, c):  [ 3.0286874   3.56541774]
# error of particle- 65 is (training, test) (317, 65)  At (gamma, c):  [ 3.06032211  4.28550468]
# error of particle- 66 is (training, test) (312, 77)  At (gamma, c):  [ 2.5974622   4.35417095]
# error of particle- 67 is (training, test) (313, 74)  At (gamma, c):  [ 3.296161    4.86286771]
# error of particle- 68 is (training, test) (318, 65)  At (gamma, c):  [ 2.65572276  3.85602632]
# error of particle- 69 is (training, test) (315, 74)  At (gamma, c):  [ 3.95969971  5.10814609]
# error of particle- 70 is (training, test) (314, 62)  At (gamma, c):  [ 2.85710579  4.40770552]
# error of particle- 71 is (training, test) (308, 60)  At (gamma, c):  [ 2.83764788  3.91657501]
# error of particle- 72 is (training, test) (314, 63)  At (gamma, c):  [ 3.04471978  4.77589678]
# error of particle- 73 is (training, test) (317, 66)  At (gamma, c):  [ 3.32669281  4.48967643]
# error of particle- 74 is (training, test) (316, 75)  At (gamma, c):  [ 2.58618692  3.85423578]
# error of particle- 75 is (training, test) (311, 66)  At (gamma, c):  [ 2.74181962  4.30445704]
# error of particle- 76 is (training, test) (304, 55)  At (gamma, c):  [ 2.49317929  4.50831007]
# error of particle- 77 is (training, test) (302, 67)  At (gamma, c):  [ 2.72849407  4.3469229 ]
# error of particle- 78 is (training, test) (308, 66)  At (gamma, c):  [ 3.12728118  3.92127873]
# error of particle- 79 is (training, test) (310, 61)  At (gamma, c):  [ 2.42913017  3.83150904]
# error of particle- 80 is (training, test) (310, 59)  At (gamma, c):  [ 2.87041215  4.02223653]
# error of particle- 81 is (training, test) (312, 73)  At (gamma, c):  [ 2.52936926  4.36960112]
# error of particle- 82 is (training, test) (314, 67)  At (gamma, c):  [ 2.65131203  4.08998364]
# error of particle- 83 is (training, test) (315, 59)  At (gamma, c):  [ 2.96183091  4.49343878]
# error of particle- 84 is (training, test) (311, 57)  At (gamma, c):  [ 2.96601256  4.12962732]
# error of particle- 85 is (training, test) (314, 67)  At (gamma, c):  [ 3.15688827  3.82379491]
# error of particle- 86 is (training, test) (317, 63)  At (gamma, c):  [ 2.69908233  3.94633126]
# error of particle- 87 is (training, test) (311, 61)  At (gamma, c):  [ 2.80640981  3.82731846]
# error of particle- 88 is (training, test) (314, 60)  At (gamma, c):  [ 3.20899579  3.91070734]
# error of particle- 89 is (training, test) (306, 59)  At (gamma, c):  [ 2.90028944  3.72879051]
# error of particle- 90 is (training, test) (321, 61)  At (gamma, c):  [ 2.4407559   3.55499909]
# error of particle- 91 is (training, test) (316, 67)  At (gamma, c):  [ 2.69563588  4.26154304]
# error of particle- 92 is (training, test) (316, 56)  At (gamma, c):  [ 2.76552516  3.91302586]
# error of particle- 93 is (training, test) (313, 77)  At (gamma, c):  [ 2.50834042  4.58456135]
# error of particle- 94 is (training, test) (314, 56)  At (gamma, c):  [ 2.15491699  4.51394993]
# error of particle- 95 is (training, test) (316, 76)  At (gamma, c):  [ 2.597008    3.83272119]
# error of particle- 96 is (training, test) (316, 56)  At (gamma, c):  [ 2.76051367  3.95672148]
# error of particle- 97 is (training, test) (302, 67)  At (gamma, c):  [ 2.72796267  4.40652336]
# error of particle- 98 is (training, test) (310, 64)  At (gamma, c):  [ 3.18534679  4.25999986]
# error of particle- 99 is (training, test) (316, 76)  At (gamma, c):  [ 2.59469766  3.90185383]
# error of particle- 0 is (training, test) (310, 58)  At (gamma, c):  [ 3.08623742  3.9998541 ]
# error of particle- 1 is (training, test) (316, 76)  At (gamma, c):  [ 2.58057366  4.47220225]
# error of particle- 2 is (training, test) (314, 66)  At (gamma, c):  [ 3.15004008  3.42163317]
# error of particle- 3 is (training, test) (320, 53)  At (gamma, c):  [ 2.79051815  3.8047504 ]
# error of particle- 4 is (training, test) (313, 62)  At (gamma, c):  [ 3.01602424  3.75071112]
# error of particle- 5 is (training, test) (325, 68)  At (gamma, c):  [ 2.55761146  4.25115326]
# error of particle- 6 is (training, test) (312, 59)  At (gamma, c):  [ 3.47775417  4.60009596]
# error of particle- 7 is (training, test) (321, 66)  At (gamma, c):  [ 2.36582588  4.54976543]
# error of particle- 8 is (training, test) (318, 65)  At (gamma, c):  [ 2.65372644  3.9475661 ]
# error of particle- 9 is (training, test) (312, 69)  At (gamma, c):  [ 2.64663235  3.99550148]
# error of particle- 10 is (training, test) (316, 76)  At (gamma, c):  [ 2.58797939  3.95084711]
# error of particle- 11 is (training, test) (314, 60)  At (gamma, c):  [ 3.20680279  4.61907874]
# error of particle- 12 is (training, test) (313, 58)  At (gamma, c):  [ 2.91778629  4.07338042]
# error of particle- 13 is (training, test) (306, 59)  At (gamma, c):  [ 2.89743736  4.66927198]
# error of particle- 14 is (training, test) (307, 53)  At (gamma, c):  [ 2.44779234  4.03333743]
# error of particle- 15 is (training, test) (310, 63)  At (gamma, c):  [ 2.75357481  4.1043553 ]
# error of particle- 16 is (training, test) (314, 61)  At (gamma, c):  [ 2.8511156   3.94332517]
# error of particle- 17 is (training, test) (319, 58)  At (gamma, c):  [ 2.77471361  4.11334444]
# error of particle- 18 is (training, test) (310, 59)  At (gamma, c):  [ 2.87369819  4.25164834]
# error of particle- 19 is (training, test) (316, 67)  At (gamma, c):  [ 2.69546384  3.85432451]
# error of particle- 20 is (training, test) (317, 58)  At (gamma, c):  [ 2.46320344  4.17055211]
# error of particle- 21 is (training, test) (317, 63)  At (gamma, c):  [ 2.69931189  3.93739242]
# error of particle- 22 is (training, test) (305, 57)  At (gamma, c):  [ 4.02692564  5.29322293]
# error of particle- 23 is (training, test) (316, 64)  At (gamma, c):  [ 2.57223334  4.12282309]
# error of particle- 24 is (training, test) (317, 65)  At (gamma, c):  [ 3.06315704  4.93870874]
# error of particle- 25 is (training, test) (309, 65)  At (gamma, c):  [ 2.70348741  4.14274704]
# error of particle- 26 is (training, test) (329, 64)  At (gamma, c):  [ 2.60611412  4.18116654]
# error of particle- 27 is (training, test) (310, 63)  At (gamma, c):  [ 3.25844069  5.25554861]
# error of particle- 28 is (training, test) (316, 56)  At (gamma, c):  [ 2.75834458  3.87803932]
# error of particle- 29 is (training, test) (313, 56)  At (gamma, c):  [ 2.34978185  4.17765954]
# error of particle- 30 is (training, test) (310, 64)  At (gamma, c):  [ 2.37103684  4.09295104]
# error of particle- 31 is (training, test) (319, 65)  At (gamma, c):  [ 3.10543392  4.26610968]
# error of particle- 32 is (training, test) (314, 58)  At (gamma, c):  [ 2.47850329  4.10694532]
# error of particle- 33 is (training, test) (313, 58)  At (gamma, c):  [ 2.90573711  4.24807515]
# error of particle- 34 is (training, test) (313, 64)  At (gamma, c):  [ 2.71781635  3.97090413]
# error of particle- 35 is (training, test) (316, 56)  At (gamma, c):  [ 2.76576102  4.00235187]
# error of particle- 36 is (training, test) (309, 65)  At (gamma, c):  [ 2.70274954  4.04065105]
# error of particle- 37 is (training, test) (316, 75)  At (gamma, c):  [ 2.50224703  4.116939  ]
# error of particle- 38 is (training, test) (319, 55)  At (gamma, c):  [ 2.46757745  3.99176459]
# error of particle- 39 is (training, test) (315, 55)  At (gamma, c):  [ 2.37956961  4.04157818]
# error of particle- 40 is (training, test) (314, 67)  At (gamma, c):  [ 2.65390917  4.05530326]
# error of particle- 41 is (training, test) (309, 66)  At (gamma, c):  [ 2.71178541  4.13812677]
# error of particle- 42 is (training, test) (316, 56)  At (gamma, c):  [ 2.76049072  3.93688648]
# error of particle- 43 is (training, test) (308, 64)  At (gamma, c):  [ 2.74786972  4.12570467]
# error of particle- 44 is (training, test) (301, 63)  At (gamma, c):  [ 2.7193752   4.29598718]
# error of particle- 45 is (training, test) (311, 58)  At (gamma, c):  [ 2.43752482  3.99699672]
# error of particle- 46 is (training, test) (321, 68)  At (gamma, c):  [ 2.56619061  4.1493034 ]
# error of particle- 47 is (training, test) (313, 62)  At (gamma, c):  [ 3.02157211  4.06573913]
# error of particle- 48 is (training, test) (306, 59)  At (gamma, c):  [ 2.90073968  4.13475113]
# error of particle- 49 is (training, test) (312, 63)  At (gamma, c):  [ 3.61391939  3.7991035 ]
# error of particle- 50 is (training, test) (310, 59)  At (gamma, c):  [ 2.1028561   3.77065692]
# error of particle- 51 is (training, test) (320, 50)  At (gamma, c):  [ 2.48868128  3.98494179]
# error of particle- 52 is (training, test) (314, 62)  At (gamma, c):  [ 2.85779908  4.40851535]
# error of particle- 53 is (training, test) (321, 68)  At (gamma, c):  [ 2.56179091  4.15492019]
# error of particle- 54 is (training, test) (316, 62)  At (gamma, c):  [ 2.66808312  3.97748681]
# error of particle- 55 is (training, test) (322, 79)  At (gamma, c):  [ 2.52341238  4.27603599]
# error of particle- 56 is (training, test) (310, 61)  At (gamma, c):  [ 2.98657464  4.30540598]
# error of particle- 57 is (training, test) (319, 65)  At (gamma, c):  [ 2.56941878  4.09070759]
# error of particle- 58 is (training, test) (315, 62)  At (gamma, c):  [ 2.81562948  4.01150814]
# error of particle- 59 is (training, test) (308, 59)  At (gamma, c):  [ 2.49921028  4.08193915]
# error of particle- 60 is (training, test) (318, 74)  At (gamma, c):  [ 2.67094098  4.04908437]
# error of particle- 61 is (training, test) (307, 57)  At (gamma, c):  [ 2.81972686  4.4227117 ]
# error of particle- 62 is (training, test) (321, 67)  At (gamma, c):  [ 2.5552967   4.14806898]
# error of particle- 63 is (training, test) (315, 60)  At (gamma, c):  [ 2.8596633   4.28073094]
# error of particle- 64 is (training, test) (320, 64)  At (gamma, c):  [ 2.95323707  3.62403416]
# error of particle- 65 is (training, test) (313, 62)  At (gamma, c):  [ 3.02500343  4.26693449]
# error of particle- 66 is (training, test) (325, 68)  At (gamma, c):  [ 2.55274026  4.20237369]
# error of particle- 67 is (training, test) (316, 69)  At (gamma, c):  [ 3.12773639  4.67974938]
# error of particle- 68 is (training, test) (315, 64)  At (gamma, c):  [ 2.6107287   3.89075081]
# error of particle- 69 is (training, test) (313, 66)  At (gamma, c):  [ 3.86240996  5.03385997]
# error of particle- 70 is (training, test) (315, 53)  At (gamma, c):  [ 2.76654658  4.30378966]
# error of particle- 71 is (training, test) (307, 67)  At (gamma, c):  [ 2.7454554   3.93463663]
# error of particle- 72 is (training, test) (314, 62)  At (gamma, c):  [ 3.02872464  4.75314398]
# error of particle- 73 is (training, test) (310, 64)  At (gamma, c):  [ 3.17959712  4.40108064]
# error of particle- 74 is (training, test) (321, 67)  At (gamma, c):  [ 2.56207449  3.88655842]
# error of particle- 75 is (training, test) (312, 69)  At (gamma, c):  [ 2.6404401  4.1764942]
# error of particle- 76 is (training, test) (310, 57)  At (gamma, c):  [ 2.49170097  4.33629985]
# error of particle- 77 is (training, test) (316, 67)  At (gamma, c):  [ 2.69312428  4.2935346 ]
# error of particle- 78 is (training, test) (317, 65)  At (gamma, c):  [ 3.01324718  3.93264696]
# error of particle- 79 is (training, test) (311, 58)  At (gamma, c):  [ 2.43559916  3.8481763 ]
# error of particle- 80 is (training, test) (308, 64)  At (gamma, c):  [ 2.74157801  4.00964956]
# error of particle- 81 is (training, test) (314, 75)  At (gamma, c):  [ 2.52696617  4.34688257]
# error of particle- 82 is (training, test) (314, 64)  At (gamma, c):  [ 2.637718    4.08120336]
# error of particle- 83 is (training, test) (310, 58)  At (gamma, c):  [ 2.87309586  4.39807465]
# error of particle- 84 is (training, test) (314, 62)  At (gamma, c):  [ 2.85607112  4.09630259]
# error of particle- 85 is (training, test) (306, 59)  At (gamma, c):  [ 2.88123885  3.89027138]
# error of particle- 86 is (training, test) (316, 60)  At (gamma, c):  [ 2.6248952   3.95994528]
# error of particle- 87 is (training, test) (318, 65)  At (gamma, c):  [ 2.64895628  3.90543027]
# error of particle- 88 is (training, test) (313, 59)  At (gamma, c):  [ 2.98012945  3.93429394]
# error of particle- 89 is (training, test) (304, 65)  At (gamma, c):  [ 2.77620917  3.80600793]
# error of particle- 90 is (training, test) (320, 63)  At (gamma, c):  [ 2.44254775  3.57107394]
# error of particle- 91 is (training, test) (316, 60)  At (gamma, c):  [ 2.60783904  4.14419983]
# error of particle- 92 is (training, test) (317, 62)  At (gamma, c):  [ 2.63386889  3.9472263 ]
# error of particle- 93 is (training, test) (313, 77)  At (gamma, c):  [ 2.507202    4.54983859]
# error of particle- 94 is (training, test) (314, 56)  At (gamma, c):  [ 2.15601131  4.51221545]
# error of particle- 95 is (training, test) (316, 76)  At (gamma, c):  [ 2.59460329  3.83610028]
# error of particle- 96 is (training, test) (316, 62)  At (gamma, c):  [ 2.66425816  3.96671426]
# error of particle- 97 is (training, test) (302, 67)  At (gamma, c):  [ 2.72401164  4.39956217]
# error of particle- 98 is (training, test) (313, 62)  At (gamma, c):  [ 3.03362081  4.20009528]
# error of particle- 99 is (training, test) (319, 65)  At (gamma, c):  [ 2.56932774  3.92173693]
# The best position is  [ 2.48868128  3.98494179] in iteration number 10 with error (train, test): (320, 50)

# %%
svclassifier = SVC(kernel='rbf', gamma = 0.18756271, C = 1.08487502)  
svclassifier.fit(X_train, y_train)
y_train_pred = svclassifier.predict(X_train)
y_test_pred = svclassifier.p0
redict(X_test)
confusion_matrix(y_train,y_train_pred)[0][1] + confusion_matrix(y_train,y_train_pred)[1][0]
# Out:
# 18
