# %%
import pandas as pd
import numpy as np
import math
import random
import csv
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix  
import matplotlib.pyplot as plt

# %%
url = "D:\\TUGAS AKHIR\\Data TA\\Australian fraud dataset\\australian.csv"
colnames = ['x1', 'x2', 'x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13','x14', 'y']
data = pd.read_csv(url, header = None, names = colnames)
X = data.drop('y', axis = 1)
X = (X-X.mean())/X.std()
y = data['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
#################### I N P U T ####################
#berdasarkan buku
#khi = 0.729
#c1 = 2.05
#c2 = 2.05

#berdasarkan paper
K = 0.3
c1 = 2
c2 = 5
c = c1+ c2
khi = 2*K/(abs(2-c-math.sqrt(c**2-4*c)))
n_iterations = int(input("Inform the number of iterations: "))
n_particles = int(input("Inform the number of particles: "))
# Out:
# Inform the number of iterations: 10
# Inform the number of particles: 100

# %%
#mencari nilai 0-1 loss dari tiap partikel
#partikle = (gamma,C) untuk rbf
def fitness_function(position):
    svclassifier = SVC(kernel='poly', gamma = position[0], C = position[1] )  
    svclassifier.fit(X_train, y_train)
    y_train_pred = svclassifier.predict(X_train)
    y_test_pred = svclassifier.predict(X_test)   
    return (confusion_matrix(y_train,y_train_pred)[0][1] + confusion_matrix(y_train,y_train_pred)[1][0])/np.sum(confusion_matrix(y_train,y_train_pred)), (confusion_matrix(y_test,y_test_pred)[0][1] + confusion_matrix(y_test,y_test_pred)[1][0])/np.sum(confusion_matrix(y_test,y_test_pred))

#plotting (x axis = gamma, y axis = C)
def plot(position):
    x = []
    y = []
    for i in range(0,len(particle_position_vector)):
        x.append(particle_position_vector[i][0])
        y.append(particle_position_vector[i][1])
    colors = (0,0,0)
    plt.scatter(x, y, c = colors, alpha = 0.1)
    plt.xlabel('gamma')
    plt.ylabel('C')
    plt.axis([0,9,0,10])
    plt.gca().set_aspect('equal', adjustable='box')
    return plt.show()

# %%
particle_position_vector = np.array([np.array([random.randint(1,8), random.random()*10]) for _ in range(n_particles)])
pbest_position = particle_position_vector
pbest_fitness_value = np.array([float('inf') for _ in range(n_particles)])
gbest_fitness_value = np.array([float('inf'), float('inf')])
gbest_position = np.array([float('inf'), float('inf')])

velocity_vector = ([np.array([0, 0]) for _ in range(n_particles)])
iteration = 0
while iteration < n_iterations:
    plot(particle_position_vector)
    for i in range(n_particles):
        fitness_cadidate = fitness_function(particle_position_vector[i])
        print("error of particle-",i+1,"is (training, test)", fitness_cadidate, " At (gamma, c): ", particle_position_vector[i])
        
        if(pbest_fitness_value[i] > fitness_cadidate[1]):
            pbest_fitness_value[i] = fitness_cadidate[1]
            pbest_position[i] = particle_position_vector[i]

        if(gbest_fitness_value[1] > fitness_cadidate[1]):
            gbest_fitness_value = fitness_cadidate
            gbest_position = particle_position_vector[i]
        elif(gbest_fitness_value[1] == fitness_cadidate[1] and gbest_fitness_value[0] > fitness_cadidate[0]):
            gbest_fitness_value = fitness_cadidate
            gbest_position = particle_position_vector[i]
            
    for i in range(n_particles):
        #(gamma,C)
        max_velocity = np.array([8,10])
        min_velocity = np.array([-8,-10])
        max_position = np.array([8,10])
        min_position = np.array([1, 0.001])
        new_velocity = khi*(velocity_vector[i] + (c1*random.randint(0,3)) * (pbest_position[i] - particle_position_vector[i]) + (c2*random.random()) * (gbest_position-particle_position_vector[i]))
        new_velocity[0] = np.round(new_velocity[0])
        for j in range(0,len(new_velocity)):
            if(new_velocity[j] > max_velocity[j]):
                new_velocity[j] = max_velocity[j]
            elif(new_velocity[j] < min_velocity[j]):
                new_velocity[j] = min_velocity[j]
            
        new_position = new_velocity + particle_position_vector[i]
        particle_position_vector[i] = new_position
        for j in range(0,2):
            if(particle_position_vector[i][j] > max_position[j]):
                particle_position_vector[i][j] = max_position[j]
            elif(particle_position_vector[i][j] < min_position[j]):
                particle_position_vector[i][j] = min_position[j]
    
    iteration = iteration + 1
    
print("The best position is ", gbest_position, "in iteration number", iteration, "with error rate (train, test):", fitness_function(gbest_position))
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 1 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         1.87397333]
# error of particle- 2 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.34396089]
# error of particle- 3 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         9.30589027]
# error of particle- 4 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         4.04788554]
# error of particle- 5 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         2.84241096]
# error of particle- 6 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         8.19215177]
# error of particle- 7 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         1.46037507]
# error of particle- 8 is (training, test) (0.005434782608695652, 0.2391304347826087)  At (gamma, c):  [1.         2.23014986]
# error of particle- 9 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.58219047]
# error of particle- 10 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         2.72204169]
# error of particle- 11 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [3.         1.38875233]
# error of particle- 12 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.        7.7001826]
# error of particle- 13 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         6.64378187]
# error of particle- 14 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         6.50266229]
# error of particle- 15 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         3.55669466]
# error of particle- 16 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         4.97572439]
# error of particle- 17 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.62608699]
# error of particle- 18 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         9.84211857]
# error of particle- 19 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [5.         0.50369926]
# error of particle- 20 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [1.         8.49764129]
# error of particle- 21 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.        5.6005031]
# error of particle- 22 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [1.         9.55572989]
# error of particle- 23 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         9.69846437]
# error of particle- 24 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         9.41666173]
# error of particle- 25 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         9.15830581]
# error of particle- 26 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         5.59205357]
# error of particle- 27 is (training, test) (0.005434782608695652, 0.2391304347826087)  At (gamma, c):  [1.         1.34464842]
# error of particle- 28 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         2.98488485]
# error of particle- 29 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         7.17850149]
# error of particle- 30 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [1.         8.59900208]
# error of particle- 31 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         0.82187313]
# error of particle- 32 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         2.20969214]
# error of particle- 33 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [1.         9.10880138]
# error of particle- 34 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.        4.0908212]
# error of particle- 35 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         7.81746917]
# error of particle- 36 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.43118505]
# error of particle- 37 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.78844334]
# error of particle- 38 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.46512548]
# error of particle- 39 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         7.78324219]
# error of particle- 40 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [2.         9.45267637]
# error of particle- 41 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         7.52179692]
# error of particle- 42 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         9.50196571]
# error of particle- 43 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.75884516]
# error of particle- 44 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         9.51931413]
# error of particle- 45 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         1.98770144]
# error of particle- 46 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         1.97168984]
# error of particle- 47 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         6.60124232]
# error of particle- 48 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.56082337]
# error of particle- 49 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         5.33490492]
# error of particle- 50 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [1.         8.61712952]
# error of particle- 51 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.        5.1359509]
# error of particle- 52 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         4.02740413]
# error of particle- 53 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [2.         1.95741806]
# error of particle- 54 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         9.09564993]
# error of particle- 55 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.        5.1817147]
# error of particle- 56 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         1.24863413]
# error of particle- 57 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         3.19018153]
# error of particle- 58 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [3.         1.00001407]
# error of particle- 59 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         4.74779978]
# error of particle- 60 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         8.36883044]
# error of particle- 61 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         9.85868503]
# error of particle- 62 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         9.38168856]
# error of particle- 63 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         4.94068236]
# error of particle- 64 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         0.69669981]
# error of particle- 65 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         8.53646437]
# error of particle- 66 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         9.00130802]
# error of particle- 67 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.66663819]
# error of particle- 68 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         3.07594924]
# error of particle- 69 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         2.91732082]
# error of particle- 70 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         9.19836247]
# error of particle- 71 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.58867561]
# error of particle- 72 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         7.81280168]
# error of particle- 73 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         3.24183642]
# error of particle- 74 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [5.         0.47850766]
# error of particle- 75 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.        6.4191206]
# error of particle- 76 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         8.00390158]
# error of particle- 77 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [3.         1.87707909]
# error of particle- 78 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         7.54242492]
# error of particle- 79 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.09188628]
# error of particle- 80 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         5.27842819]
# error of particle- 81 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [4.         1.05816655]
# error of particle- 82 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         8.63523611]
# error of particle- 83 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [4.         0.26071695]
# error of particle- 84 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.61796683]
# error of particle- 85 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         4.82297101]
# error of particle- 86 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         6.48854217]
# error of particle- 87 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         8.73857082]
# error of particle- 88 is (training, test) (0.0018115942028985507, 0.2608695652173913)  At (gamma, c):  [6.         0.08979198]
# error of particle- 89 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         4.01515227]
# error of particle- 90 is (training, test) (0.005434782608695652, 0.2318840579710145)  At (gamma, c):  [1.         1.61555636]
# error of particle- 91 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [3.        0.4128971]
# error of particle- 92 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         4.01538888]
# error of particle- 93 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         9.70564297]
# error of particle- 94 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         8.34070815]
# error of particle- 95 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         4.19427495]
# error of particle- 96 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         8.27850613]
# error of particle- 97 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         3.83429598]
# error of particle- 98 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         2.11150619]
# error of particle- 99 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         7.62351095]
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 100 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.        5.5942489]
# error of particle- 1 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         2.90326443]
# error of particle- 2 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.40650197]
# error of particle- 3 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         8.53331771]
# error of particle- 4 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.        4.5521587]
# error of particle- 5 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         3.41939631]
# error of particle- 6 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         8.13086127]
# error of particle- 7 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         2.36078604]
# error of particle- 8 is (training, test) (0.005434782608695652, 0.2318840579710145)  At (gamma, c):  [1.         3.14219688]
# error of particle- 9 is (training, test) (0.0018115942028985507, 0.2971014492753623)  At (gamma, c):  [2.         5.75944262]
# error of particle- 10 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         2.78494617]
# error of particle- 11 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [3.         1.96295536]
# error of particle- 12 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         7.65696241]
# error of particle- 13 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         6.63076816]
# error of particle- 14 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         6.49222794]
# error of particle- 15 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         3.59165634]
# error of particle- 16 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         5.34481672]
# error of particle- 17 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.67123219]
# error of particle- 18 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [2.         9.46514118]
# error of particle- 19 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [5.         0.75879783]
# error of particle- 20 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [1.         8.37224501]
# error of particle- 21 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.81973442]
# error of particle- 22 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [1.         8.67533505]
# error of particle- 23 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         9.65101744]
# error of particle- 24 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         9.36839804]
# error of particle- 25 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         8.80718024]
# error of particle- 26 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.        5.7922968]
# error of particle- 27 is (training, test) (0.005434782608695652, 0.2318840579710145)  At (gamma, c):  [1.         1.44462786]
# error of particle- 28 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         3.87268865]
# error of particle- 29 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         7.04757492]
# error of particle- 30 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [1.         8.57156706]
# error of particle- 31 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         1.55634033]
# error of particle- 32 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         3.03775269]
# error of particle- 33 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [1.         8.82472888]
# error of particle- 34 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         4.51790057]
# error of particle- 35 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.        7.5814024]
# error of particle- 36 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.43737039]
# error of particle- 37 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.60788149]
# error of particle- 38 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.46512548]
# error of particle- 39 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         7.72548649]
# error of particle- 40 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.65889637]
# error of particle- 41 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         7.29941972]
# error of particle- 42 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         9.50175517]
# error of particle- 43 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.75989051]
# error of particle- 44 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         9.27064473]
# error of particle- 45 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.        3.2986284]
# error of particle- 46 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         3.22756173]
# error of particle- 47 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         6.59801252]
# error of particle- 48 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.46137198]
# error of particle- 49 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.         5.39502397]
# error of particle- 50 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         8.07429842]
# error of particle- 51 is (training, test) (0.0018115942028985507, 0.2391304347826087)  At (gamma, c):  [1.         5.53935026]
# error of particle- 52 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [8.        4.1996951]
# error of particle- 53 is (training, test) (0.0018115942028985507, 0.2608695652173913)  At (gamma, c):  [2.         3.11122734]
# error of particle- 54 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         8.40247932]
# error of particle- 55 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.37130911]
# error of particle- 56 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         1.63574039]
# error of particle- 57 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         3.65112236]
# error of particle- 58 is (training, test) (0.0018115942028985507, 0.2608695652173913)  At (gamma, c):  [2.        2.5493271]
# error of particle- 59 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         4.77221774]
# error of particle- 60 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         8.00746856]
# error of particle- 61 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         9.26663972]
# error of particle- 62 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         9.31448185]
# error of particle- 63 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         5.14586695]
# error of particle- 64 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         1.39510965]
# error of particle- 65 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         8.29510189]
# error of particle- 66 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         8.24285702]
# error of particle- 67 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.        6.6621863]
# error of particle- 68 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         3.76425517]
# error of particle- 69 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         4.01338876]
# error of particle- 70 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         8.87066819]
# error of particle- 71 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.85864832]
# error of particle- 72 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.53384148]
# error of particle- 73 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         3.85984502]
# error of particle- 74 is (training, test) (0.0, 0.2826086956521739)  At (gamma, c):  [5.         1.07220063]
# error of particle- 75 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         6.42116874]
# error of particle- 76 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.65837284]
# error of particle- 77 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [2.         3.23878441]
# error of particle- 78 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         7.28885942]
# error of particle- 79 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.03853547]
# error of particle- 80 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         5.47640199]
# error of particle- 81 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         2.04841321]
# error of particle- 82 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         8.24857639]
# error of particle- 83 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [3.         1.63090482]
# error of particle- 84 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.61292189]
# error of particle- 85 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.        5.3127107]
# error of particle- 86 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.48350595]
# error of particle- 87 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         8.26151902]
# error of particle- 88 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [5.         0.79131888]
# error of particle- 89 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         4.58930713]
# error of particle- 90 is (training, test) (0.005434782608695652, 0.2391304347826087)  At (gamma, c):  [1.         2.59289881]
# error of particle- 91 is (training, test) (0.0018115942028985507, 0.2608695652173913)  At (gamma, c):  [2.         2.23722408]
# error of particle- 92 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         4.14702528]
# error of particle- 93 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         8.71217742]
# error of particle- 94 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.        8.2882401]
# error of particle- 95 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         4.83979936]
# error of particle- 96 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         8.03260413]
# error of particle- 97 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         3.95446907]
# error of particle- 98 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         2.46897979]
# error of particle- 99 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.28721443]
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 100 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.83108152]
# error of particle- 1 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         3.58740175]
# error of particle- 2 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.         5.71947678]
# error of particle- 3 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.96094627]
# error of particle- 4 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.12703414]
# error of particle- 5 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         3.73642978]
# error of particle- 6 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.93594136]
# error of particle- 7 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         3.29330979]
# error of particle- 8 is (training, test) (0.0036231884057971015, 0.2391304347826087)  At (gamma, c):  [1.         3.98554472]
# error of particle- 9 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.82191503]
# error of particle- 10 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         3.87573996]
# error of particle- 11 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         2.23302435]
# error of particle- 12 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         7.61038526]
# error of particle- 13 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         6.60035545]
# error of particle- 14 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         6.49134157]
# error of particle- 15 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         4.22886706]
# error of particle- 16 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.46119828]
# error of particle- 17 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.76563396]
# error of particle- 18 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         9.33898014]
# error of particle- 19 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [5.         1.28052564]
# error of particle- 20 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.97578579]
# error of particle- 21 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.96914209]
# error of particle- 22 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         8.12273487]
# error of particle- 23 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         9.07747943]
# error of particle- 24 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         9.05696993]
# error of particle- 25 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         8.38744437]
# error of particle- 26 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.85635289]
# error of particle- 27 is (training, test) (0.005434782608695652, 0.2318840579710145)  At (gamma, c):  [1.        1.6330971]
# error of particle- 28 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         4.61801237]
# error of particle- 29 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         6.94647522]
# error of particle- 30 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [1.         8.52675914]
# error of particle- 31 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         2.82444654]
# error of particle- 32 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         3.37435545]
# error of particle- 33 is (training, test) (0.0018115942028985507, 0.2536231884057971)  At (gamma, c):  [1.         8.36142983]
# error of particle- 34 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         4.77039981]
# error of particle- 35 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         7.43874532]
# error of particle- 36 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.44088472]
# error of particle- 37 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.27061594]
# error of particle- 38 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.46512548]
# error of particle- 39 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         7.56385402]
# error of particle- 40 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.11244947]
# error of particle- 41 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         7.13765028]
# error of particle- 42 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         9.21046686]
# error of particle- 43 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.79870157]
# error of particle- 44 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.53798599]
# error of particle- 45 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         3.38946851]
# error of particle- 46 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [3.         3.90286169]
# error of particle- 47 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         6.56746547]
# error of particle- 48 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.85543275]
# error of particle- 49 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         5.57695761]
# error of particle- 50 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.57299193]
# error of particle- 51 is (training, test) (0.0018115942028985507, 0.2391304347826087)  At (gamma, c):  [1.         5.80802778]
# error of particle- 52 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         4.53178253]
# error of particle- 53 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         3.94112193]
# error of particle- 54 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         7.95849703]
# error of particle- 55 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.46765719]
# error of particle- 56 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         1.98612761]
# error of particle- 57 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         3.74680334]
# error of particle- 58 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         3.66869074]
# error of particle- 59 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.16962146]
# error of particle- 60 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         7.55699142]
# error of particle- 61 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.56520884]
# error of particle- 62 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         8.44305783]
# error of particle- 63 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [7.         5.16064247]
# error of particle- 64 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         1.46546857]
# error of particle- 65 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         7.83804302]
# error of particle- 66 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.        7.8519478]
# error of particle- 67 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.65564178]
# error of particle- 68 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         4.17606228]
# error of particle- 69 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         4.42013567]
# error of particle- 70 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         8.38320022]
# error of particle- 71 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.90989746]
# error of particle- 72 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.40162663]
# error of particle- 73 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         4.45594574]
# error of particle- 74 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [4.         2.42433017]
# error of particle- 75 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         6.42484662]
# error of particle- 76 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.43900048]
# error of particle- 77 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         3.98700819]
# error of particle- 78 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         7.28306737]
# error of particle- 79 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         6.98058983]
# error of particle- 80 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         5.51573084]
# error of particle- 81 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.        2.6762814]
# error of particle- 82 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         8.20101716]
# error of particle- 83 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         2.72029165]
# error of particle- 84 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.21950931]
# error of particle- 85 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.40194577]
# error of particle- 86 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.48114197]
# error of particle- 87 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.        8.2091458]
# error of particle- 88 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         1.32017755]
# error of particle- 89 is (training, test) (0.0, 0.2826086956521739)  At (gamma, c):  [3.         5.16655042]
# error of particle- 90 is (training, test) (0.005434782608695652, 0.2391304347826087)  At (gamma, c):  [1.         3.20791479]
# error of particle- 91 is (training, test) (0.0018115942028985507, 0.2608695652173913)  At (gamma, c):  [2.         2.54690616]
# error of particle- 92 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         4.38494288]
# error of particle- 93 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.       8.609025]
# error of particle- 94 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         8.28137984]
# error of particle- 95 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.06823609]
# error of particle- 96 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.98928506]
# error of particle- 97 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.        4.6898305]
# error of particle- 98 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         2.91372104]
# error of particle- 99 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.        7.2714294]
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 100 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.91517762]
# error of particle- 1 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         4.24203007]
# error of particle- 2 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.         5.85773793]
# error of particle- 3 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         7.51665918]
# error of particle- 4 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.        5.5082266]
# error of particle- 5 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.        4.2416087]
# error of particle- 6 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.74624635]
# error of particle- 7 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         3.82467435]
# error of particle- 8 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         4.21515767]
# error of particle- 9 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.95867308]
# error of particle- 10 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         4.50081562]
# error of particle- 11 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         2.49706701]
# error of particle- 12 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         7.60906275]
# error of particle- 13 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         6.58275039]
# error of particle- 14 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.48495346]
# error of particle- 15 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         4.70390164]
# error of particle- 16 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.67127993]
# error of particle- 17 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.83287042]
# error of particle- 18 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.68497541]
# error of particle- 19 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         1.59752188]
# error of particle- 20 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.83373808]
# error of particle- 21 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.06567216]
# error of particle- 22 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         8.02555668]
# error of particle- 23 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         8.61814522]
# error of particle- 24 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.        8.7404805]
# error of particle- 25 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         8.30788042]
# error of particle- 26 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.96890333]
# error of particle- 27 is (training, test) (0.005434782608695652, 0.2318840579710145)  At (gamma, c):  [1.         1.68346963]
# error of particle- 28 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.00711443]
# error of particle- 29 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         6.87009818]
# error of particle- 30 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         8.25929494]
# error of particle- 31 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         3.25118269]
# error of particle- 32 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         3.54861136]
# error of particle- 33 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         8.30736617]
# error of particle- 34 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.12050111]
# error of particle- 35 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         7.29661207]
# error of particle- 36 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.44653966]
# error of particle- 37 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.06264234]
# error of particle- 38 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.46512548]
# error of particle- 39 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         7.26067971]
# error of particle- 40 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.81619004]
# error of particle- 41 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.       6.930174]
# error of particle- 42 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         8.56969027]
# error of particle- 43 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.84994706]
# error of particle- 44 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.10049955]
# error of particle- 45 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [3.         3.94838115]
# error of particle- 46 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [3.         4.21058777]
# error of particle- 47 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         6.53848847]
# error of particle- 48 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.78101527]
# error of particle- 49 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.82937545]
# error of particle- 50 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.22677769]
# error of particle- 51 is (training, test) (0.0018115942028985507, 0.2391304347826087)  At (gamma, c):  [1.         5.98245209]
# error of particle- 52 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.05258452]
# error of particle- 53 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         4.56908739]
# error of particle- 54 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.57167712]
# error of particle- 55 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.66975105]
# error of particle- 56 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.         2.55449595]
# error of particle- 57 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         4.28439402]
# error of particle- 58 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         4.36177149]
# error of particle- 59 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.43110387]
# error of particle- 60 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.24185269]
# error of particle- 61 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         8.25623667]
# error of particle- 62 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         8.38952034]
# error of particle- 63 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [6.       5.348793]
# error of particle- 64 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         2.33090463]
# error of particle- 65 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.48270975]
# error of particle- 66 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         7.79469494]
# error of particle- 67 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.65539529]
# error of particle- 68 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         4.72471836]
# error of particle- 69 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         4.61898308]
# error of particle- 70 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         7.99967497]
# error of particle- 71 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.94974305]
# error of particle- 72 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.35914453]
# error of particle- 73 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         4.84510834]
# error of particle- 74 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         3.33510036]
# error of particle- 75 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.43630011]
# error of particle- 76 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.34101627]
# error of particle- 77 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         4.03847114]
# error of particle- 78 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         7.19741424]
# error of particle- 79 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         6.95261784]
# error of particle- 80 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         5.70721497]
# error of particle- 81 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.        2.6867826]
# error of particle- 82 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.92707973]
# error of particle- 83 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [3.         2.82343393]
# error of particle- 84 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.97977481]
# error of particle- 85 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.51799631]
# error of particle- 86 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.47804382]
# error of particle- 87 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.82892627]
# error of particle- 88 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         2.61515786]
# error of particle- 89 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.53616181]
# error of particle- 90 is (training, test) (0.005434782608695652, 0.2318840579710145)  At (gamma, c):  [1.         3.58114207]
# error of particle- 91 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         3.76699881]
# error of particle- 92 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         4.82604932]
# error of particle- 93 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         8.31407095]
# error of particle- 94 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.         8.08738969]
# error of particle- 95 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.48605759]
# error of particle- 96 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.98824233]
# error of particle- 97 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.04854458]
# error of particle- 98 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [5.        3.8937076]
# error of particle- 99 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.15090885]
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 100 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.93670883]
# error of particle- 1 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [3.         4.70994198]
# error of particle- 2 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.        5.8986772]
# ...
# error of particle- 74 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.07165911]
# error of particle- 75 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.45410918]
# error of particle- 76 is (training, test) (0.0018115942028985507, 0.2391304347826087)  At (gamma, c):  [1.         6.75205904]
# error of particle- 77 is (training, test) (0.0018115942028985507, 0.2971014492753623)  At (gamma, c):  [2.         5.64595484]
# error of particle- 78 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.72275781]
# error of particle- 79 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.69266332]
# error of particle- 80 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.18657408]
# error of particle- 81 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         4.86152465]
# error of particle- 82 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.57895963]
# error of particle- 83 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [3.         4.90765903]
# error of particle- 84 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.16757301]
# error of particle- 85 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.08335007]
# error of particle- 86 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.47016659]
# error of particle- 87 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         7.32438431]
# error of particle- 88 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [3.         4.34903587]
# error of particle- 89 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.03296513]
# error of particle- 90 is (training, test) (0.0018115942028985507, 0.2391304347826087)  At (gamma, c):  [1.         5.50604777]
# error of particle- 91 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.27367788]
# error of particle- 92 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         5.68844312]
# error of particle- 93 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         6.99817703]
# error of particle- 94 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.30305782]
# error of particle- 95 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.14769782]
# error of particle- 96 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         6.97605936]
# error of particle- 97 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.         5.70638055]
# error of particle- 98 is (training, test) (0.0, 0.2826086956521739)  At (gamma, c):  [3.         5.42664644]
# error of particle- 99 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.70958786]
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 100 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.12040879]
# error of particle- 1 is (training, test) (0.0018115942028985507, 0.2971014492753623)  At (gamma, c):  [2.         5.70029507]
# error of particle- 2 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.12304495]
# error of particle- 3 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.74222646]
# error of particle- 4 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.14310992]
# error of particle- 5 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.         5.50702416]
# error of particle- 6 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.98504127]
# error of particle- 7 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.38799044]
# error of particle- 8 is (training, test) (0.0018115942028985507, 0.2391304347826087)  At (gamma, c):  [1.         5.40759306]
# error of particle- 9 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.27924219]
# error of particle- 10 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.36288852]
# error of particle- 11 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.27246623]
# error of particle- 12 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.76196844]
# error of particle- 13 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.51165374]
# error of particle- 14 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.47629815]
# error of particle- 15 is (training, test) (0.0018115942028985507, 0.2971014492753623)  At (gamma, c):  [2.         5.65101177]
# error of particle- 16 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.15517339]
# error of particle- 17 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.        6.1186827]
# error of particle- 18 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.26792168]
# error of particle- 19 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         4.43310699]
# error of particle- 20 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.04666594]
# error of particle- 21 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.38201049]
# error of particle- 22 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.06624545]
# error of particle- 23 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.12505452]
# error of particle- 24 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         7.36822332]
# error of particle- 25 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.        7.0360015]
# error of particle- 26 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.27055008]
# error of particle- 27 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         4.42746959]
# error of particle- 28 is (training, test) (0.0018115942028985507, 0.2971014492753623)  At (gamma, c):  [2.         5.71797095]
# error of particle- 29 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.58344324]
# error of particle- 30 is (training, test) (0.0018115942028985507, 0.2391304347826087)  At (gamma, c):  [1.         6.90741435]
# error of particle- 31 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [3.         4.72839664]
# error of particle- 32 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.         5.44989096]
# error of particle- 33 is (training, test) (0.0018115942028985507, 0.2463768115942029)  At (gamma, c):  [1.         7.42609847]
# error of particle- 34 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.94250945]
# error of particle- 35 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         6.80989401]
# error of particle- 36 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.46089517]
# error of particle- 37 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.56721104]
# error of particle- 38 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.46512548]
# error of particle- 39 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.        6.7826881]
# error of particle- 40 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         6.85009626]
# error of particle- 41 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.        6.5586285]
# error of particle- 42 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.08093677]
# error of particle- 43 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.15414392]
# error of particle- 44 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.08182903]
# error of particle- 45 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.         5.65607014]
# error of particle- 46 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.87574587]
# error of particle- 47 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.48497311]
# error of particle- 48 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         6.82330623]
# error of particle- 49 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.25319983]
# error of particle- 50 is (training, test) (0.0018115942028985507, 0.2391304347826087)  At (gamma, c):  [1.         6.76442196]
# error of particle- 51 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.29075857]
# error of particle- 52 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.         5.92214954]
# error of particle- 53 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.92467256]
# error of particle- 54 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.83150486]
# error of particle- 55 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.27561789]
# error of particle- 56 is (training, test) (0.0, 0.2826086956521739)  At (gamma, c):  [3.         5.11626467]
# error of particle- 57 is (training, test) (0.0018115942028985507, 0.2971014492753623)  At (gamma, c):  [2.         5.76042369]
# error of particle- 58 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.07997912]
# error of particle- 59 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.21388389]
# error of particle- 60 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.63691292]
# error of particle- 61 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.00659159]
# error of particle- 62 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         7.22048402]
# error of particle- 63 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.06018608]
# error of particle- 64 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         4.88222207]
# error of particle- 65 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.71283789]
# error of particle- 66 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.93461309]
# error of particle- 67 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.52419809]
# error of particle- 68 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.         5.84249342]
# error of particle- 69 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.         5.89123694]
# error of particle- 70 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.11614614]
# error of particle- 71 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.30794409]
# error of particle- 72 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.       6.835106]
# error of particle- 73 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.90729503]
# error of particle- 74 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.32646018]
# error of particle- 75 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.45685071]
# error of particle- 76 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.         6.68165893]
# error of particle- 77 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.80766326]
# error of particle- 78 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.68009127]
# error of particle- 79 is (training, test) (0.0018115942028985507, 0.2318840579710145)  At (gamma, c):  [1.        6.6537574]
# error of particle- 80 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.        6.2052946]
# error of particle- 81 is (training, test) (0.0, 0.2826086956521739)  At (gamma, c):  [3.         5.23720218]
# error of particle- 82 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [4.         7.55156735]
# error of particle- 83 is (training, test) (0.0, 0.2826086956521739)  At (gamma, c):  [3.         5.28410672]
# error of particle- 84 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         7.05572539]
# error of particle- 85 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.18254204]
# error of particle- 86 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.46969296]
# error of particle- 87 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.        7.0668405]
# error of particle- 88 is (training, test) (0.0018115942028985507, 0.2753623188405797)  At (gamma, c):  [3.         4.69215626]
# error of particle- 89 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.10937704]
# error of particle- 90 is (training, test) (0.0018115942028985507, 0.2391304347826087)  At (gamma, c):  [1.         5.70089031]
# error of particle- 91 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.31796969]
# error of particle- 92 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.         5.93069437]
# error of particle- 93 is (training, test) (0.0018115942028985507, 0.2826086956521739)  At (gamma, c):  [2.         6.91600828]
# error of particle- 94 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         7.06450811]
# error of particle- 95 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         6.16442236]
# error of particle- 96 is (training, test) (0.0018115942028985507, 0.2391304347826087)  At (gamma, c):  [1.         6.87813651]
# error of particle- 97 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.         5.92829826]
# error of particle- 98 is (training, test) (0.0, 0.2898550724637681)  At (gamma, c):  [3.         5.61659768]
# error of particle- 99 is (training, test) (0.0018115942028985507, 0.2898550724637681)  At (gamma, c):  [2.        6.6647435]
# error of particle- 100 is (training, test) (0.0, 0.2971014492753623)  At (gamma, c):  [3.         6.15155703]
# The best position is  [1.         6.46512548] in iteration number 10 with error rate (train, test): (0.0018115942028985507, 0.2318840579710145)
