# %%
import pandas as pd
import numpy as np
import math
import random
import csv
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix  
import matplotlib.pyplot as plt

# %%
url = "D:\\TUGAS AKHIR\\Data TA\\Australian fraud dataset\\australian.csv"
colnames = ['x1', 'x2', 'x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13','x14', 'y']
data = pd.read_csv(url, header = None, names = colnames)
X = data.drop('y', axis = 1)
X = (X-X.mean())/X.std()
y = data['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
#################### I N P U T ####################
#berdasarkan buku
#khi = 0.729
#c1 = 2.05
#c2 = 2.05

#berdasarkan paper
K = 0.3
c1 = 2
c2 = 5
c = c1+ c2
khi = 2*K/(abs(2-c-math.sqrt(c**2-4*c)))
n_iterations = int(input("Inform the number of iterations: "))
n_particles = int(input("Inform the number of particles: "))
# Out:
# Inform the number of iterations: 10
# Inform the number of particles: 100

# %%
#mencari nilai 0-1 loss dari tiap partikel
#partikle = (gamma,C) untuk rbf
def fitness_function(position):
    svclassifier = SVC(kernel='rbf', gamma = position[0], C = position[1] )  
    svclassifier.fit(X_train, y_train)
    y_train_pred = svclassifier.predict(X_train)
    y_test_pred = svclassifier.predict(X_test)   
    return (confusion_matrix(y_train,y_train_pred)[0][1] + confusion_matrix(y_train,y_train_pred)[1][0])/np.sum(confusion_matrix(y_train,y_train_pred)), (confusion_matrix(y_test,y_test_pred)[0][1] + confusion_matrix(y_test,y_test_pred)[1][0])/np.sum(confusion_matrix(y_test,y_test_pred))

#plotting (x axis = gamma, y axis = C)
def plot(position):
    x = []
    y = []
    for i in range(0,len(particle_position_vector)):
        x.append(particle_position_vector[i][0])
        y.append(particle_position_vector[i][1])
    colors = (0,0,0)
    plt.scatter(x, y, c = colors, alpha = 0.1)
    plt.xlabel('gamma')
    plt.ylabel('C')
    plt.axis([0,10,0,10])
    plt.gca().set_aspect('equal', adjustable='box')
    return plt.show()

# %%
particle_position_vector = np.array([np.array([random.random()*10, random.random()*10]) for _ in range(n_particles)])
pbest_position = particle_position_vector
pbest_fitness_value = np.array([float('inf') for _ in range(n_particles)])
gbest_fitness_value = np.array([float('inf'), float('inf')])
gbest_position = np.array([float('inf'), float('inf')])

velocity_vector = ([np.array([0, 0]) for _ in range(n_particles)])
iteration = 0
while iteration < n_iterations:
    plot(particle_position_vector)
    for i in range(n_particles):
        fitness_cadidate = fitness_function(particle_position_vector[i])
        print("error of particle-",i+1,"is (training, test)", fitness_cadidate, " At (gamma, c): ", particle_position_vector[i])
        
        if(pbest_fitness_value[i] > fitness_cadidate[1]):
            pbest_fitness_value[i] = fitness_cadidate[1]
            pbest_position[i] = particle_position_vector[i]

        if(gbest_fitness_value[1] > fitness_cadidate[1]):
            gbest_fitness_value = fitness_cadidate
            gbest_position = particle_position_vector[i]
        elif(gbest_fitness_value[1] == fitness_cadidate[1] and gbest_fitness_value[0] > fitness_cadidate[0]):
            gbest_fitness_value = fitness_cadidate
            gbest_position = particle_position_vector[i]
            
    for i in range(n_particles):
        max_velocity = np.array([10,10])
        min_velocity = np.array([-10,-10])
        max_position = np.array([10,10])
        min_position = np.array([0.001, 0.001])
        new_velocity = khi*(velocity_vector[i] + (c1*random.random()) * (pbest_position[i] - particle_position_vector[i]) + (c2*random.random()) * (gbest_position-particle_position_vector[i]))
        for j in range(0,len(new_velocity)):
            if(new_velocity[j] > max_velocity[j]):
                new_velocity[j] = max_velocity[j]
            elif(new_velocity[j] < min_velocity[j]):
                new_velocity[j] = min_velocity[j]
            
        new_position = new_velocity + particle_position_vector[i]
        particle_position_vector[i] = new_position
        for j in range(0,2):
            if(particle_position_vector[i][j] > max_position[j]):
                particle_position_vector[i][j] = max_position[j]
            elif(particle_position_vector[i][j] < min_position[j]):
                particle_position_vector[i][j] = min_position[j]
    
    iteration = iteration + 1
    
print("The best position is ", gbest_position, "in iteration number", iteration, "with error rate (train, test):", fitness_function(gbest_position))
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 1 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.05974035 9.93943688]
# error of particle- 2 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.6210354  9.92019618]
# error of particle- 3 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.71543747 1.61252239]
# error of particle- 4 is (training, test) (0.08695652173913043, 0.15942028985507245)  At (gamma, c):  [0.02393609 5.50041006]
# error of particle- 5 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.81283935 7.93266006]
# error of particle- 6 is (training, test) (0.0018115942028985507, 0.4420289855072464)  At (gamma, c):  [1.95945756 4.929601  ]
# error of particle- 7 is (training, test) (0.007246376811594203, 0.35507246376811596)  At (gamma, c):  [1.36861447 2.43537588]
# error of particle- 8 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.31820615 2.42683028]
# error of particle- 9 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.0564012  7.62616028]
# error of particle- 10 is (training, test) (0.0018115942028985507, 0.43478260869565216)  At (gamma, c):  [2.79405573 1.14758339]
# error of particle- 11 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.63814778 7.03126774]
# error of particle- 12 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.9947266  9.51669479]
# error of particle- 13 is (training, test) (0.0036231884057971015, 0.3695652173913043)  At (gamma, c):  [1.44812969 5.17837693]
# error of particle- 14 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.10177999 8.27387744]
# error of particle- 15 is (training, test) (0.009057971014492754, 0.36231884057971014)  At (gamma, c):  [1.42176779 1.43273605]
# error of particle- 16 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.94921971 5.13091766]
# error of particle- 17 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.67393415 1.41307506]
# error of particle- 18 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.94799226 1.54539649]
# error of particle- 19 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.07658477 8.98039862]
# error of particle- 20 is (training, test) (0.0036231884057971015, 0.2898550724637681)  At (gamma, c):  [1.02052932 9.91433336]
# error of particle- 21 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.3831253  3.50548729]
# error of particle- 22 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.32122527 2.67805672]
# error of particle- 23 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.3833032 8.4795509]
# error of particle- 24 is (training, test) (0.0018115942028985507, 0.43478260869565216)  At (gamma, c):  [1.90831297 6.41467262]
# error of particle- 25 is (training, test) (0.005434782608695652, 0.463768115942029)  At (gamma, c):  [6.57485721 0.65995261]
# error of particle- 26 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.42507455 4.50903595]
# error of particle- 27 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.65809214 4.61519926]
# error of particle- 28 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.85251932 1.7190376 ]
# error of particle- 29 is (training, test) (0.009057971014492754, 0.21739130434782608)  At (gamma, c):  [0.63220293 4.96270025]
# error of particle- 30 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.0630583  8.48708118]
# error of particle- 31 is (training, test) (0.0036231884057971015, 0.32608695652173914)  At (gamma, c):  [1.28645108 6.49588579]
# error of particle- 32 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.49627905 7.10085002]
# error of particle- 33 is (training, test) (0.0036231884057971015, 0.36231884057971014)  At (gamma, c):  [1.43307244 9.16119734]
# error of particle- 34 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.00895792 8.12665943]
# error of particle- 35 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.10225117 9.67390857]
# error of particle- 36 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.28409926 9.2676429 ]
# error of particle- 37 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.13090538 1.2383769 ]
# error of particle- 38 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.06015653 9.2566261 ]
# error of particle- 39 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.29660022 1.60638077]
# error of particle- 40 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.64078381 4.32789184]
# error of particle- 41 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.32672407 8.49846796]
# error of particle- 42 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.24978936 3.88302466]
# error of particle- 43 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.19443267 9.62699996]
# error of particle- 44 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.9109485  2.84929983]
# error of particle- 45 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.60189329 4.9651526 ]
# error of particle- 46 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.77476035 3.75749717]
# error of particle- 47 is (training, test) (0.44021739130434784, 0.463768115942029)  At (gamma, c):  [5.53166683 0.16079308]
# error of particle- 48 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.25719596 5.99546243]
# error of particle- 49 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.53465953 6.75481857]
# error of particle- 50 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.7268769  3.16082552]
# error of particle- 51 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.78504765 1.6837648 ]
# error of particle- 52 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.71965265 6.71092972]
# error of particle- 53 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.26982183 2.89643606]
# error of particle- 54 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.70536127 8.08192555]
# error of particle- 55 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.62337165 7.73562165]
# error of particle- 56 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.45232581 2.47100206]
# error of particle- 57 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.74933306 4.41364005]
# error of particle- 58 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.04802577 2.87820366]
# error of particle- 59 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.07018383 9.23755797]
# error of particle- 60 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.2269924  5.95971404]
# error of particle- 61 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.0339474  4.87840091]
# error of particle- 62 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [2.29146994 8.80952055]
# error of particle- 63 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.12620494 5.77157046]
# error of particle- 64 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.14086158 3.62981567]
# error of particle- 65 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.9204241  4.65668682]
# error of particle- 66 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [3.61657353 9.06587642]
# error of particle- 67 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.04521821 3.03522252]
# error of particle- 68 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.53772557 9.50923685]
# error of particle- 69 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.67435901 4.74656401]
# error of particle- 70 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.02564392 5.16333031]
# error of particle- 71 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.9066178 7.2818871]
# error of particle- 72 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.83525231 2.89612696]
# error of particle- 73 is (training, test) (0.0036231884057971015, 0.4057971014492754)  At (gamma, c):  [1.720195   4.57826966]
# error of particle- 74 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.88440842 1.1039277 ]
# error of particle- 75 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.94324514 4.87148389]
# error of particle- 76 is (training, test) (0.007246376811594203, 0.18840579710144928)  At (gamma, c):  [0.55803125 9.57742933]
# error of particle- 77 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.73933508 6.98384256]
# error of particle- 78 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.10696492 3.9301663 ]
# error of particle- 79 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.10096913 4.5151979 ]
# error of particle- 80 is (training, test) (0.0036231884057971015, 0.463768115942029)  At (gamma, c):  [8.97237157 0.72926748]
# error of particle- 81 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [2.06427549 2.76882294]
# error of particle- 82 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.88579745 7.58609839]
# error of particle- 83 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.61897229 2.6376548 ]
# error of particle- 84 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.78473389 7.49644037]
# error of particle- 85 is (training, test) (0.010869565217391304, 0.18115942028985507)  At (gamma, c):  [0.37755627 4.27608614]
# error of particle- 86 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.17071562 5.49048082]
# error of particle- 87 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.16486128 8.49105964]
# error of particle- 88 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.34329384 1.62044542]
# error of particle- 89 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.81768839 9.05937662]
# error of particle- 90 is (training, test) (0.007246376811594203, 0.18840579710144928)  At (gamma, c):  [0.55508547 9.37396643]
# error of particle- 91 is (training, test) (0.0036231884057971015, 0.3188405797101449)  At (gamma, c):  [1.2936364  9.43272157]
# error of particle- 92 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.39055336 4.26266004]
# error of particle- 93 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.04005292 8.26575042]
# error of particle- 94 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.83629026 1.98859387]
# error of particle- 95 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.24778416 5.39127263]
# error of particle- 96 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.62269105 8.64617589]
# error of particle- 97 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.30226532 4.07070345]
# error of particle- 98 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.3289506  7.93529277]
# error of particle- 99 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.94071891 3.63109383]
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 100 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.04304432 3.9679629 ]
# error of particle- 1 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.77057944 9.30610977]
# error of particle- 2 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.23698569 9.55095952]
# error of particle- 3 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.38270064 2.38686745]
# error of particle- 4 is (training, test) (0.08695652173913043, 0.15942028985507245)  At (gamma, c):  [0.02393609 5.50041006]
# error of particle- 5 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.56709196 7.80784671]
# error of particle- 6 is (training, test) (0.0018115942028985507, 0.41304347826086957)  At (gamma, c):  [1.76268229 4.98763244]
# error of particle- 7 is (training, test) (0.007246376811594203, 0.32608695652173914)  At (gamma, c):  [1.25728323 2.68914219]
# error of particle- 8 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.01062787 2.97780332]
# error of particle- 9 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.48281016 7.1505004 ]
# error of particle- 10 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [2.02902062 2.34972109]
# error of particle- 11 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.21545824 6.77843726]
# error of particle- 12 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.69758824 9.3836639 ]
# error of particle- 13 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.18509408 5.23785352]
# error of particle- 14 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.88802101 7.90304919]
# error of particle- 15 is (training, test) (0.009057971014492754, 0.35507246376811596)  At (gamma, c):  [1.4028654  1.48774176]
# error of particle- 16 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.9685441  5.22323002]
# error of particle- 17 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.66507911 1.42673301]
# error of particle- 18 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.0336568  2.15582439]
# error of particle- 19 is (training, test) (0.0, 0.427536231884058)  At (gamma, c):  [1.82558608 8.55486426]
# error of particle- 20 is (training, test) (0.005434782608695652, 0.2391304347826087)  At (gamma, c):  [0.78024541 8.85011306]
# error of particle- 21 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.28837153 4.00648624]
# error of particle- 22 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.17567011 2.72756784]
# error of particle- 23 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.59246049 7.77821885]
# error of particle- 24 is (training, test) (0.0018115942028985507, 0.42028985507246375)  At (gamma, c):  [1.80246365 6.36331661]
# error of particle- 25 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.05423743 1.78353435]
# error of particle- 26 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.12064489 4.66296482]
# error of particle- 27 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.88225089 4.87025063]
# error of particle- 28 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.94896208 2.45139737]
# error of particle- 29 is (training, test) (0.009057971014492754, 0.18840579710144928)  At (gamma, c):  [0.56234236 5.02445721]
# error of particle- 30 is (training, test) (0.0018115942028985507, 0.41304347826086957)  At (gamma, c):  [1.74737704 8.02470767]
# error of particle- 31 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.98943862 6.26169554]
# error of particle- 32 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.46694784 7.08186283]
# error of particle- 33 is (training, test) (0.0036231884057971015, 0.35507246376811596)  At (gamma, c):  [1.37230353 9.00332614]
# error of particle- 34 is (training, test) (0.0018115942028985507, 0.42028985507246375)  At (gamma, c):  [1.80112775 7.85169326]
# error of particle- 35 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.16505372 8.78333685]
# error of particle- 36 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [8.07762159 8.77682193]
# error of particle- 37 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.12166182 2.08064347]
# error of particle- 38 is (training, test) (0.0036231884057971015, 0.2753623188405797)  At (gamma, c):  [0.91560462 8.73263701]
# error of particle- 39 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.64534598 2.29982036]
# error of particle- 40 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.04807972 4.45161895]
# error of particle- 41 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.24859202 7.74725681]
# error of particle- 42 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.31931103 4.17100482]
# error of particle- 43 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.48950493 8.85980731]
# error of particle- 44 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [3.6605424 3.0200876]
# error of particle- 45 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.74765301 5.03466331]
# error of particle- 46 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.35572557 3.83239762]
# error of particle- 47 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.42066832 1.23788032]
# error of particle- 48 is (training, test) (0.0036231884057971015, 0.391304347826087)  At (gamma, c):  [1.57247238 5.84367802]
# error of particle- 49 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.18348665 6.67488093]
# error of particle- 50 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.01439544 3.6109841 ]
# error of particle- 51 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.89488159 2.75076292]
# error of particle- 52 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.26999317 6.40283129]
# error of particle- 53 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.17452437 3.64942891]
# error of particle- 54 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.88541143 7.47029052]
# error of particle- 55 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.29716522 7.20621972]
# error of particle- 56 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.30528162 3.11113017]
# error of particle- 57 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.2851548  4.75037896]
# error of particle- 58 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.33084279 3.62567065]
# error of particle- 59 is (training, test) (0.0036231884057971015, 0.2753623188405797)  At (gamma, c):  [0.92034616 8.70234485]
# error of particle- 60 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.92284673 5.83070075]
# error of particle- 61 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.68802607 5.04035238]
# error of particle- 62 is (training, test) (0.0018115942028985507, 0.43478260869565216)  At (gamma, c):  [1.85243171 8.16881301]
# error of particle- 63 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.38741315 5.69430551]
# error of particle- 64 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.90389377 3.73748598]
# error of particle- 65 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.86137392 4.88600749]
# error of particle- 66 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.29929854 8.75100097]
# error of particle- 67 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.27612772 3.66275487]
# error of particle- 68 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.9803146  8.67831248]
# error of particle- 69 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.15527399 4.85375986]
# error of particle- 70 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.62016142 5.20886437]
# error of particle- 71 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.63941047 6.82718458]
# error of particle- 72 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [3.52091067 3.60755759]
# error of particle- 73 is (training, test) (0.0036231884057971015, 0.35507246376811596)  At (gamma, c):  [1.35932021 4.7744527 ]
# error of particle- 74 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.64442525 2.21538611]
# error of particle- 75 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.83474538 5.0132039 ]
# error of particle- 76 is (training, test) (0.007246376811594203, 0.18840579710144928)  At (gamma, c):  [0.54454552 9.47448593]
# error of particle- 77 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.52415652 6.91614884]
# error of particle- 78 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.60983466 4.22100523]
# error of particle- 79 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.20147279 4.68974763]
# error of particle- 80 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.81945044 1.343984  ]
# error of particle- 81 is (training, test) (0.0018115942028985507, 0.42028985507246375)  At (gamma, c):  [1.7788561  3.15093972]
# error of particle- 82 is (training, test) (0.005434782608695652, 0.2391304347826087)  At (gamma, c):  [0.78026966 7.3307231 ]
# error of particle- 83 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.05048494 3.44018676]
# error of particle- 84 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.38673968 7.39407866]
# error of particle- 85 is (training, test) (0.014492753623188406, 0.18840579710144928)  At (gamma, c):  [0.27063218 4.6462848 ]
# error of particle- 86 is (training, test) (0.0036231884057971015, 0.4057971014492754)  At (gamma, c):  [1.7193176  5.49256861]
# error of particle- 87 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.80049243 8.14412379]
# error of particle- 88 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [9.21198272 1.67511469]
# error of particle- 89 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.50525763 8.66137046]
# error of particle- 90 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.4921481  8.91497794]
# error of particle- 91 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.0816387 8.7761564]
# error of particle- 92 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.67775362 4.51605013]
# error of particle- 93 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.85957886 8.14148307]
# error of particle- 94 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.45466767 2.46513001]
# error of particle- 95 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.92044609 5.39561668]
# error of particle- 96 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.49771954 7.76647089]
# error of particle- 97 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.59685159 4.37834023]
# error of particle- 98 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.63043163 7.73049942]
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 99 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.34261698 3.79273569]
# error of particle- 100 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.02467444 3.97357164]
# error of particle- 1 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.00706862 8.43974839]
# error of particle- 2 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.20457761 9.51980144]
# error of particle- 3 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.29608141 2.43719485]
# error of particle- 4 is (training, test) (0.08695652173913043, 0.15942028985507245)  At (gamma, c):  [0.02393609 5.50041006]
# error of particle- 5 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [3.65657715 7.34540269]
# error of particle- 6 is (training, test) (0.0036231884057971015, 0.39855072463768115)  At (gamma, c):  [1.627874   5.02738906]
# error of particle- 7 is (training, test) (0.009057971014492754, 0.2753623188405797)  At (gamma, c):  [0.98611754 3.30723207]
# error of particle- 8 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.61745922 3.56484149]
# error of particle- 9 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.40609714 6.82503516]
# error of particle- 10 is (training, test) (0.0018115942028985507, 0.4420289855072464)  At (gamma, c):  [1.93245256 2.50146328]
# error of particle- 11 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.84948085 6.71339831]
# error of particle- 12 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.04692859 8.19694531]
# error of particle- 13 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.14764906 5.24632044]
# error of particle- 14 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.07898347 7.35035114]
# error of particle- 15 is (training, test) (0.009057971014492754, 0.3115942028985507)  At (gamma, c):  [1.07664335 2.43704416]
# error of particle- 16 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.63998456 5.25415779]
# error of particle- 17 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.6013949 1.524959 ]
# error of particle- 18 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.025923   2.82860681]
# error of particle- 19 is (training, test) (0.0036231884057971015, 0.35507246376811596)  At (gamma, c):  [1.40940337 7.84928269]
# error of particle- 20 is (training, test) (0.007246376811594203, 0.18840579710144928)  At (gamma, c):  [0.57944498 7.96076558]
# error of particle- 21 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.94677381 4.16281372]
# error of particle- 22 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.27028454 3.37569173]
# error of particle- 23 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.52894905 7.72189589]
# error of particle- 24 is (training, test) (0.0036231884057971015, 0.32608695652173914)  At (gamma, c):  [1.28583621 6.11265915]
# error of particle- 25 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.82627529 1.95197494]
# error of particle- 26 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.89900899 4.68911891]
# error of particle- 27 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.11110489 5.03298803]
# error of particle- 28 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.01328111 3.19611616]
# error of particle- 29 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.41175768 5.15757454]
# error of particle- 30 is (training, test) (0.0036231884057971015, 0.32608695652173914)  At (gamma, c):  [1.27804024 7.33727724]
# error of particle- 31 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.87852492 6.17424161]
# error of particle- 32 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.092022   6.83915933]
# error of particle- 33 is (training, test) (0.0036231884057971015, 0.32608695652173914)  At (gamma, c):  [1.29383692 8.79947819]
# error of particle- 34 is (training, test) (0.0036231884057971015, 0.35507246376811596)  At (gamma, c):  [1.35525527 7.26178926]
# error of particle- 35 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.50088836 8.47800562]
# error of particle- 36 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.41300136 8.50644017]
# error of particle- 37 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [3.56909732 2.54178746]
# error of particle- 38 is (training, test) (0.0036231884057971015, 0.26811594202898553)  At (gamma, c):  [0.85080346 8.497738  ]
# error of particle- 39 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.00376241 2.98919877]
# error of particle- 40 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.25545952 4.61707859]
# error of particle- 41 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [3.00559447 7.57794316]
# error of particle- 42 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.24283626 4.19467353]
# error of particle- 43 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.46185966 7.94739647]
# error of particle- 44 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.22529869 3.31694259]
# error of particle- 45 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.83191945 5.10917782]
# error of particle- 46 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.44795186 4.17340298]
# error of particle- 47 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.67148116 1.96419987]
# error of particle- 48 is (training, test) (0.0036231884057971015, 0.391304347826087)  At (gamma, c):  [1.48393923 5.82405265]
# error of particle- 49 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.76680733 6.58003203]
# error of particle- 50 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.74315651 3.78235774]
# error of particle- 51 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.50476475 2.97098375]
# error of particle- 52 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.04448838 6.3549044 ]
# error of particle- 53 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.83963232 4.12915275]
# error of particle- 54 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.30883336 7.27651851]
# error of particle- 55 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.22053357 7.17562951]
# error of particle- 56 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.38547331 3.62444531]
# error of particle- 57 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.77948142 4.86667621]
# error of particle- 58 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.98973128 4.20943872]
# error of particle- 59 is (training, test) (0.005434782608695652, 0.2608695652173913)  At (gamma, c):  [0.82223441 8.35189427]
# error of particle- 60 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.66366229 5.81618855]
# error of particle- 61 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.524582   5.05163579]
# error of particle- 62 is (training, test) (0.0036231884057971015, 0.35507246376811596)  At (gamma, c):  [1.36157666 7.45248696]
# error of particle- 63 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.23070026 5.64290582]
# error of particle- 64 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.93018693 4.17990608]
# error of particle- 65 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.4941363  4.96552703]
# error of particle- 66 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.04629094 8.49990687]
# error of particle- 67 is (training, test) (0.0018115942028985507, 0.41304347826086957)  At (gamma, c):  [1.75187034 4.09051789]
# error of particle- 68 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.80328518 8.5838621 ]
# error of particle- 69 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [2.32085604 5.02607487]
# error of particle- 70 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.53598965 5.21831652]
# error of particle- 71 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.34531397 6.7682017 ]
# error of particle- 72 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.23472618 3.76246435]
# error of particle- 73 is (training, test) (0.0036231884057971015, 0.35507246376811596)  At (gamma, c):  [1.34313386 4.78325211]
# error of particle- 74 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.89999464 3.08095604]
# error of particle- 75 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.8184538  5.14313523]
# error of particle- 76 is (training, test) (0.009057971014492754, 0.17391304347826086)  At (gamma, c):  [0.39484319 8.33173209]
# error of particle- 77 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.90165792 6.72031501]
# error of particle- 78 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.92263847 4.3545029 ]
# error of particle- 79 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.17782726 4.69433611]
# error of particle- 80 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.79517743 1.89010768]
# error of particle- 81 is (training, test) (0.0036231884057971015, 0.37681159420289856)  At (gamma, c):  [1.46292705 3.57390255]
# error of particle- 82 is (training, test) (0.009057971014492754, 0.21739130434782608)  At (gamma, c):  [0.623158   6.95051584]
# error of particle- 83 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.34760893 3.79982018]
# error of particle- 84 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.10469358 7.32153811]
# error of particle- 85 is (training, test) (0.016304347826086956, 0.18115942028985507)  At (gamma, c):  [0.20051617 4.88904446]
# error of particle- 86 is (training, test) (0.0036231884057971015, 0.35507246376811596)  At (gamma, c):  [1.34996498 5.49427694]
# error of particle- 87 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.59364496 7.94717281]
# error of particle- 88 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.95904611 2.6130886 ]
# error of particle- 89 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.34220674 8.45365961]
# error of particle- 90 is (training, test) (0.009057971014492754, 0.17391304347826086)  At (gamma, c):  [0.41330803 8.34001455]
# error of particle- 91 is (training, test) (0.0036231884057971015, 0.2753623188405797)  At (gamma, c):  [0.96502877 8.4150109 ]
# error of particle- 92 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.19815948 4.58700087]
# error of particle- 93 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.26275351 7.73053256]
# error of particle- 94 is (training, test) (0.0018115942028985507, 0.43478260869565216)  At (gamma, c):  [1.85330311 3.21606025]
# error of particle- 95 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [7.03812831 5.40732578]
# error of particle- 96 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.91853505 7.11271318]
# error of particle- 97 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.36691879 4.47861584]
# error of particle- 98 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.76403048 7.18330376]
# error of particle- 99 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.78142501 4.21466039]
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 100 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [3.5016238  4.43859342]
# error of particle- 1 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.71040828 8.29400782]
# error of particle- 2 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [3.45786808 8.80189299]
# error of particle- 3 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.94973507 2.63842856]
# error of particle- 4 is (training, test) (0.08695652173913043, 0.15942028985507245)  At (gamma, c):  [0.02393609 5.50041006]
# error of particle- 5 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.17962134 7.10316022]
# error of particle- 6 is (training, test) (0.0036231884057971015, 0.3695652173913043)  At (gamma, c):  [1.44722277 5.08066533]
# error of particle- 7 is (training, test) (0.009057971014492754, 0.2536231884057971)  At (gamma, c):  [0.80447064 3.72127454]
# error of particle- 8 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.41035352 3.65210943]
# error of particle- 9 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.1229195  6.73943716]
# error of particle- 10 is (training, test) (0.0036231884057971015, 0.391304347826087)  At (gamma, c):  [1.50036014 3.18043158]
# error of particle- 11 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.09779047 6.4021001 ]
# error of particle- 12 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.2038248  7.37177504]
# error of particle- 13 is (training, test) (0.007246376811594203, 0.2608695652173913)  At (gamma, c):  [0.80571264 5.32363778]
# error of particle- 14 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.64634826 7.21817222]
# error of particle- 15 is (training, test) (0.009057971014492754, 0.2826086956521739)  At (gamma, c):  [1.00677279 2.64036667]
# error of particle- 16 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [2.04725572 5.30995217]
# error of particle- 17 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [2.14332791 2.23147772]
# error of particle- 18 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.91813934 3.56818444]
# error of particle- 19 is (training, test) (0.0036231884057971015, 0.3188405797101449)  At (gamma, c):  [1.24404147 7.56893393]
# error of particle- 20 is (training, test) (0.009057971014492754, 0.18840579710144928)  At (gamma, c):  [0.56052515 7.87696943]
# error of particle- 21 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.16760385 4.5193901 ]
# error of particle- 22 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.39741608 3.67260114]
# error of particle- 23 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.2501056  7.47461303]
# error of particle- 24 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.92474635 5.93746546]
# error of particle- 25 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.92955964 2.61455565]
# error of particle- 26 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.4126627  4.86451481]
# error of particle- 27 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.33959604 5.10387623]
# error of particle- 28 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.78897123 3.2824154 ]
# error of particle- 29 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.40325103 5.16509445]
# error of particle- 30 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.94315212 6.84677172]
# error of particle- 31 is (training, test) (0.009057971014492754, 0.2246376811594203)  At (gamma, c):  [0.64280712 5.98838137]
# error of particle- 32 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.05186718 6.81316561]
# error of particle- 33 is (training, test) (0.0036231884057971015, 0.2753623188405797)  At (gamma, c):  [0.95168254 7.91059726]
# error of particle- 34 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.21468489 7.07581001]
# error of particle- 35 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.01048634 8.25255716]
# error of particle- 36 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.81164669 7.85497477]
# error of particle- 37 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.8825021  3.11478711]
# error of particle- 38 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.83664193 8.44640361]
# error of particle- 39 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.18165723 3.75438673]
# error of particle- 40 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.91663983 4.68780728]
# error of particle- 41 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.96267153 7.5480357 ]
# error of particle- 42 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.1593922  4.52999611]
# error of particle- 43 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.38576408 7.91315456]
# error of particle- 44 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.67994689 3.68889606]
# error of particle- 45 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.92077454 5.18331894]
# error of particle- 46 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.92320965 4.26719813]
# error of particle- 47 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.25607086 2.3669305 ]
# error of particle- 48 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.14691141 5.74934284]
# error of particle- 49 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.24604909 6.46149159]
# error of particle- 50 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [2.2802413  4.07483588]
# error of particle- 51 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [3.50682307 3.5343215 ]
# error of particle- 52 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.21175433 6.17792212]
# error of particle- 53 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.75630197 4.51847218]
# error of particle- 54 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.85753645 7.12485005]
# error of particle- 55 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.0535869  6.70980171]
# error of particle- 56 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.96550182 3.85881776]
# error of particle- 57 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [2.03150138 5.03870033]
# error of particle- 58 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.81937364 4.28359314]
# error of particle- 59 is (training, test) (0.007246376811594203, 0.2246376811594203)  At (gamma, c):  [0.67865621 7.83903967]
# error of particle- 60 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.37309936 5.74392759]
# error of particle- 61 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.05348248 5.15319364]
# error of particle- 62 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.94541002 6.84515692]
# error of particle- 63 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.0620225  5.63541046]
# error of particle- 64 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [2.29407518 4.46893415]
# error of particle- 65 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.3893033  4.98822697]
# error of particle- 66 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.15978057 7.62010117]
# error of particle- 67 is (training, test) (0.0036231884057971015, 0.35507246376811596)  At (gamma, c):  [1.3496123  4.41873667]
# error of particle- 68 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.77768844 8.57020549]
# error of particle- 69 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [2.02626082 5.08691151]
# error of particle- 70 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [2.28545034 5.24645108]
# error of particle- 71 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.43170152 6.58497104]
# error of particle- 72 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.52334774 4.14752132]
# error of particle- 73 is (training, test) (0.005434782608695652, 0.3115942028985507)  At (gamma, c):  [1.11878805 4.90521365]
# error of particle- 74 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.25479129 3.40109982]
# error of particle- 75 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [2.13301198 5.23076792]
# error of particle- 76 is (training, test) (0.009057971014492754, 0.17391304347826086)  At (gamma, c):  [0.30856263 7.67310882]
# error of particle- 77 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.0611657  6.45590187]
# error of particle- 78 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.63511452 4.60462281]
# error of particle- 79 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.130438   4.89758486]
# error of particle- 80 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.27942938 2.16509514]
# error of particle- 81 is (training, test) (0.007246376811594203, 0.3115942028985507)  At (gamma, c):  [1.21395874 3.90721897]
# error of particle- 82 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.49741853 6.64622869]
# error of particle- 83 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.78858062 4.08585251]
# error of particle- 84 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [6.46964517 7.15820749]
# error of particle- 85 is (training, test) (0.018115942028985508, 0.16666666666666666)  At (gamma, c):  [0.18979118 4.92617712]
# error of particle- 86 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.97150975 5.49602736]
# error of particle- 87 is (training, test) (0.0018115942028985507, 0.4420289855072464)  At (gamma, c):  [1.92940547 7.31471345]
# error of particle- 88 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.19464475 3.34766871]
# error of particle- 89 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.17788731 8.24433276]
# error of particle- 90 is (training, test) (0.009057971014492754, 0.17391304347826086)  At (gamma, c):  [0.40242863 8.26067341]
# error of particle- 91 is (training, test) (0.005434782608695652, 0.2391304347826087)  At (gamma, c):  [0.75108516 7.75241916]
# error of particle- 92 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.14941829 4.74215072]
# error of particle- 93 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.035729  7.5742124]
# error of particle- 94 is (training, test) (0.0036231884057971015, 0.34057971014492755)  At (gamma, c):  [1.32052505 3.88134581]
# error of particle- 95 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [5.87552265 5.42275455]
# error of particle- 96 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [3.60530694 6.98304164]
# error of particle- 97 is (training, test) (0.0036231884057971015, 0.39855072463768115)  At (gamma, c):  [1.67073975 4.7822253 ]
# error of particle- 98 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.11278337 6.69918744]
# error of particle- 99 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [4.66662509 4.24568599]
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 100 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [3.45626027 4.45244393]
# error of particle- 1 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.0462882  7.47647422]
# error of particle- 2 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.5629077  7.94145184]
# error of particle- 3 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [4.01121598 3.18372574]
# error of particle- 4 is (training, test) (0.08695652173913043, 0.15942028985507245)  At (gamma, c):  [0.02393609 5.50041006]
# error of particle- 5 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.26411921 6.63818318]
# error of particle- 6 is (training, test) (0.0036231884057971015, 0.32608695652173914)  At (gamma, c):  [1.2606989  5.13567351]
# error of particle- 7 is (training, test) (0.009057971014492754, 0.18840579710144928)  At (gamma, c):  [0.59897371 4.1896803 ]
# error of particle- 8 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.70272534 3.95028206]
# error of particle- 9 is (training, test) (0.0, 0.45652173913043476)  At (gamma, c):  [3.66909985 6.60225806]
# ...
# error of particle- 77 is (training, test) (0.0036231884057971015, 0.391304347826087)  At (gamma, c):  [1.49305905 5.96258617]
# error of particle- 78 is (training, test) (0.0, 0.4420289855072464)  At (gamma, c):  [2.4384918  5.03134814]
# error of particle- 79 is (training, test) (0.0036231884057971015, 0.39855072463768115)  At (gamma, c):  [1.64331685 5.18616479]
# error of particle- 80 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.688755   4.07957722]
# error of particle- 81 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.50429822 4.85730578]
# error of particle- 82 is (training, test) (0.016304347826086956, 0.17391304347826086)  At (gamma, c):  [0.20702721 5.94348712]
# error of particle- 83 is (training, test) (0.005434782608695652, 0.3115942028985507)  At (gamma, c):  [1.07651988 4.96184522]
# error of particle- 84 is (training, test) (0.0018115942028985507, 0.43478260869565216)  At (gamma, c):  [1.89445676 5.98149668]
# error of particle- 85 is (training, test) (0.05253623188405797, 0.16666666666666666)  At (gamma, c):  [0.08043721 5.30478868]
# error of particle- 86 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.51204627 5.49815246]
# error of particle- 87 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.95068361 6.38281792]
# error of particle- 88 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.30809057 4.13310519]
# error of particle- 89 is (training, test) (0.009057971014492754, 0.18840579710144928)  At (gamma, c):  [0.587494   6.21832759]
# error of particle- 90 is (training, test) (0.030797101449275364, 0.16666666666666666)  At (gamma, c):  [0.13766153 6.32978486]
# error of particle- 91 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.51507216 7.02147767]
# error of particle- 92 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.08974974 5.04685628]
# error of particle- 93 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.05655709 6.21143234]
# error of particle- 94 is (training, test) (0.009057971014492754, 0.2246376811594203)  At (gamma, c):  [0.72497931 4.62501003]
# error of particle- 95 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.17846169 5.45854683]
# error of particle- 96 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.13512961 6.37441119]
# error of particle- 97 is (training, test) (0.009057971014492754, 0.2246376811594203)  At (gamma, c):  [0.7017866  5.20479382]
# error of particle- 98 is (training, test) (0.0036231884057971015, 0.3695652173913043)  At (gamma, c):  [1.41748372 5.90897347]
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# error of particle- 99 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.33520846 4.8757701 ]
# error of particle- 100 is (training, test) (0.0036231884057971015, 0.39855072463768115)  At (gamma, c):  [1.64398514 5.00577248]
# error of particle- 1 is (training, test) (0.0018115942028985507, 0.43478260869565216)  At (gamma, c):  [1.86883627 6.40675565]
# error of particle- 2 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.08861914 6.52402757]
# error of particle- 3 is (training, test) (0.0036231884057971015, 0.39855072463768115)  At (gamma, c):  [1.67431118 4.54151121]
# error of particle- 4 is (training, test) (0.08695652173913043, 0.15942028985507245)  At (gamma, c):  [0.02393609 5.50041006]
# error of particle- 5 is (training, test) (0.007246376811594203, 0.2246376811594203)  At (gamma, c):  [0.70927637 5.84848953]
# error of particle- 6 is (training, test) (0.009057971014492754, 0.18840579710144928)  At (gamma, c):  [0.5912416 5.3331047]
# error of particle- 7 is (training, test) (0.016304347826086956, 0.18115942028985507)  At (gamma, c):  [0.20855929 5.07958348]
# error of particle- 8 is (training, test) (0.0036231884057971015, 0.35507246376811596)  At (gamma, c):  [1.35775406 4.93838043]
# error of particle- 9 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.94141489 5.77774251]
# error of particle- 10 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.46488578 4.80752389]
# error of particle- 11 is (training, test) (0.0036231884057971015, 0.36231884057971014)  At (gamma, c):  [1.39318074 5.74374268]
# error of particle- 12 is (training, test) (0.0036231884057971015, 0.32608695652173914)  At (gamma, c):  [1.25346468 6.05087848]
# error of particle- 13 is (training, test) (0.016304347826086956, 0.18115942028985507)  At (gamma, c):  [0.20683397 5.4590539 ]
# error of particle- 14 is (training, test) (0.0036231884057971015, 0.39855072463768115)  At (gamma, c):  [1.6402766  5.99423522]
# error of particle- 15 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.43415895 4.3066663 ]
# error of particle- 16 is (training, test) (0.007246376811594203, 0.2753623188405797)  At (gamma, c):  [0.86946222 5.42081951]
# error of particle- 17 is (training, test) (0.007246376811594203, 0.3115942028985507)  At (gamma, c):  [1.05656262 3.90769548]
# error of particle- 18 is (training, test) (0.007246376811594203, 0.2753623188405797)  At (gamma, c):  [0.86880883 4.93635681]
# error of particle- 19 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.48099407 6.27529013]
# error of particle- 20 is (training, test) (0.014492753623188406, 0.17391304347826086)  At (gamma, c):  [0.21356621 6.34028413]
# error of particle- 21 is (training, test) (0.009057971014492754, 0.21014492753623187)  At (gamma, c):  [0.6223295  5.22656358]
# error of particle- 22 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.82281471 4.54836124]
# error of particle- 23 is (training, test) (0.007246376811594203, 0.2391304347826087)  At (gamma, c):  [0.75141617 6.14555111]
# error of particle- 24 is (training, test) (0.016304347826086956, 0.18115942028985507)  At (gamma, c):  [0.21216482 5.59173494]
# error of particle- 25 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [2.1389793 3.9376105]
# error of particle- 26 is (training, test) (0.0018115942028985507, 0.427536231884058)  At (gamma, c):  [1.84235531 5.28582798]
# error of particle- 27 is (training, test) (0.0018115942028985507, 0.4420289855072464)  At (gamma, c):  [1.95360734 5.32310695]
# error of particle- 28 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [1.99998945 4.7401587 ]
# error of particle- 29 is (training, test) (0.016304347826086956, 0.17391304347826086)  At (gamma, c):  [0.18731148 5.35598569]
# error of particle- 30 is (training, test) (0.014492753623188406, 0.17391304347826086)  At (gamma, c):  [0.23456294 5.80891199]
# error of particle- 31 is (training, test) (0.012681159420289856, 0.17391304347826086)  At (gamma, c):  [0.25377566 5.6816354 ]
# error of particle- 32 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.47164076 5.79022602]
# error of particle- 33 is (training, test) (0.010869565217391304, 0.18115942028985507)  At (gamma, c):  [0.28501933 6.17867671]
# error of particle- 34 is (training, test) (0.009057971014492754, 0.17391304347826086)  At (gamma, c):  [0.40752647 6.00791279]
# error of particle- 35 is (training, test) (0.0036231884057971015, 0.39855072463768115)  At (gamma, c):  [1.69103132 6.26680993]
# error of particle- 36 is (training, test) (0.0, 0.463768115942029)  At (gamma, c):  [3.71550428 7.00221912]
# error of particle- 37 is (training, test) (0.007246376811594203, 0.2753623188405797)  At (gamma, c):  [0.90061651 4.76877436]
# error of particle- 38 is (training, test) (0.009057971014492754, 0.17391304347826086)  At (gamma, c):  [0.36825352 6.74853315]
# error of particle- 39 is (training, test) (0.007246376811594203, 0.2753623188405797)  At (gamma, c):  [0.94389886 5.11407427]
# error of particle- 40 is (training, test) (0.0018115942028985507, 0.43478260869565216)  At (gamma, c):  [1.88048493 5.11285507]
# error of particle- 41 is (training, test) (0.0036231884057971015, 0.34782608695652173)  At (gamma, c):  [1.32670358 6.40814067]
# error of particle- 42 is (training, test) (0.005434782608695652, 0.2898550724637681)  At (gamma, c):  [1.02014635 5.19208607]
# error of particle- 43 is (training, test) (0.0036231884057971015, 0.3695652173913043)  At (gamma, c):  [1.41605705 6.12684422]
# error of particle- 44 is (training, test) (0.007246376811594203, 0.2826086956521739)  At (gamma, c):  [1.00995213 4.82790456]
# error of particle- 45 is (training, test) (0.0036231884057971015, 0.32608695652173914)  At (gamma, c):  [1.28902004 5.39746843]
# error of particle- 46 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.35601595 4.90481683]
# error of particle- 47 is (training, test) (0.0018115942028985507, 0.4057971014492754)  At (gamma, c):  [1.73494299 3.84162862]
# error of particle- 48 is (training, test) (0.009057971014492754, 0.17391304347826086)  At (gamma, c):  [0.39255045 5.58212174]
# error of particle- 49 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.18714682 5.76519226]
# error of particle- 50 is (training, test) (0.005434782608695652, 0.3115942028985507)  At (gamma, c):  [1.0706549 4.8390743]
# error of particle- 51 is (training, test) (0.005434782608695652, 0.3115942028985507)  At (gamma, c):  [1.09805385 4.89407094]
# error of particle- 52 is (training, test) (0.0036231884057971015, 0.391304347826087)  At (gamma, c):  [1.5438954  5.82344942]
# error of particle- 53 is (training, test) (0.0036231884057971015, 0.3188405797101449)  At (gamma, c):  [1.22771778 5.0678037 ]
# error of particle- 54 is (training, test) (0.0018115942028985507, 0.43478260869565216)  At (gamma, c):  [1.86369024 6.11870077]
# error of particle- 55 is (training, test) (0.0036231884057971015, 0.39855072463768115)  At (gamma, c):  [1.63638445 6.14407552]
# error of particle- 56 is (training, test) (0.0036231884057971015, 0.391304347826087)  At (gamma, c):  [1.48401107 4.68558964]
# error of particle- 57 is (training, test) (0.009057971014492754, 0.18840579710144928)  At (gamma, c):  [0.57089063 5.37461877]
# error of particle- 58 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [2.02135176 4.63096149]
# error of particle- 59 is (training, test) (0.010869565217391304, 0.18115942028985507)  At (gamma, c):  [0.28366216 6.4281394 ]
# error of particle- 60 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.1865138  5.56550489]
# error of particle- 61 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [2.02247506 5.36244025]
# error of particle- 62 is (training, test) (0.014492753623188406, 0.18115942028985507)  At (gamma, c):  [0.22942732 5.80029233]
# error of particle- 63 is (training, test) (0.0036231884057971015, 0.39855072463768115)  At (gamma, c):  [1.66652407 5.57340009]
# error of particle- 64 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.14081836 4.9929358 ]
# error of particle- 65 is (training, test) (0.009057971014492754, 0.21014492753623187)  At (gamma, c):  [0.62280781 5.3707338 ]
# error of particle- 66 is (training, test) (0.009057971014492754, 0.21739130434782608)  At (gamma, c):  [0.62137091 6.09332649]
# error of particle- 67 is (training, test) (0.009057971014492754, 0.2246376811594203)  At (gamma, c):  [0.70863569 4.94173568]
# error of particle- 68 is (training, test) (0.0018115942028985507, 0.43478260869565216)  At (gamma, c):  [1.870706  6.4857159]
# error of particle- 69 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.48094718 5.40603305]
# error of particle- 70 is (training, test) (0.007246376811594203, 0.2391304347826087)  At (gamma, c):  [0.78181685 5.41530309]
# error of particle- 71 is (training, test) (0.0036231884057971015, 0.391304347826087)  At (gamma, c):  [1.52272089 5.80100067]
# error of particle- 72 is (training, test) (0.009057971014492754, 0.21014492753623187)  At (gamma, c):  [0.63193383 5.17131129]
# error of particle- 73 is (training, test) (0.009057971014492754, 0.17391304347826086)  At (gamma, c):  [0.36890288 5.31287512]
# error of particle- 74 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.32631773 4.35799012]
# error of particle- 75 is (training, test) (0.007246376811594203, 0.26811594202898553)  At (gamma, c):  [0.83879756 5.39623126]
# error of particle- 76 is (training, test) (0.03260869565217391, 0.16666666666666666)  At (gamma, c):  [0.12494397 6.27145444]
# error of particle- 77 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.21636715 5.87554077]
# error of particle- 78 is (training, test) (0.0, 0.4492753623188406)  At (gamma, c):  [2.14768719 5.08784108]
# error of particle- 79 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.14089182 5.28366174]
# error of particle- 80 is (training, test) (0.0018115942028985507, 0.4492753623188406)  At (gamma, c):  [2.1552936  4.36400911]
# error of particle- 81 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.36230721 5.047402  ]
# error of particle- 82 is (training, test) (0.016304347826086956, 0.17391304347826086)  At (gamma, c):  [0.19043043 5.90332324]
# error of particle- 83 is (training, test) (0.007246376811594203, 0.2753623188405797)  At (gamma, c):  [0.95377639 5.02464813]
# error of particle- 84 is (training, test) (0.0036231884057971015, 0.4057971014492754)  At (gamma, c):  [1.73453957 5.94036694]
# error of particle- 85 is (training, test) (0.05434782608695652, 0.15942028985507245)  At (gamma, c):  [0.06721611 5.35056351]
# error of particle- 86 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.48352578 5.49828437]
# error of particle- 87 is (training, test) (0.007246376811594203, 0.2246376811594203)  At (gamma, c):  [0.68624313 6.13102943]
# error of particle- 88 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.01771084 4.25400012]
# error of particle- 89 is (training, test) (0.009057971014492754, 0.18840579710144928)  At (gamma, c):  [0.58272518 6.21225258]
# error of particle- 90 is (training, test) (0.036231884057971016, 0.17391304347826086)  At (gamma, c):  [0.11685255 6.17802948]
# error of particle- 91 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.44408098 6.80161521]
# error of particle- 92 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [3.04422218 5.05359159]
# error of particle- 93 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.97980175 6.15858162]
# error of particle- 94 is (training, test) (0.009057971014492754, 0.2246376811594203)  At (gamma, c):  [0.67884494 4.6826185 ]
# error of particle- 95 is (training, test) (0.0, 0.43478260869565216)  At (gamma, c):  [2.8077765  5.46346614]
# error of particle- 96 is (training, test) (0.0036231884057971015, 0.391304347826087)  At (gamma, c):  [1.569229   6.14013718]
# error of particle- 97 is (training, test) (0.009057971014492754, 0.18115942028985507)  At (gamma, c):  [0.49600181 5.29453828]
# error of particle- 98 is (training, test) (0.005434782608695652, 0.2753623188405797)  At (gamma, c):  [0.98814223 5.78309817]
# error of particle- 99 is (training, test) (0.0018115942028985507, 0.43478260869565216)  At (gamma, c):  [1.90264288 4.99267443]
# error of particle- 100 is (training, test) (0.0036231884057971015, 0.3115942028985507)  At (gamma, c):  [1.22090187 5.13494936]
# The best position is  [0.06721611 5.35056351] in iteration number 10 with error rate (train, test): (0.05434782608695652, 0.15942028985507245)
