# %%
import pandas as pd
import numpy as np
import random
import csv
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix  
import matplotlib.pyplot as plt

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/heart/"
colnames = ['x1', 'x2', 'x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13','y']
data = pd.read_csv(url, sep = ' ', header = None, names = colnames)
X = data.drop('y', axis = 1)
X = (X-X.mean())/X.std()
y = data['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
#################### I N P U T ####################
W = 0.5
c1 = 0.2
c2 = 0.5

n_iterations = int(input("Inform the number of iterations: "))
n_particles = int(input("Inform the number of particles: "))
# Out:
# Inform the number of iterations: 10
# Inform the number of particles: 100

# %%
#mencari nilai 0-1 loss dari tiap partikel
#partikle = (gamma,C) untuk rbf
def fitness_function(position):
    svclassifier = SVC(kernel='rbf', gamma = position[0], C = position[1] )  
    svclassifier.fit(X_train, y_train)
    y_train_pred = svclassifier.predict(X_train)
    y_test_pred = svclassifier.predict(X_test)   
    return confusion_matrix(y_train,y_train_pred)[0][1] + confusion_matrix(y_train,y_train_pred)[1][0], confusion_matrix(y_test,y_test_pred)[0][1] + confusion_matrix(y_test,y_test_pred)[1][0]

#plotting (x axis = gamma, y axis = C)
def plot(position):
    x = []
    y = []
    for i in range(0,len(particle_position_vector)):
        x.append(particle_position_vector[i][0])
        y.append(particle_position_vector[i][1])
    colors = (0,0,0)
    plt.scatter(x, y, c = colors, alpha = 0.1)
    plt.xlabel('C')
    plt.ylabel('gamma')
    plt.axis([0,10,0,10])
    plt.gca().set_aspect('equal', adjustable='box')
    return plt.show()

# %%
particle_position_vector = np.array([np.array([random.random()*10, random.random()*10]) for _ in range(n_particles)])
pbest_position = particle_position_vector
pbest_fitness_value = np.array([float('inf') for _ in range(n_particles)])
gbest_fitness_value = np.array([float('inf'), float('inf')])
gbest_position = np.array([float('inf'), float('inf')])

velocity_vector = ([np.array([0, 0]) for _ in range(n_particles)])
iteration = 0
while iteration < n_iterations:
    plot(particle_position_vector)
    for i in range(n_particles):
        fitness_cadidate = fitness_function(particle_position_vector[i])
        print("error of particle-",i,"is (training, test)", fitness_cadidate, " At (gamma, c): ", particle_position_vector[i])
        
        if(pbest_fitness_value[i] > fitness_cadidate[1]):
            pbest_fitness_value[i] = fitness_cadidate[1]
            pbest_position[i] = particle_position_vector[i]

        if(gbest_fitness_value[1] > fitness_cadidate[1]):
            gbest_fitness_value = fitness_cadidate
            gbest_position = particle_position_vector[i]
        elif(gbest_fitness_value[1] == fitness_cadidate[1] and gbest_fitness_value[0] > fitness_cadidate[0]):
            gbest_fitness_value = fitness_cadidate
            gbest_position = particle_position_vector[i]
            
    for i in range(n_particles):
        new_velocity = (W*velocity_vector[i]) + (c1*random.random()) * (pbest_position[i] - particle_position_vector[i]) + (c2*random.random()) * (gbest_position-particle_position_vector[i])
        new_position = new_velocity + particle_position_vector[i]
        particle_position_vector[i] = new_position
        
    iteration = iteration + 1
    
print("The best position is ", gbest_position, "in iteration number", iteration, "with error (train, test):", fitness_function(gbest_position))
# Out:
# error of particle- 0 is (training, test) (0, 21)  At (gamma, c):  [ 6.22766983  1.39042593]
# error of particle- 1 is (training, test) (0, 21)  At (gamma, c):  [ 1.39832526  2.47140193]
# error of particle- 2 is (training, test) (0, 21)  At (gamma, c):  [ 6.81926342  0.87505542]
# error of particle- 3 is (training, test) (0, 21)  At (gamma, c):  [ 7.99004245  7.92534683]
# error of particle- 4 is (training, test) (0, 21)  At (gamma, c):  [ 7.21798015  7.78483616]
# error of particle- 5 is (training, test) (0, 21)  At (gamma, c):  [ 6.77270178  6.08532638]
# error of particle- 6 is (training, test) (0, 21)  At (gamma, c):  [ 9.09172638  3.4237735 ]
# error of particle- 7 is (training, test) (0, 21)  At (gamma, c):  [ 3.1671377  6.2219737]
# error of particle- 8 is (training, test) (0, 21)  At (gamma, c):  [ 4.2923195   4.67897991]
# error of particle- 9 is (training, test) (0, 21)  At (gamma, c):  [ 4.26962116  3.19840265]
# error of particle- 10 is (training, test) (21, 6)  At (gamma, c):  [ 0.02411098  7.3876421 ]
# error of particle- 11 is (training, test) (0, 21)  At (gamma, c):  [ 5.55322345  4.14007739]
# error of particle- 12 is (training, test) (0, 21)  At (gamma, c):  [ 1.18831858  6.06869955]
# error of particle- 13 is (training, test) (0, 21)  At (gamma, c):  [ 3.68274458  1.00666294]
# error of particle- 14 is (training, test) (0, 21)  At (gamma, c):  [ 7.01896043  4.73575807]
# error of particle- 15 is (training, test) (15, 8)  At (gamma, c):  [ 0.04165294  5.57438755]
# error of particle- 16 is (training, test) (0, 21)  At (gamma, c):  [ 7.45707065  6.20312653]
# error of particle- 17 is (training, test) (0, 16)  At (gamma, c):  [ 0.90008181  2.25479266]
# error of particle- 18 is (training, test) (0, 21)  At (gamma, c):  [ 5.1480037   3.75052787]
# error of particle- 19 is (training, test) (99, 21)  At (gamma, c):  [ 8.54159044  0.45579984]
# error of particle- 20 is (training, test) (99, 21)  At (gamma, c):  [ 9.66211837  0.40354878]
# error of particle- 21 is (training, test) (0, 21)  At (gamma, c):  [ 7.08708855  4.50488882]
# error of particle- 22 is (training, test) (0, 21)  At (gamma, c):  [ 7.08730372  7.42701006]
# error of particle- 23 is (training, test) (3, 11)  At (gamma, c):  [ 0.17806537  2.15272612]
# error of particle- 24 is (training, test) (99, 21)  At (gamma, c):  [ 5.12761545  0.40655522]
# error of particle- 25 is (training, test) (0, 21)  At (gamma, c):  [ 1.90281672  6.78450531]
# error of particle- 26 is (training, test) (0, 21)  At (gamma, c):  [ 9.23973797  5.22402733]
# error of particle- 27 is (training, test) (0, 21)  At (gamma, c):  [ 4.12143881  6.33104723]
# error of particle- 28 is (training, test) (0, 21)  At (gamma, c):  [ 3.88072713  3.99659857]
# error of particle- 29 is (training, test) (0, 21)  At (gamma, c):  [ 3.59036425  8.3770712 ]
# error of particle- 30 is (training, test) (0, 15)  At (gamma, c):  [ 0.79641995  1.25790621]
# error of particle- 31 is (training, test) (0, 21)  At (gamma, c):  [ 4.87162036  5.35718484]
# error of particle- 32 is (training, test) (0, 21)  At (gamma, c):  [ 2.18993757  9.97032494]
# error of particle- 33 is (training, test) (0, 21)  At (gamma, c):  [ 9.98139101  8.70017064]
# error of particle- 34 is (training, test) (0, 21)  At (gamma, c):  [ 3.67544974  1.9166444 ]
# error of particle- 35 is (training, test) (0, 21)  At (gamma, c):  [ 4.68937697  0.63009652]
# error of particle- 36 is (training, test) (1, 21)  At (gamma, c):  [ 1.42820656  0.57613791]
# error of particle- 37 is (training, test) (0, 21)  At (gamma, c):  [ 6.08096772  9.31781739]
# error of particle- 38 is (training, test) (0, 21)  At (gamma, c):  [ 5.25247527  8.6002521 ]
# error of particle- 39 is (training, test) (0, 21)  At (gamma, c):  [ 8.87653347  2.68931251]
# error of particle- 40 is (training, test) (0, 21)  At (gamma, c):  [ 3.7012399   6.03109957]
# error of particle- 41 is (training, test) (0, 21)  At (gamma, c):  [ 5.0196492   9.36117905]
# error of particle- 42 is (training, test) (0, 21)  At (gamma, c):  [ 8.65134462  1.99432568]
# error of particle- 43 is (training, test) (0, 21)  At (gamma, c):  [ 2.70600868  6.33782954]
# error of particle- 44 is (training, test) (0, 21)  At (gamma, c):  [ 5.72000944  8.88324883]
# error of particle- 45 is (training, test) (0, 21)  At (gamma, c):  [ 1.89676362  5.28840535]
# error of particle- 46 is (training, test) (0, 21)  At (gamma, c):  [ 2.10941034  9.99274694]
# error of particle- 47 is (training, test) (0, 21)  At (gamma, c):  [ 9.20476789  1.73239022]
# error of particle- 48 is (training, test) (0, 21)  At (gamma, c):  [ 4.70107593  4.21492033]
# error of particle- 49 is (training, test) (0, 21)  At (gamma, c):  [ 5.36412176  6.0452124 ]
# error of particle- 50 is (training, test) (0, 21)  At (gamma, c):  [ 8.21077325  4.07372656]
# error of particle- 51 is (training, test) (0, 21)  At (gamma, c):  [ 3.71608003  0.86370924]
# error of particle- 52 is (training, test) (0, 21)  At (gamma, c):  [ 8.54610668  1.83183662]
# error of particle- 53 is (training, test) (0, 21)  At (gamma, c):  [ 8.76185216  1.91181988]
# error of particle- 54 is (training, test) (0, 16)  At (gamma, c):  [ 0.85981475  1.7310476 ]
# error of particle- 55 is (training, test) (0, 21)  At (gamma, c):  [ 7.66707513  9.81710134]
# error of particle- 56 is (training, test) (0, 21)  At (gamma, c):  [ 7.96392078  3.7022758 ]
# error of particle- 57 is (training, test) (0, 21)  At (gamma, c):  [ 4.48199497  2.85905883]
# error of particle- 58 is (training, test) (0, 21)  At (gamma, c):  [ 4.12097835  7.03148117]
# error of particle- 59 is (training, test) (0, 21)  At (gamma, c):  [ 2.97309553  5.54876645]
# error of particle- 60 is (training, test) (0, 21)  At (gamma, c):  [ 8.32556393  1.90460685]
# error of particle- 61 is (training, test) (0, 21)  At (gamma, c):  [ 9.5183385   1.48598213]
# error of particle- 62 is (training, test) (0, 21)  At (gamma, c):  [ 1.79808776  4.14544268]
# error of particle- 63 is (training, test) (0, 21)  At (gamma, c):  [ 7.47404473  7.17912866]
# error of particle- 64 is (training, test) (0, 21)  At (gamma, c):  [ 7.45110048  4.37028403]
# error of particle- 65 is (training, test) (0, 21)  At (gamma, c):  [ 7.61625597  3.47256192]
# error of particle- 66 is (training, test) (0, 21)  At (gamma, c):  [ 5.29514807  4.44058667]
# error of particle- 67 is (training, test) (0, 21)  At (gamma, c):  [ 3.82473332  6.27861343]
# error of particle- 68 is (training, test) (0, 21)  At (gamma, c):  [ 2.24394338  1.42626607]
# error of particle- 69 is (training, test) (0, 21)  At (gamma, c):  [ 3.89887182  1.73931993]
# error of particle- 70 is (training, test) (97, 21)  At (gamma, c):  [ 0.63937093  0.26611434]
# error of particle- 71 is (training, test) (0, 10)  At (gamma, c):  [ 0.32827441  9.94607437]
# error of particle- 72 is (training, test) (0, 21)  At (gamma, c):  [ 3.25110844  3.44833698]
# error of particle- 73 is (training, test) (0, 21)  At (gamma, c):  [ 4.78665233  4.89140309]
# error of particle- 74 is (training, test) (0, 21)  At (gamma, c):  [ 6.02302576  9.8811657 ]
# error of particle- 75 is (training, test) (0, 21)  At (gamma, c):  [ 2.99522965  5.16919549]
# error of particle- 76 is (training, test) (0, 21)  At (gamma, c):  [ 4.10148135  3.94421967]
# error of particle- 77 is (training, test) (0, 21)  At (gamma, c):  [ 3.70122811  9.92445684]
# error of particle- 78 is (training, test) (0, 21)  At (gamma, c):  [ 6.76841896  8.60181716]
# error of particle- 79 is (training, test) (0, 21)  At (gamma, c):  [ 6.16550019  5.86894592]
# error of particle- 80 is (training, test) (0, 21)  At (gamma, c):  [ 5.74214965  7.55048321]
# error of particle- 81 is (training, test) (0, 21)  At (gamma, c):  [ 5.30486974  9.82253319]
# error of particle- 82 is (training, test) (0, 21)  At (gamma, c):  [ 1.70075001  4.79481382]
# error of particle- 83 is (training, test) (0, 21)  At (gamma, c):  [ 4.81166074  9.83394221]
# error of particle- 84 is (training, test) (0, 10)  At (gamma, c):  [ 0.43742133  6.98651781]
# error of particle- 85 is (training, test) (0, 21)  At (gamma, c):  [ 1.78150909  7.7256762 ]
# error of particle- 86 is (training, test) (0, 21)  At (gamma, c):  [ 5.51363565  6.0181508 ]
# error of particle- 87 is (training, test) (0, 21)  At (gamma, c):  [ 6.04922766  9.48880631]
# error of particle- 88 is (training, test) (0, 21)  At (gamma, c):  [ 4.73759917  4.53576084]
# error of particle- 89 is (training, test) (0, 21)  At (gamma, c):  [ 2.95744427  9.99120085]
# error of particle- 90 is (training, test) (0, 21)  At (gamma, c):  [ 8.6090495   7.50779107]
# error of particle- 91 is (training, test) (0, 21)  At (gamma, c):  [ 8.36820065  3.06834203]
# error of particle- 92 is (training, test) (0, 21)  At (gamma, c):  [ 1.83278384  3.57251809]
# error of particle- 93 is (training, test) (99, 21)  At (gamma, c):  [ 2.69259524  0.03727181]
# error of particle- 94 is (training, test) (0, 21)  At (gamma, c):  [ 7.77592885  4.2495258 ]
# error of particle- 95 is (training, test) (0, 21)  At (gamma, c):  [ 3.22616783  4.38680744]
# error of particle- 96 is (training, test) (0, 21)  At (gamma, c):  [ 7.38300567  8.97460986]
# error of particle- 97 is (training, test) (0, 21)  At (gamma, c):  [ 4.35153181  8.59297055]
# error of particle- 98 is (training, test) (0, 21)  At (gamma, c):  [ 1.81471637  9.21682795]
# error of particle- 99 is (training, test) (0, 21)  At (gamma, c):  [ 2.44773575  8.80396636]
# error of particle- 0 is (training, test) (0, 21)  At (gamma, c):  [ 5.59353764  2.00346563]
# error of particle- 1 is (training, test) (0, 19)  At (gamma, c):  [ 1.06145066  3.676568  ]
# error of particle- 2 is (training, test) (0, 21)  At (gamma, c):  [ 5.68294948  1.96411752]
# error of particle- 3 is (training, test) (0, 21)  At (gamma, c):  [ 4.42120286  7.6844482 ]
# error of particle- 4 is (training, test) (0, 21)  At (gamma, c):  [ 6.97212368  7.77126172]
# error of particle- 5 is (training, test) (0, 21)  At (gamma, c):  [ 4.88681568  6.44925704]
# error of particle- 6 is (training, test) (0, 21)  At (gamma, c):  [ 7.75272123  4.00911377]
# error of particle- 7 is (training, test) (0, 21)  At (gamma, c):  [ 2.73164575  6.38348655]
# error of particle- 8 is (training, test) (0, 21)  At (gamma, c):  [ 4.01247714  4.85657161]
# error of particle- 9 is (training, test) (0, 21)  At (gamma, c):  [ 3.55391953  3.90461825]
# error of particle- 10 is (training, test) (21, 6)  At (gamma, c):  [ 0.02411098  7.3876421 ]
# error of particle- 11 is (training, test) (0, 21)  At (gamma, c):  [ 2.99936092  5.64010725]
# error of particle- 12 is (training, test) (0, 19)  At (gamma, c):  [ 1.07288996  6.1994698 ]
# error of particle- 13 is (training, test) (0, 21)  At (gamma, c):  [ 3.06504182  2.08399095]
# error of particle- 14 is (training, test) (0, 21)  At (gamma, c):  [ 3.74903353  5.97545122]
# error of particle- 15 is (training, test) (15, 8)  At (gamma, c):  [ 0.0415709   5.58286869]
# error of particle- 16 is (training, test) (0, 21)  At (gamma, c):  [ 6.54265212  6.34884816]
# error of particle- 17 is (training, test) (0, 15)  At (gamma, c):  [ 0.69465371  3.45852166]
# error of particle- 18 is (training, test) (0, 21)  At (gamma, c):  [ 3.64610489  4.81662699]
# error of particle- 19 is (training, test) (0, 21)  At (gamma, c):  [ 6.9600268   1.74293528]
# error of particle- 20 is (training, test) (0, 21)  At (gamma, c):  [ 6.3156009   2.82857185]
# error of particle- 21 is (training, test) (0, 21)  At (gamma, c):  [ 6.15425211  4.88562588]
# error of particle- 22 is (training, test) (0, 21)  At (gamma, c):  [ 5.16635606  7.41630332]
# error of particle- 23 is (training, test) (3, 11)  At (gamma, c):  [ 0.10732339  4.55816804]
# error of particle- 24 is (training, test) (0, 21)  At (gamma, c):  [ 2.72379224  3.69474645]
# error of particle- 25 is (training, test) (0, 21)  At (gamma, c):  [ 1.31114562  6.97445449]
# error of particle- 26 is (training, test) (0, 21)  At (gamma, c):  [ 8.50449515  5.39664524]
# error of particle- 27 is (training, test) (0, 21)  At (gamma, c):  [ 3.47010619  6.49900906]
# error of particle- 28 is (training, test) (0, 21)  At (gamma, c):  [ 3.14373331  4.64462212]
# error of particle- 29 is (training, test) (0, 21)  At (gamma, c):  [ 2.9976896   8.21263825]
# error of particle- 30 is (training, test) (0, 15)  At (gamma, c):  [ 0.59006701  2.89570803]
# error of particle- 31 is (training, test) (0, 21)  At (gamma, c):  [ 3.62544827  5.87916406]
# error of particle- 32 is (training, test) (0, 21)  At (gamma, c):  [ 1.61676772  9.28683719]
# error of particle- 33 is (training, test) (0, 21)  At (gamma, c):  [ 8.64260726  8.52369756]
# error of particle- 34 is (training, test) (0, 21)  At (gamma, c):  [ 3.0063856   2.91913926]
# error of particle- 35 is (training, test) (0, 21)  At (gamma, c):  [ 4.0607416   1.54066243]
# error of particle- 36 is (training, test) (0, 21)  At (gamma, c):  [ 1.36000368  0.90700159]
# error of particle- 37 is (training, test) (0, 21)  At (gamma, c):  [ 5.90522937  9.26181378]
# error of particle- 38 is (training, test) (0, 21)  At (gamma, c):  [ 2.82464233  8.03716691]
# error of particle- 39 is (training, test) (0, 21)  At (gamma, c):  [ 5.54244671  4.45884378]
# error of particle- 40 is (training, test) (0, 21)  At (gamma, c):  [ 1.86932962  6.70691602]
# error of particle- 41 is (training, test) (0, 21)  At (gamma, c):  [ 4.6978891   9.23406452]
# error of particle- 42 is (training, test) (0, 21)  At (gamma, c):  [ 6.18405668  3.53675111]
# error of particle- 43 is (training, test) (0, 21)  At (gamma, c):  [ 2.62227322  6.37060728]
# error of particle- 44 is (training, test) (0, 21)  At (gamma, c):  [ 2.97097222  8.16141739]
# error of particle- 45 is (training, test) (0, 21)  At (gamma, c):  [ 1.50317128  5.72962092]
# error of particle- 46 is (training, test) (0, 21)  At (gamma, c):  [ 1.29360623  8.9735862 ]
# error of particle- 47 is (training, test) (0, 21)  At (gamma, c):  [ 8.17091224  2.36924161]
# error of particle- 48 is (training, test) (0, 21)  At (gamma, c):  [ 4.64314969  4.25421587]
# error of particle- 49 is (training, test) (0, 21)  At (gamma, c):  [ 3.57906368  6.49395962]
# error of particle- 50 is (training, test) (0, 21)  At (gamma, c):  [ 7.19875871  4.48338444]
# error of particle- 51 is (training, test) (0, 21)  At (gamma, c):  [ 3.2037457   1.76903502]
# error of particle- 52 is (training, test) (0, 21)  At (gamma, c):  [ 4.96366709  4.16736203]
# error of particle- 53 is (training, test) (0, 21)  At (gamma, c):  [ 5.41307582  4.01045195]
# error of particle- 54 is (training, test) (0, 15)  At (gamma, c):  [ 0.61157881  3.41127225]
# error of particle- 55 is (training, test) (0, 21)  At (gamma, c):  [ 5.98578654  9.28267228]
# error of particle- 56 is (training, test) (0, 21)  At (gamma, c):  [ 4.40070416  5.35618928]
# error of particle- 57 is (training, test) (0, 21)  At (gamma, c):  [ 4.25410438  3.09056362]
# error of particle- 58 is (training, test) (0, 21)  At (gamma, c):  [ 2.3928808   7.18171323]
# error of particle- 59 is (training, test) (0, 21)  At (gamma, c):  [ 2.5477086  5.8140217]
# error of particle- 60 is (training, test) (0, 21)  At (gamma, c):  [ 4.82502066  4.21668429]
# error of particle- 61 is (training, test) (0, 21)  At (gamma, c):  [ 9.4264692   1.54308855]
# error of particle- 62 is (training, test) (0, 18)  At (gamma, c):  [ 0.98710217  5.62763625]
# error of particle- 63 is (training, test) (0, 21)  At (gamma, c):  [ 5.29003181  7.24025619]
# error of particle- 64 is (training, test) (0, 21)  At (gamma, c):  [ 6.63365608  4.70238662]
# error of particle- 65 is (training, test) (0, 21)  At (gamma, c):  [ 5.91967038  4.34744888]
# error of particle- 66 is (training, test) (0, 21)  At (gamma, c):  [ 3.26475607  5.575786  ]
# error of particle- 67 is (training, test) (0, 21)  At (gamma, c):  [ 2.68506329  6.61117127]
# error of particle- 68 is (training, test) (0, 21)  At (gamma, c):  [ 1.75851574  2.72988551]
# error of particle- 69 is (training, test) (0, 21)  At (gamma, c):  [ 2.98020971  3.07847343]
# error of particle- 70 is (training, test) (72, 21)  At (gamma, c):  [ 0.62549907  0.42667864]
# error of particle- 71 is (training, test) (0, 9)  At (gamma, c):  [ 0.26092909  9.37960771]
# error of particle- 72 is (training, test) (0, 21)  At (gamma, c):  [ 2.61077151  4.23001796]
# error of particle- 73 is (training, test) (0, 21)  At (gamma, c):  [ 4.71070759  4.93120877]
# error of particle- 74 is (training, test) (0, 21)  At (gamma, c):  [ 5.94704835  9.84958474]
# error of particle- 75 is (training, test) (0, 21)  At (gamma, c):  [ 2.26234222  5.71642091]
# error of particle- 76 is (training, test) (0, 21)  At (gamma, c):  [ 2.36325994  5.4121831 ]
# error of particle- 77 is (training, test) (0, 21)  At (gamma, c):  [ 2.43658535  9.05198956]
# error of particle- 78 is (training, test) (0, 21)  At (gamma, c):  [ 3.85265767  8.07689382]
# error of particle- 79 is (training, test) (0, 21)  At (gamma, c):  [ 3.59179846  6.50539328]
# error of particle- 80 is (training, test) (0, 21)  At (gamma, c):  [ 3.1496292   7.47665214]
# error of particle- 81 is (training, test) (0, 21)  At (gamma, c):  [ 4.98174566  9.67354476]
# error of particle- 82 is (training, test) (0, 21)  At (gamma, c):  [ 1.2838169   5.43957751]
# error of particle- 83 is (training, test) (0, 21)  At (gamma, c):  [ 3.56162743  9.19521117]
# error of particle- 84 is (training, test) (0, 10)  At (gamma, c):  [ 0.40780882  7.01525722]
# error of particle- 85 is (training, test) (0, 21)  At (gamma, c):  [ 1.19195062  7.61227511]
# error of particle- 86 is (training, test) (0, 21)  At (gamma, c):  [ 5.34553436  6.06008763]
# error of particle- 87 is (training, test) (0, 21)  At (gamma, c):  [ 4.51339688  8.9532096 ]
# error of particle- 88 is (training, test) (0, 21)  At (gamma, c):  [ 2.71477524  5.75966412]
# error of particle- 89 is (training, test) (0, 21)  At (gamma, c):  [ 2.65694978  9.7244889 ]
# error of particle- 90 is (training, test) (0, 21)  At (gamma, c):  [ 6.00859887  7.47139693]
# error of particle- 91 is (training, test) (0, 21)  At (gamma, c):  [ 8.01282827  3.25229978]
# error of particle- 92 is (training, test) (0, 16)  At (gamma, c):  [ 0.92846701  5.48003874]
# error of particle- 93 is (training, test) (90, 21)  At (gamma, c):  [ 2.51557418  0.52487834]
# error of particle- 94 is (training, test) (0, 21)  At (gamma, c):  [ 6.48530992  4.77199838]
# error of particle- 95 is (training, test) (0, 21)  At (gamma, c):  [ 2.84169843  4.74711619]
# error of particle- 96 is (training, test) (0, 21)  At (gamma, c):  [ 5.59902053  8.5898881 ]
# error of particle- 97 is (training, test) (0, 21)  At (gamma, c):  [ 2.93008046  8.19704979]
# error of particle- 98 is (training, test) (0, 21)  At (gamma, c):  [ 1.37087486  8.76342341]
# error of particle- 99 is (training, test) (0, 21)  At (gamma, c):  [ 1.81689223  8.43531236]
# error of particle- 0 is (training, test) (0, 21)  At (gamma, c):  [ 3.47884282  4.0478215 ]
# error of particle- 1 is (training, test) (0, 18)  At (gamma, c):  [ 1.01922444  3.82763194]
# error of particle- 2 is (training, test) (0, 21)  At (gamma, c):  [ 5.67873621  1.96815559]
# error of particle- 3 is (training, test) (0, 21)  At (gamma, c):  [ 3.68445235  7.63471714]
# error of particle- 4 is (training, test) (0, 21)  At (gamma, c):  [ 3.80167892  7.59621241]
# error of particle- 5 is (training, test) (0, 21)  At (gamma, c):  [ 4.74832197  6.475983  ]
# error of particle- 6 is (training, test) (0, 21)  At (gamma, c):  [ 4.61392237  5.38122603]
# error of particle- 7 is (training, test) (0, 21)  At (gamma, c):  [ 1.93171216  6.6801615 ]
# error of particle- 8 is (training, test) (0, 21)  At (gamma, c):  [ 3.02983933  5.4801667 ]
# error of particle- 9 is (training, test) (0, 21)  At (gamma, c):  [ 1.79437444  5.64084202]
# error of particle- 10 is (training, test) (21, 6)  At (gamma, c):  [ 0.02411098  7.3876421 ]
# error of particle- 11 is (training, test) (0, 21)  At (gamma, c):  [ 1.54251123  6.49579859]
# error of particle- 12 is (training, test) (0, 18)  At (gamma, c):  [ 1.01792114  6.26174453]
# error of particle- 13 is (training, test) (0, 21)  At (gamma, c):  [ 2.28835013  3.43860965]
# error of particle- 14 is (training, test) (0, 21)  At (gamma, c):  [ 3.66200801  6.00844429]
# error of particle- 15 is (training, test) (15, 8)  At (gamma, c):  [ 0.04033804  5.71030473]
# error of particle- 16 is (training, test) (0, 21)  At (gamma, c):  [ 5.83113268  6.46223581]
# error of particle- 17 is (training, test) (0, 10)  At (gamma, c):  [ 0.37632432  5.32380845]
# error of particle- 18 is (training, test) (0, 21)  At (gamma, c):  [ 3.07763531  5.22014613]
# error of particle- 19 is (training, test) (0, 21)  At (gamma, c):  [ 3.8804846  4.2491815]
# error of particle- 20 is (training, test) (0, 21)  At (gamma, c):  [ 5.00277832  3.77989665]
# error of particle- 21 is (training, test) (0, 21)  At (gamma, c):  [ 3.20202985  6.09057497]
# error of particle- 22 is (training, test) (0, 21)  At (gamma, c):  [ 4.91069617  7.41487835]
# error of particle- 23 is (training, test) (3, 10)  At (gamma, c):  [ 0.10135401  4.76114479]
# error of particle- 24 is (training, test) (0, 21)  At (gamma, c):  [ 2.06643926  4.59393999]
# error of particle- 25 is (training, test) (0, 21)  At (gamma, c):  [ 1.2671886   6.98856638]
# error of particle- 26 is (training, test) (0, 21)  At (gamma, c):  [ 8.17052437  5.47505381]
# error of particle- 27 is (training, test) (0, 21)  At (gamma, c):  [ 2.70774195  6.69560308]
# error of particle- 28 is (training, test) (0, 21)  At (gamma, c):  [ 2.48697404  5.22209709]
# error of particle- 29 is (training, test) (0, 21)  At (gamma, c):  [ 2.41740126  8.05164179]
# error of particle- 30 is (training, test) (0, 10)  At (gamma, c):  [ 0.43735343  4.1077798 ]
# error of particle- 31 is (training, test) (0, 21)  At (gamma, c):  [ 3.35445632  5.9926734 ]
# error of particle- 32 is (training, test) (0, 21)  At (gamma, c):  [ 1.28249644  8.88822877]
# error of particle- 33 is (training, test) (0, 21)  At (gamma, c):  [ 5.15752027  8.06430743]
# error of particle- 34 is (training, test) (0, 21)  At (gamma, c):  [ 2.56181455  3.58526404]
# error of particle- 35 is (training, test) (0, 21)  At (gamma, c):  [ 3.68707711  2.08190805]
# error of particle- 36 is (training, test) (0, 17)  At (gamma, c):  [ 0.95252207  2.88376351]
# error of particle- 37 is (training, test) (0, 21)  At (gamma, c):  [ 5.63468852  9.17559889]
# error of particle- 38 is (training, test) (0, 21)  At (gamma, c):  [ 2.44710311  7.94960456]
# error of particle- 39 is (training, test) (0, 21)  At (gamma, c):  [ 3.35339056  5.62066218]
# error of particle- 40 is (training, test) (0, 21)  At (gamma, c):  [ 1.83369123  6.7200635 ]
# error of particle- 41 is (training, test) (0, 21)  At (gamma, c):  [ 3.88390693  8.91249279]
# error of particle- 42 is (training, test) (0, 21)  At (gamma, c):  [ 3.49346981  5.21877189]
# error of particle- 43 is (training, test) (0, 21)  At (gamma, c):  [ 2.26768999  6.50940673]
# error of particle- 44 is (training, test) (0, 21)  At (gamma, c):  [ 2.24933561  7.97193287]
# error of particle- 45 is (training, test) (0, 18)  At (gamma, c):  [ 1.02181263  6.26922221]
# error of particle- 46 is (training, test) (0, 21)  At (gamma, c):  [ 1.26913259  8.94301199]
# error of particle- 47 is (training, test) (0, 21)  At (gamma, c):  [ 6.33715461  3.49882976]
# error of particle- 48 is (training, test) (0, 21)  At (gamma, c):  [ 3.22814093  5.2141181 ]
# error of particle- 49 is (training, test) (0, 21)  At (gamma, c):  [ 3.06725639  6.62262327]
# error of particle- 50 is (training, test) (0, 21)  At (gamma, c):  [ 7.13648929  4.50859075]
# error of particle- 51 is (training, test) (0, 21)  At (gamma, c):  [ 2.4734409   3.05952781]
# error of particle- 52 is (training, test) (0, 21)  At (gamma, c):  [ 4.69081415  4.34524499]
# error of particle- 53 is (training, test) (0, 21)  At (gamma, c):  [ 4.16435405  4.79300871]
# error of particle- 54 is (training, test) (0, 11)  At (gamma, c):  [ 0.47700739  4.32214035]
# error of particle- 55 is (training, test) (0, 21)  At (gamma, c):  [ 4.58967993  8.83889366]
# error of particle- 56 is (training, test) (0, 21)  At (gamma, c):  [ 2.24080462  6.35873482]
# error of particle- 57 is (training, test) (0, 21)  At (gamma, c):  [ 3.18181374  4.17986012]
# error of particle- 58 is (training, test) (0, 21)  At (gamma, c):  [ 2.15511038  7.20238379]
# error of particle- 59 is (training, test) (0, 21)  At (gamma, c):  [ 2.36191129  5.92987791]
# error of particle- 60 is (training, test) (0, 21)  At (gamma, c):  [ 2.75429716  5.5843786 ]
# error of particle- 61 is (training, test) (0, 21)  At (gamma, c):  [ 7.07045691  3.00759773]
# error of particle- 62 is (training, test) (0, 15)  At (gamma, c):  [ 0.69581469  6.1600063 ]
# error of particle- 63 is (training, test) (0, 21)  At (gamma, c):  [ 4.48409472  7.26281326]
# error of particle- 64 is (training, test) (0, 21)  At (gamma, c):  [ 4.14358281  5.71402703]
# error of particle- 65 is (training, test) (0, 21)  At (gamma, c):  [ 4.44281362  5.10902714]
# error of particle- 66 is (training, test) (0, 21)  At (gamma, c):  [ 2.65954241  5.91416309]
# error of particle- 67 is (training, test) (0, 21)  At (gamma, c):  [ 2.35063997  6.70875661]
# error of particle- 68 is (training, test) (0, 21)  At (gamma, c):  [ 1.40416563  3.6814953 ]
# error of particle- 69 is (training, test) (0, 21)  At (gamma, c):  [ 2.50738775  3.76771617]
# error of particle- 70 is (training, test) (1, 15)  At (gamma, c):  [ 0.58130728  0.93819106]
# error of particle- 71 is (training, test) (0, 9)  At (gamma, c):  [ 0.25569986  9.33562274]
# error of particle- 72 is (training, test) (0, 21)  At (gamma, c):  [ 1.62408136  5.43450405]
# error of particle- 73 is (training, test) (0, 21)  At (gamma, c):  [ 4.21676686  5.19010293]
# error of particle- 74 is (training, test) (0, 21)  At (gamma, c):  [ 3.79234596  8.95395587]
# error of particle- 75 is (training, test) (0, 21)  At (gamma, c):  [ 1.78112033  6.07573508]
# error of particle- 76 is (training, test) (0, 21)  At (gamma, c):  [ 2.28682464  5.47673426]
# error of particle- 77 is (training, test) (0, 21)  At (gamma, c):  [ 1.56649956  8.45172408]
# error of particle- 78 is (training, test) (0, 21)  At (gamma, c):  [ 2.66668596  7.86338381]
# error of particle- 79 is (training, test) (0, 21)  At (gamma, c):  [ 1.93057931  6.91619401]
# error of particle- 80 is (training, test) (0, 21)  At (gamma, c):  [ 2.63079717  7.46187659]
# error of particle- 81 is (training, test) (0, 21)  At (gamma, c):  [ 2.98293332  8.75191767]
# error of particle- 82 is (training, test) (0, 15)  At (gamma, c):  [ 0.80357602  6.1822431 ]
# error of particle- 83 is (training, test) (0, 21)  At (gamma, c):  [ 3.27516938  9.04883935]
# error of particle- 84 is (training, test) (0, 9)  At (gamma, c):  [ 0.28619261  7.1332877 ]
# error of particle- 85 is (training, test) (0, 15)  At (gamma, c):  [ 0.70111419  7.51786312]
# error of particle- 86 is (training, test) (0, 21)  At (gamma, c):  [ 3.08673174  6.62359917]
# error of particle- 87 is (training, test) (0, 21)  At (gamma, c):  [ 4.07395661  8.79996175]
# error of particle- 88 is (training, test) (0, 21)  At (gamma, c):  [ 2.33052633  5.99215272]
# error of particle- 89 is (training, test) (0, 21)  At (gamma, c):  [ 2.33306703  9.43701806]
# error of particle- 90 is (training, test) (0, 21)  At (gamma, c):  [ 4.19493958  7.44601418]
# error of particle- 91 is (training, test) (0, 21)  At (gamma, c):  [ 6.51487886  4.02771007]
# error of particle- 92 is (training, test) (0, 16)  At (gamma, c):  [ 0.82589852  5.69639159]
# error of particle- 93 is (training, test) (0, 21)  At (gamma, c):  [ 2.31815771  1.06866426]
# error of particle- 94 is (training, test) (0, 21)  At (gamma, c):  [ 3.30340918  6.06010586]
# error of particle- 95 is (training, test) (0, 21)  At (gamma, c):  [ 2.69382021  4.88570151]
# error of particle- 96 is (training, test) (0, 21)  At (gamma, c):  [ 3.40808133  8.11740547]
# error of particle- 97 is (training, test) (0, 21)  At (gamma, c):  [ 2.75822466  8.14918232]
# error of particle- 98 is (training, test) (0, 21)  At (gamma, c):  [ 1.31391874  8.70524011]
# error of particle- 99 is (training, test) (0, 19)  At (gamma, c):  [ 1.0586672  7.9922188]
# error of particle- 0 is (training, test) (0, 21)  At (gamma, c):  [ 2.71627437  4.7850254 ]
# error of particle- 1 is (training, test) (0, 16)  At (gamma, c):  [ 0.62376837  5.24237274]
# error of particle- 2 is (training, test) (0, 21)  At (gamma, c):  [ 5.04150304  2.57889041]
# error of particle- 3 is (training, test) (0, 21)  At (gamma, c):  [ 1.95038078  7.51766636]
# error of particle- 4 is (training, test) (0, 21)  At (gamma, c):  [ 3.07770597  7.5562398 ]
# error of particle- 5 is (training, test) (0, 21)  At (gamma, c):  [ 3.35469345  6.74491978]
# error of particle- 6 is (training, test) (0, 21)  At (gamma, c):  [ 3.48195142  5.8760622 ]
# error of particle- 7 is (training, test) (0, 21)  At (gamma, c):  [ 1.8210283   6.72121132]
# error of particle- 8 is (training, test) (0, 21)  At (gamma, c):  [ 1.67043507  6.34286282]
# error of particle- 9 is (training, test) (0, 18)  At (gamma, c):  [ 0.98081249  6.44362087]
# error of particle- 10 is (training, test) (21, 6)  At (gamma, c):  [ 0.02411098  7.3876421 ]
# error of particle- 11 is (training, test) (0, 21)  At (gamma, c):  [ 1.43204133  6.56068389]
# error of particle- 12 is (training, test) (0, 15)  At (gamma, c):  [ 0.74990242  6.56538565]
# error of particle- 13 is (training, test) (0, 21)  At (gamma, c):  [ 2.00623383  3.93064531]
# error of particle- 14 is (training, test) (0, 21)  At (gamma, c):  [ 2.89384143  6.29967124]
# error of particle- 15 is (training, test) (16, 7)  At (gamma, c):  [ 0.03238705  6.5321724 ]
# error of particle- 16 is (training, test) (0, 21)  At (gamma, c):  [ 3.76957032  6.79076614]
# error of particle- 17 is (training, test) (0, 9)  At (gamma, c):  [ 0.25689573  6.02361371]
# error of particle- 18 is (training, test) (0, 21)  At (gamma, c):  [ 2.24579712  5.81061332]
# error of particle- 19 is (training, test) (0, 21)  At (gamma, c):  [ 1.99628789  5.78261102]
# error of particle- 20 is (training, test) (0, 21)  At (gamma, c):  [ 2.84573595  5.34297754]
# error of particle- 21 is (training, test) (0, 21)  At (gamma, c):  [ 2.12034406  6.53206487]
# error of particle- 22 is (training, test) (0, 21)  At (gamma, c):  [ 4.59347476  7.41311026]
# error of particle- 23 is (training, test) (7, 9)  At (gamma, c):  [ 0.06663949  5.94154392]
# error of particle- 24 is (training, test) (0, 21)  At (gamma, c):  [ 1.30482377  5.63575429]
# error of particle- 25 is (training, test) (0, 19)  At (gamma, c):  [ 1.07412986  7.05054566]
# error of particle- 26 is (training, test) (0, 21)  At (gamma, c):  [ 6.41594923  5.88698722]
# error of particle- 27 is (training, test) (0, 21)  At (gamma, c):  [ 2.38997122  6.77754793]
# error of particle- 28 is (training, test) (0, 21)  At (gamma, c):  [ 1.66794629  5.9422514 ]
# error of particle- 29 is (training, test) (0, 21)  At (gamma, c):  [ 2.21482164  7.99543766]
# error of particle- 30 is (training, test) (0, 9)  At (gamma, c):  [ 0.30267384  5.17671768]
# error of particle- 31 is (training, test) (0, 21)  At (gamma, c):  [ 2.5637667   6.32386646]
# error of particle- 32 is (training, test) (0, 16)  At (gamma, c):  [ 0.91490833  8.44989105]
# error of particle- 33 is (training, test) (0, 21)  At (gamma, c):  [ 3.79645026  7.88489666]
# error of particle- 34 is (training, test) (0, 21)  At (gamma, c):  [ 2.40527055  3.81982234]
# error of particle- 35 is (training, test) (0, 21)  At (gamma, c):  [ 3.65390201  2.12996153]
# error of particle- 36 is (training, test) (0, 15)  At (gamma, c):  [ 0.72847952  3.97063164]
# error of particle- 37 is (training, test) (0, 21)  At (gamma, c):  [ 4.94650336  8.95629075]
# error of particle- 38 is (training, test) (0, 21)  At (gamma, c):  [ 2.19339975  7.89076336]
# error of particle- 39 is (training, test) (0, 21)  At (gamma, c):  [ 2.93075937  5.84496921]
# error of particle- 40 is (training, test) (0, 21)  At (gamma, c):  [ 1.67446222  6.77880523]
# error of particle- 41 is (training, test) (0, 21)  At (gamma, c):  [ 2.68776478  8.43994497]
# error of particle- 42 is (training, test) (0, 21)  At (gamma, c):  [ 2.17703345  6.04174229]
# error of particle- 43 is (training, test) (0, 21)  At (gamma, c):  [ 1.8862402   6.65872293]
# error of particle- 44 is (training, test) (0, 21)  At (gamma, c):  [ 1.93873907  7.89037765]
# error of particle- 45 is (training, test) (0, 15)  At (gamma, c):  [ 0.82409394  6.49086413]
# error of particle- 46 is (training, test) (0, 16)  At (gamma, c):  [ 0.87530006  8.45100827]
# error of particle- 47 is (training, test) (0, 21)  At (gamma, c):  [ 4.26152153  4.77741233]
# error of particle- 48 is (training, test) (0, 21)  At (gamma, c):  [ 2.99002596  5.37564861]
# error of particle- 49 is (training, test) (0, 21)  At (gamma, c):  [ 1.85356586  6.92773393]
# error of particle- 50 is (training, test) (0, 21)  At (gamma, c):  [ 6.85912393  4.62086671]
# error of particle- 51 is (training, test) (0, 21)  At (gamma, c):  [ 1.37625117  4.99832851]
# error of particle- 52 is (training, test) (0, 21)  At (gamma, c):  [ 3.92610008  4.84379049]
# error of particle- 53 is (training, test) (0, 21)  At (gamma, c):  [ 2.20394367  6.02157093]
# error of particle- 54 is (training, test) (0, 9)  At (gamma, c):  [ 0.28735264  5.60584884]
# error of particle- 55 is (training, test) (0, 21)  At (gamma, c):  [ 2.62081859  8.21305423]
# error of particle- 56 is (training, test) (0, 21)  At (gamma, c):  [ 2.10509946  6.42172414]
# error of particle- 57 is (training, test) (0, 21)  At (gamma, c):  [ 2.99803275  4.36655577]
# error of particle- 58 is (training, test) (0, 21)  At (gamma, c):  [ 1.65190881  7.24612959]
# error of particle- 59 is (training, test) (0, 21)  At (gamma, c):  [ 1.84230114  6.25388722]
# error of particle- 60 is (training, test) (0, 21)  At (gamma, c):  [ 2.02450442  6.06640016]
# error of particle- 61 is (training, test) (0, 21)  At (gamma, c):  [ 5.80020213  3.79719455]
# error of particle- 62 is (training, test) (0, 10)  At (gamma, c):  [ 0.40950597  6.68327695]
# error of particle- 63 is (training, test) (0, 21)  At (gamma, c):  [ 2.36574814  7.32210288]
# error of particle- 64 is (training, test) (0, 21)  At (gamma, c):  [ 2.60072522  6.34084275]
# error of particle- 65 is (training, test) (0, 21)  At (gamma, c):  [ 3.84788119  5.41581899]
# error of particle- 66 is (training, test) (0, 21)  At (gamma, c):  [ 1.75399658  6.42045695]
# error of particle- 67 is (training, test) (0, 21)  At (gamma, c):  [ 2.14656318  6.7683066 ]
# error of particle- 68 is (training, test) (0, 16)  At (gamma, c):  [ 0.92339601  4.9726056 ]
# error of particle- 69 is (training, test) (0, 21)  At (gamma, c):  [ 1.73882856  4.88806141]
# error of particle- 70 is (training, test) (0, 11)  At (gamma, c):  [ 0.40878944  2.93505521]
# error of particle- 71 is (training, test) (0, 10)  At (gamma, c):  [ 0.18227353  8.71800643]
# error of particle- 72 is (training, test) (0, 21)  At (gamma, c):  [ 1.44322023  5.65528736]
# error of particle- 73 is (training, test) (0, 21)  At (gamma, c):  [ 3.20544074  5.72017952]
# error of particle- 74 is (training, test) (0, 21)  At (gamma, c):  [ 2.47498694  8.4063792 ]
# error of particle- 75 is (training, test) (0, 19)  At (gamma, c):  [ 1.09148136  6.59066814]
# error of particle- 76 is (training, test) (0, 21)  At (gamma, c):  [ 1.77212958  5.91140474]
# error of particle- 77 is (training, test) (0, 21)  At (gamma, c):  [ 1.26396305  8.24300648]
# error of particle- 78 is (training, test) (0, 21)  At (gamma, c):  [ 2.3053502   7.79833268]
# error of particle- 79 is (training, test) (0, 21)  At (gamma, c):  [ 1.59462184  6.9992725 ]
# error of particle- 80 is (training, test) (0, 21)  At (gamma, c):  [ 1.85641994  7.43982349]
# error of particle- 81 is (training, test) (0, 21)  At (gamma, c):  [ 1.68959908  8.1555776 ]
# error of particle- 82 is (training, test) (0, 11)  At (gamma, c):  [ 0.4750405   6.69030487]
# error of particle- 83 is (training, test) (0, 21)  At (gamma, c):  [ 2.32281077  8.56221152]
# error of particle- 84 is (training, test) (0, 10)  At (gamma, c):  [ 0.19006877  7.22657741]
# error of particle- 85 is (training, test) (0, 10)  At (gamma, c):  [ 0.43014276  7.46574198]
# error of particle- 86 is (training, test) (0, 21)  At (gamma, c):  [ 2.81411442  6.69160999]
# error of particle- 87 is (training, test) (0, 21)  At (gamma, c):  [ 3.500666    8.60003571]
# error of particle- 88 is (training, test) (0, 21)  At (gamma, c):  [ 1.46292557  6.51709184]
# error of particle- 89 is (training, test) (0, 21)  At (gamma, c):  [ 1.44440151  8.64825911]
# error of particle- 90 is (training, test) (0, 21)  At (gamma, c):  [ 4.17264302  7.44570214]
# error of particle- 91 is (training, test) (0, 21)  At (gamma, c):  [ 4.31063938  5.16872989]
# error of particle- 92 is (training, test) (0, 11)  At (gamma, c):  [ 0.47237607  6.44209415]
# error of particle- 93 is (training, test) (0, 21)  At (gamma, c):  [ 1.20351029  4.13897324]
# error of particle- 94 is (training, test) (0, 21)  At (gamma, c):  [ 3.18051039  6.10985815]
# error of particle- 95 is (training, test) (0, 21)  At (gamma, c):  [ 2.69122633  4.88813239]
# error of particle- 96 is (training, test) (0, 21)  At (gamma, c):  [ 2.1240041   7.84049036]
# error of particle- 97 is (training, test) (0, 21)  At (gamma, c):  [ 1.90247446  7.91082785]
# error of particle- 98 is (training, test) (0, 19)  At (gamma, c):  [ 1.03988244  8.42529941]
# error of particle- 99 is (training, test) (0, 15)  At (gamma, c):  [ 0.68580285  7.77432335]
# error of particle- 0 is (training, test) (0, 21)  At (gamma, c):  [ 1.43314806  6.02547238]
# error of particle- 1 is (training, test) (0, 15)  At (gamma, c):  [ 0.53581268  5.55703351]
# error of particle- 2 is (training, test) (0, 21)  At (gamma, c):  [ 3.363773    4.18685468]
# error of particle- 3 is (training, test) (0, 21)  At (gamma, c):  [ 1.33664969  7.47623918]
# error of particle- 4 is (training, test) (0, 21)  At (gamma, c):  [ 2.21534855  7.50862658]
# error of particle- 5 is (training, test) (0, 21)  At (gamma, c):  [ 2.52232478  6.90554692]
# error of particle- 6 is (training, test) (0, 21)  At (gamma, c):  [ 2.76720063  6.1885124 ]
# error of particle- 7 is (training, test) (0, 21)  At (gamma, c):  [ 1.41900701  6.87031076]
# error of particle- 8 is (training, test) (0, 16)  At (gamma, c):  [ 0.91068939  6.82500759]
# error of particle- 9 is (training, test) (0, 17)  At (gamma, c):  [ 0.94059675  6.48330358]
# error of particle- 10 is (training, test) (21, 6)  At (gamma, c):  [ 0.02411098  7.3876421 ]
# error of particle- 11 is (training, test) (0, 21)  At (gamma, c):  [ 1.25628364  6.66391646]
# error of particle- 12 is (training, test) (0, 12)  At (gamma, c):  [ 0.49966645  6.84888051]
# error of particle- 13 is (training, test) (0, 21)  At (gamma, c):  [ 1.89363658  4.12702483]
# error of particle- 14 is (training, test) (0, 21)  At (gamma, c):  [ 1.8764019   6.68540244]
# error of particle- 15 is (training, test) (17, 7)  At (gamma, c):  [ 0.03001882  6.77696753]
# error of particle- 16 is (training, test) (0, 21)  At (gamma, c):  [ 2.81432452  6.942994  ]
# error of particle- 17 is (training, test) (0, 9)  At (gamma, c):  [ 0.24107588  6.11631186]
# error of particle- 18 is (training, test) (0, 21)  At (gamma, c):  [ 2.16381386  5.86880784]
# error of particle- 19 is (training, test) (0, 21)  At (gamma, c):  [ 1.36956957  6.29265774]
# error of particle- 20 is (training, test) (0, 21)  At (gamma, c):  [ 1.55386524  6.27911975]
# error of particle- 21 is (training, test) (0, 21)  At (gamma, c):  [ 1.46582117  6.79920829]
# error of particle- 22 is (training, test) (0, 21)  At (gamma, c):  [ 3.59460068  7.40754286]
# error of particle- 23 is (training, test) (7, 9)  At (gamma, c):  [ 0.06271575  6.0749628 ]
# error of particle- 24 is (training, test) (0, 21)  At (gamma, c):  [ 1.26129896  5.6952919 ]
# error of particle- 25 is (training, test) (0, 15)  At (gamma, c):  [ 0.5621298   7.21491737]
# error of particle- 26 is (training, test) (0, 21)  At (gamma, c):  [ 3.56031885  6.55742278]
# error of particle- 27 is (training, test) (0, 21)  At (gamma, c):  [ 2.27552303  6.80706116]
# error of particle- 28 is (training, test) (0, 17)  At (gamma, c):  [ 0.97647292  6.55024976]
# error of particle- 29 is (training, test) (0, 21)  At (gamma, c):  [ 1.21440399  7.71787959]
# error of particle- 30 is (training, test) (0, 9)  At (gamma, c):  [ 0.24530675  5.63203432]
# error of particle- 31 is (training, test) (0, 21)  At (gamma, c):  [ 2.01843915  6.55228567]
# error of particle- 32 is (training, test) (0, 15)  At (gamma, c):  [ 0.50896823  7.96581973]
# error of particle- 33 is (training, test) (0, 21)  At (gamma, c):  [ 2.464557    7.70933186]
# error of particle- 34 is (training, test) (0, 21)  At (gamma, c):  [ 2.39419822  3.83641262]
# error of particle- 35 is (training, test) (0, 21)  At (gamma, c):  [ 3.3481293   2.57286725]
# error of particle- 36 is (training, test) (0, 10)  At (gamma, c):  [ 0.39165167  5.60464028]
# error of particle- 37 is (training, test) (0, 21)  At (gamma, c):  [ 2.65313242  8.22544831]
# error of particle- 38 is (training, test) (0, 21)  At (gamma, c):  [ 1.40223235  7.70726859]
# error of particle- 39 is (training, test) (0, 21)  At (gamma, c):  [ 2.0277116   6.32425226]
# error of particle- 40 is (training, test) (0, 21)  At (gamma, c):  [ 1.5240128   6.83430806]
# error of particle- 41 is (training, test) (0, 21)  At (gamma, c):  [ 1.44203836  7.94780838]
# error of particle- 42 is (training, test) (0, 21)  At (gamma, c):  [ 1.96584237  6.17376842]
# error of particle- 43 is (training, test) (0, 21)  At (gamma, c):  [ 1.48270258  6.81668528]
# error of particle- 44 is (training, test) (0, 21)  At (gamma, c):  [ 1.21163794  7.69945828]
# error of particle- 45 is (training, test) (0, 10)  At (gamma, c):  [ 0.45084751  6.90927201]
# error of particle- 46 is (training, test) (0, 15)  At (gamma, c):  [ 0.81625168  8.37724082]
# error of particle- 47 is (training, test) (0, 21)  At (gamma, c):  [ 3.44396169  5.28102627]
# error of particle- 48 is (training, test) (0, 21)  At (gamma, c):  [ 2.85726973  5.46570671]
# error of particle- 49 is (training, test) (0, 21)  At (gamma, c):  [ 1.3134046   7.06352551]
# error of particle- 50 is (training, test) (0, 21)  At (gamma, c):  [ 4.16616002  5.71096359]
# error of particle- 51 is (training, test) (0, 21)  At (gamma, c):  [ 1.25091842  5.21979906]
# error of particle- 52 is (training, test) (0, 21)  At (gamma, c):  [ 2.09786588  6.03568426]
# error of particle- 53 is (training, test) (0, 21)  At (gamma, c):  [ 1.69497162  6.34053671]
# error of particle- 54 is (training, test) (1, 10)  At (gamma, c):  [ 0.20621775  6.15502333]
# error of particle- 55 is (training, test) (0, 21)  At (gamma, c):  [ 1.61615915  7.89370441]
# error of particle- 56 is (training, test) (0, 21)  At (gamma, c):  [ 1.70283444  6.6084407 ]
# error of particle- 57 is (training, test) (0, 21)  At (gamma, c):  [ 1.63740213  5.74876514]
# error of particle- 58 is (training, test) (0, 21)  At (gamma, c):  [ 1.203682    7.28509616]
# error of particle- 59 is (training, test) (0, 21)  At (gamma, c):  [ 1.67647892  6.35728771]
# error of particle- 60 is (training, test) (0, 21)  At (gamma, c):  [ 1.43289429  6.45715335]
# error of particle- 61 is (training, test) (0, 21)  At (gamma, c):  [ 4.29828016  4.73079686]
# error of particle- 62 is (training, test) (0, 10)  At (gamma, c):  [ 0.33610139  6.81743445]
# error of particle- 63 is (training, test) (0, 21)  At (gamma, c):  [ 1.75701648  7.33914045]
# error of particle- 64 is (training, test) (0, 21)  At (gamma, c):  [ 1.93166755  6.61266036]
# error of particle- 65 is (training, test) (0, 21)  At (gamma, c):  [ 2.6750113   6.02063879]
# error of particle- 66 is (training, test) (0, 21)  At (gamma, c):  [ 1.22314779  6.71725638]
# error of particle- 67 is (training, test) (0, 21)  At (gamma, c):  [ 1.7921704   6.87171907]
# error of particle- 68 is (training, test) (0, 16)  At (gamma, c):  [ 0.89622933  5.04556193]
# error of particle- 69 is (training, test) (0, 21)  At (gamma, c):  [ 1.15748938  5.73549204]
# error of particle- 70 is (training, test) (0, 11)  At (gamma, c):  [ 0.40710219  2.95458488]
# error of particle- 71 is (training, test) (1, 11)  At (gamma, c):  [ 0.12577311  8.24276029]
# error of particle- 72 is (training, test) (0, 21)  At (gamma, c):  [ 1.19987     5.95235323]
# error of particle- 73 is (training, test) (0, 21)  At (gamma, c):  [ 2.38972638  6.14772815]
# error of particle- 74 is (training, test) (0, 21)  At (gamma, c):  [ 1.90140241  8.16796165]
# error of particle- 75 is (training, test) (0, 15)  At (gamma, c):  [ 0.8167955   6.79576796]
# error of particle- 76 is (training, test) (0, 21)  At (gamma, c):  [ 1.16247577  6.42626981]
# error of particle- 77 is (training, test) (0, 15)  At (gamma, c):  [ 0.77301812  7.90430736]
# error of particle- 78 is (training, test) (0, 21)  At (gamma, c):  [ 1.91334151  7.72775951]
# error of particle- 79 is (training, test) (0, 20)  At (gamma, c):  [ 1.13775294  7.11225102]
# error of particle- 80 is (training, test) (0, 21)  At (gamma, c):  [ 1.78406721  7.437763  ]
# error of particle- 81 is (training, test) (0, 21)  At (gamma, c):  [ 1.55103847  8.09168906]
# error of particle- 82 is (training, test) (0, 10)  At (gamma, c):  [ 0.38167856  6.83468387]
# error of particle- 83 is (training, test) (0, 21)  At (gamma, c):  [ 1.83836895  8.3146757 ]
# error of particle- 84 is (training, test) (1, 10)  At (gamma, c):  [ 0.1670921   7.24887664]
# error of particle- 85 is (training, test) (0, 9)  At (gamma, c):  [ 0.25896675  7.43281641]
# error of particle- 86 is (training, test) (0, 21)  At (gamma, c):  [ 2.32254884  6.81424261]
# error of particle- 87 is (training, test) (0, 21)  At (gamma, c):  [ 2.86272626  8.37756431]
# error of particle- 88 is (training, test) (0, 18)  At (gamma, c):  [ 1.01061747  6.79075944]
# error of particle- 89 is (training, test) (0, 21)  At (gamma, c):  [ 1.33240717  8.54885552]
# error of particle- 90 is (training, test) (0, 21)  At (gamma, c):  [ 3.78766541  7.44031425]
# error of particle- 91 is (training, test) (0, 21)  At (gamma, c):  [ 3.6660638   5.50239305]
# error of particle- 92 is (training, test) (0, 10)  At (gamma, c):  [ 0.41094692  6.57166971]
# error of particle- 93 is (training, test) (0, 18)  At (gamma, c):  [ 0.98761004  4.73367294]
# error of particle- 94 is (training, test) (0, 21)  At (gamma, c):  [ 2.13355155  6.53369146]
# error of particle- 95 is (training, test) (0, 21)  At (gamma, c):  [ 2.17096274  5.37570181]
# error of particle- 96 is (training, test) (0, 21)  At (gamma, c):  [ 1.51062538  7.7082134 ]
# error of particle- 97 is (training, test) (0, 21)  At (gamma, c):  [ 1.5642529   7.81662207]
# error of particle- 98 is (training, test) (0, 16)  At (gamma, c):  [ 0.89683089  8.27916566]
# error of particle- 99 is (training, test) (0, 15)  At (gamma, c):  [ 0.61734201  7.73431602]
# error of particle- 0 is (training, test) (0, 17)  At (gamma, c):  [ 0.95307771  6.48957464]
# error of particle- 1 is (training, test) (0, 15)  At (gamma, c):  [ 0.51533759  5.63028298]
# error of particle- 2 is (training, test) (0, 21)  At (gamma, c):  [ 1.73482514  5.7480653 ]
# error of particle- 3 is (training, test) (0, 18)  At (gamma, c):  [ 1.010208    7.45420418]
# error of particle- 4 is (training, test) (0, 21)  At (gamma, c):  [ 1.54612499  7.47167684]
# error of particle- 5 is (training, test) (0, 21)  At (gamma, c):  [ 1.33308854  7.13504091]
# error of particle- 6 is (training, test) (0, 21)  At (gamma, c):  [ 2.09049411  6.48433171]
# error of particle- 7 is (training, test) (0, 16)  At (gamma, c):  [ 0.86861097  7.0744386 ]
# error of particle- 8 is (training, test) (0, 15)  At (gamma, c):  [ 0.68476125  6.9683846 ]
# error of particle- 9 is (training, test) (0, 16)  At (gamma, c):  [ 0.90360568  6.51980437]
# error of particle- 10 is (training, test) (21, 6)  At (gamma, c):  [ 0.02411098  7.3876421 ]
# error of particle- 11 is (training, test) (0, 17)  At (gamma, c):  [ 0.94292705  6.84796875]
# error of particle- 12 is (training, test) (0, 12)  At (gamma, c):  [ 0.49734475  6.85151078]
# error of particle- 13 is (training, test) (0, 20)  At (gamma, c):  [ 1.12749446  5.46324415]
# error of particle- 14 is (training, test) (0, 21)  At (gamma, c):  [ 1.69723137  6.75332948]
# error of particle- 15 is (training, test) (19, 6)  At (gamma, c):  [ 0.02717908  7.07050221]
# ...
# error of particle- 29 is (training, test) (1, 10)  At (gamma, c):  [ 0.16687638  7.16877241]
# error of particle- 30 is (training, test) (3, 8)  At (gamma, c):  [ 0.07858731  6.76916767]
# error of particle- 31 is (training, test) (0, 16)  At (gamma, c):  [ 0.89712767  6.85220115]
# error of particle- 32 is (training, test) (1, 10)  At (gamma, c):  [ 0.18449093  7.37457985]
# error of particle- 33 is (training, test) (0, 11)  At (gamma, c):  [ 0.45804048  7.20970406]
# error of particle- 34 is (training, test) (0, 16)  At (gamma, c):  [ 0.91214189  5.87710894]
# error of particle- 35 is (training, test) (0, 10)  At (gamma, c):  [ 0.35493852  6.65675034]
# error of particle- 36 is (training, test) (2, 11)  At (gamma, c):  [ 0.12295897  6.72826912]
# error of particle- 37 is (training, test) (0, 16)  At (gamma, c):  [ 0.83558636  7.43339436]
# error of particle- 38 is (training, test) (0, 9)  At (gamma, c):  [ 0.26751637  7.20529834]
# error of particle- 39 is (training, test) (0, 10)  At (gamma, c):  [ 0.42541688  6.93782689]
# error of particle- 40 is (training, test) (0, 10)  At (gamma, c):  [ 0.35165594  7.03289596]
# error of particle- 41 is (training, test) (0, 16)  At (gamma, c):  [ 0.88035076  7.70856699]
# error of particle- 42 is (training, test) (0, 10)  At (gamma, c):  [ 0.43295829  6.90274279]
# error of particle- 43 is (training, test) (0, 10)  At (gamma, c):  [ 0.41591795  7.02410253]
# error of particle- 44 is (training, test) (0, 15)  At (gamma, c):  [ 0.76288591  7.47651734]
# error of particle- 45 is (training, test) (2, 10)  At (gamma, c):  [ 0.10647907  7.08835608]
# error of particle- 46 is (training, test) (0, 11)  At (gamma, c):  [ 0.46304929  7.80182202]
# error of particle- 47 is (training, test) (0, 16)  At (gamma, c):  [ 0.89405378  6.66437268]
# error of particle- 48 is (training, test) (0, 16)  At (gamma, c):  [ 0.66843812  6.72829798]
# error of particle- 49 is (training, test) (0, 9)  At (gamma, c):  [ 0.22891073  7.10333089]
# error of particle- 50 is (training, test) (0, 20)  At (gamma, c):  [ 1.13406916  6.77250912]
# error of particle- 51 is (training, test) (0, 10)  At (gamma, c):  [ 0.40803015  6.50862454]
# error of particle- 52 is (training, test) (0, 9)  At (gamma, c):  [ 0.27891081  6.97257624]
# error of particle- 53 is (training, test) (0, 12)  At (gamma, c):  [ 0.48537804  6.87095079]
# error of particle- 54 is (training, test) (7, 9)  At (gamma, c):  [ 0.05639074  6.95309109]
# error of particle- 55 is (training, test) (0, 15)  At (gamma, c):  [ 0.57425362  7.39827866]
# error of particle- 56 is (training, test) (0, 15)  At (gamma, c):  [ 0.76848883  6.93732056]
# error of particle- 57 is (training, test) (0, 9)  At (gamma, c):  [ 0.30341817  6.88622633]
# error of particle- 58 is (training, test) (0, 9)  At (gamma, c):  [ 0.31256672  7.16699446]
# error of particle- 59 is (training, test) (0, 15)  At (gamma, c):  [ 0.73640066  6.78453986]
# error of particle- 60 is (training, test) (0, 11)  At (gamma, c):  [ 0.48443346  6.87558134]
# error of particle- 61 is (training, test) (0, 15)  At (gamma, c):  [ 0.61914037  6.75745385]
# error of particle- 62 is (training, test) (1, 11)  At (gamma, c):  [ 0.14385218  6.99087812]
# error of particle- 63 is (training, test) (0, 10)  At (gamma, c):  [ 0.35593011  7.17903244]
# error of particle- 64 is (training, test) (0, 15)  At (gamma, c):  [ 0.74771535  6.91677434]
# error of particle- 65 is (training, test) (0, 16)  At (gamma, c):  [ 0.91525891  6.72528819]
# error of particle- 66 is (training, test) (0, 9)  At (gamma, c):  [ 0.28981089  7.01573472]
# error of particle- 67 is (training, test) (0, 10)  At (gamma, c):  [ 0.41948381  7.08327652]
# error of particle- 68 is (training, test) (0, 9)  At (gamma, c):  [ 0.29500801  6.45071174]
# error of particle- 69 is (training, test) (0, 10)  At (gamma, c):  [ 0.4059893   6.62818973]
# error of particle- 70 is (training, test) (2, 10)  At (gamma, c):  [ 0.09814481  6.3356498 ]
# error of particle- 71 is (training, test) (4, 9)  At (gamma, c):  [ 0.06862973  7.56941832]
# error of particle- 72 is (training, test) (0, 10)  At (gamma, c):  [ 0.33032083  6.7854147 ]
# error of particle- 73 is (training, test) (0, 10)  At (gamma, c):  [ 0.41913223  6.95677477]
# error of particle- 74 is (training, test) (0, 15)  At (gamma, c):  [ 0.53017491  7.37153064]
# error of particle- 75 is (training, test) (0, 9)  At (gamma, c):  [ 0.2872048   6.98602702]
# error of particle- 76 is (training, test) (0, 10)  At (gamma, c):  [ 0.21256122  7.01086507]
# error of particle- 77 is (training, test) (0, 9)  At (gamma, c):  [ 0.27463466  7.37312357]
# error of particle- 78 is (training, test) (0, 15)  At (gamma, c):  [ 0.79030471  7.44868944]
# error of particle- 79 is (training, test) (0, 10)  At (gamma, c):  [ 0.34288603  7.09554046]
# error of particle- 80 is (training, test) (0, 16)  At (gamma, c):  [ 0.64680796  7.2423803 ]
# error of particle- 81 is (training, test) (0, 15)  At (gamma, c):  [ 0.61468254  7.51482934]
# error of particle- 82 is (training, test) (2, 10)  At (gamma, c):  [ 0.10380793  7.05922588]
# error of particle- 83 is (training, test) (0, 16)  At (gamma, c):  [ 0.62380013  7.55541893]
# error of particle- 84 is (training, test) (6, 9)  At (gamma, c):  [ 0.06841736  7.12364562]
# error of particle- 85 is (training, test) (1, 10)  At (gamma, c):  [ 0.15361943  7.29135233]
# error of particle- 86 is (training, test) (0, 10)  At (gamma, c):  [ 0.37254813  7.06042551]
# error of particle- 87 is (training, test) (0, 21)  At (gamma, c):  [ 1.87171502  7.9274861 ]
# error of particle- 88 is (training, test) (0, 15)  At (gamma, c):  [ 0.55244944  6.9234204 ]
# error of particle- 89 is (training, test) (0, 16)  At (gamma, c):  [ 0.6550839   7.82466317]
# error of particle- 90 is (training, test) (0, 15)  At (gamma, c):  [ 0.60208015  7.16639629]
# error of particle- 91 is (training, test) (0, 16)  At (gamma, c):  [ 0.85032508  6.74391474]
# error of particle- 92 is (training, test) (4, 9)  At (gamma, c):  [ 0.0754103   7.04503886]
# error of particle- 93 is (training, test) (0, 10)  At (gamma, c):  [ 0.35233973  6.28170307]
# error of particle- 94 is (training, test) (0, 15)  At (gamma, c):  [ 0.74063407  6.91120636]
# error of particle- 95 is (training, test) (0, 15)  At (gamma, c):  [ 0.57176031  6.6751125 ]
# error of particle- 96 is (training, test) (0, 15)  At (gamma, c):  [ 0.71341571  7.38245152]
# error of particle- 97 is (training, test) (0, 16)  At (gamma, c):  [ 0.93063831  7.53192988]
# error of particle- 98 is (training, test) (1, 10)  At (gamma, c):  [ 0.18536605  7.3178774 ]
# error of particle- 99 is (training, test) (2, 11)  At (gamma, c):  [ 0.12903864  7.22860093]
# error of particle- 0 is (training, test) (0, 10)  At (gamma, c):  [ 0.32789414  6.88182749]
# error of particle- 1 is (training, test) (2, 11)  At (gamma, c):  [ 0.11394563  6.81451394]
# error of particle- 2 is (training, test) (0, 11)  At (gamma, c):  [ 0.45340692  6.74042244]
# error of particle- 3 is (training, test) (0, 15)  At (gamma, c):  [ 0.50606826  7.25742522]
# error of particle- 4 is (training, test) (0, 9)  At (gamma, c):  [ 0.28473932  7.13852744]
# error of particle- 5 is (training, test) (0, 11)  At (gamma, c):  [ 0.453344   7.0915635]
# error of particle- 6 is (training, test) (0, 16)  At (gamma, c):  [ 0.83061404  6.84225308]
# error of particle- 7 is (training, test) (0, 9)  At (gamma, c):  [ 0.26850895  7.0716312 ]
# error of particle- 8 is (training, test) (1, 11)  At (gamma, c):  [ 0.14280039  7.05254709]
# error of particle- 9 is (training, test) (0, 10)  At (gamma, c):  [ 0.19574484  6.96458485]
# error of particle- 10 is (training, test) (19, 6)  At (gamma, c):  [ 0.0267304   7.11688057]
# error of particle- 11 is (training, test) (0, 15)  At (gamma, c):  [ 0.68997599  6.90943771]
# error of particle- 12 is (training, test) (2, 11)  At (gamma, c):  [ 0.12862105  7.02325307]
# error of particle- 13 is (training, test) (0, 11)  At (gamma, c):  [ 0.46460523  6.43154295]
# error of particle- 14 is (training, test) (0, 11)  At (gamma, c):  [ 0.48039905  6.98442765]
# error of particle- 15 is (training, test) (19, 6)  At (gamma, c):  [ 0.02717908  7.07050221]
# error of particle- 16 is (training, test) (0, 16)  At (gamma, c):  [ 0.86353631  7.04973567]
# error of particle- 17 is (training, test) (5, 9)  At (gamma, c):  [ 0.07012885  6.90473332]
# error of particle- 18 is (training, test) (0, 15)  At (gamma, c):  [ 0.54845883  6.79247277]
# error of particle- 19 is (training, test) (1, 10)  At (gamma, c):  [ 0.18018928  7.01620169]
# error of particle- 20 is (training, test) (0, 15)  At (gamma, c):  [ 0.59244056  6.79725378]
# error of particle- 21 is (training, test) (0, 10)  At (gamma, c):  [ 0.32472767  7.06292161]
# error of particle- 22 is (training, test) (0, 16)  At (gamma, c):  [ 0.84911704  7.20785672]
# error of particle- 23 is (training, test) (16, 7)  At (gamma, c):  [ 0.03355379  6.91299585]
# error of particle- 24 is (training, test) (0, 10)  At (gamma, c):  [ 0.42163202  6.64831655]
# error of particle- 25 is (training, test) (1, 11)  At (gamma, c):  [ 0.15911027  7.15481187]
# error of particle- 26 is (training, test) (0, 21)  At (gamma, c):  [ 1.16677285  6.9060253 ]
# error of particle- 27 is (training, test) (0, 15)  At (gamma, c):  [ 0.67989897  7.01766277]
# error of particle- 28 is (training, test) (0, 9)  At (gamma, c):  [ 0.31073327  6.98013136]
# error of particle- 29 is (training, test) (1, 11)  At (gamma, c):  [ 0.1391002   7.14923323]
# error of particle- 30 is (training, test) (4, 9)  At (gamma, c):  [ 0.07602258  6.78420107]
# error of particle- 31 is (training, test) (0, 11)  At (gamma, c):  [ 0.48365129  6.95595709]
# error of particle- 32 is (training, test) (2, 11)  At (gamma, c):  [ 0.11059898  7.23174961]
# error of particle- 33 is (training, test) (0, 10)  At (gamma, c):  [ 0.3537462   7.17600887]
# error of particle- 34 is (training, test) (0, 15)  At (gamma, c):  [ 0.60296366  6.29404309]
# error of particle- 35 is (training, test) (0, 9)  At (gamma, c):  [ 0.2409725  6.800617 ]
# error of particle- 36 is (training, test) (2, 10)  At (gamma, c):  [ 0.10916416  6.77755966]
# error of particle- 37 is (training, test) (0, 15)  At (gamma, c):  [ 0.7301825   7.38607882]
# error of particle- 38 is (training, test) (0, 9)  At (gamma, c):  [ 0.23354106  7.18624287]
# error of particle- 39 is (training, test) (0, 9)  At (gamma, c):  [ 0.27856074  6.9867529 ]
# error of particle- 40 is (training, test) (1, 10)  At (gamma, c):  [ 0.19082499  7.05153597]
# error of particle- 41 is (training, test) (0, 15)  At (gamma, c):  [ 0.8046736   7.65197002]
# error of particle- 42 is (training, test) (0, 9)  At (gamma, c):  [ 0.27298269  6.96888077]
# error of particle- 43 is (training, test) (0, 10)  At (gamma, c):  [ 0.34874614  7.03212013]
# error of particle- 44 is (training, test) (0, 15)  At (gamma, c):  [ 0.74171754  7.46483513]
# error of particle- 45 is (training, test) (2, 10)  At (gamma, c):  [ 0.10027747  7.08695983]
# error of particle- 46 is (training, test) (0, 9)  At (gamma, c):  [ 0.30275427  7.53287286]
# error of particle- 47 is (training, test) (0, 15)  At (gamma, c):  [ 0.690046    6.75995003]
# error of particle- 48 is (training, test) (0, 15)  At (gamma, c):  [ 0.58087187  6.77502721]
# error of particle- 49 is (training, test) (0, 10)  At (gamma, c):  [ 0.21538883  7.10113041]
# error of particle- 50 is (training, test) (0, 20)  At (gamma, c):  [ 1.13109733  6.77330919]
# error of particle- 51 is (training, test) (0, 10)  At (gamma, c):  [ 0.39707896  6.52478106]
# error of particle- 52 is (training, test) (0, 9)  At (gamma, c):  [ 0.24792867  6.98462858]
# error of particle- 53 is (training, test) (0, 10)  At (gamma, c):  [ 0.41983197  6.89949693]
# error of particle- 54 is (training, test) (8, 9)  At (gamma, c):  [ 0.05220137  6.96992953]
# error of particle- 55 is (training, test) (0, 10)  At (gamma, c):  [ 0.35251792  7.26542704]
# error of particle- 56 is (training, test) (0, 15)  At (gamma, c):  [ 0.69642613  6.95026715]
# error of particle- 57 is (training, test) (1, 10)  At (gamma, c):  [ 0.17205521  6.97385703]
# error of particle- 58 is (training, test) (1, 10)  At (gamma, c):  [ 0.1793454   7.12195108]
# error of particle- 59 is (training, test) (0, 11)  At (gamma, c):  [ 0.45547508  6.89781073]
# error of particle- 60 is (training, test) (0, 9)  At (gamma, c):  [ 0.29833787  6.95491118]
# error of particle- 61 is (training, test) (0, 15)  At (gamma, c):  [ 0.56132821  6.7880268 ]
# error of particle- 62 is (training, test) (1, 11)  At (gamma, c):  [ 0.13725933  6.99537743]
# error of particle- 63 is (training, test) (0, 9)  At (gamma, c):  [ 0.28166278  7.15451464]
# error of particle- 64 is (training, test) (0, 15)  At (gamma, c):  [ 0.68513817  6.93012531]
# error of particle- 65 is (training, test) (0, 16)  At (gamma, c):  [ 0.91411922  6.72573121]
# error of particle- 66 is (training, test) (0, 9)  At (gamma, c):  [ 0.28824544  7.01606117]
# error of particle- 67 is (training, test) (0, 9)  At (gamma, c):  [ 0.23088257  7.07713525]
# error of particle- 68 is (training, test) (1, 10)  At (gamma, c):  [ 0.17285826  6.73338191]
# error of particle- 69 is (training, test) (0, 10)  At (gamma, c):  [ 0.40412416  6.63036754]
# error of particle- 70 is (training, test) (4, 9)  At (gamma, c):  [ 0.07391456  6.58655483]
# error of particle- 71 is (training, test) (7, 9)  At (gamma, c):  [ 0.05739565  7.43420058]
# error of particle- 72 is (training, test) (0, 10)  At (gamma, c):  [ 0.20921077  6.8993118 ]
# error of particle- 73 is (training, test) (0, 10)  At (gamma, c):  [ 0.40784108  6.96005097]
# error of particle- 74 is (training, test) (0, 12)  At (gamma, c):  [ 0.48635792  7.34530744]
# error of particle- 75 is (training, test) (0, 9)  At (gamma, c):  [ 0.25742068  6.99570306]
# error of particle- 76 is (training, test) (1, 11)  At (gamma, c):  [ 0.16161621  7.027254  ]
# error of particle- 77 is (training, test) (1, 10)  At (gamma, c):  [ 0.16830658  7.24309156]
# error of particle- 78 is (training, test) (0, 15)  At (gamma, c):  [ 0.5287188   7.31905357]
# error of particle- 79 is (training, test) (0, 9)  At (gamma, c):  [ 0.27397693  7.09007538]
# error of particle- 80 is (training, test) (0, 15)  At (gamma, c):  [ 0.60425392  7.23057629]
# error of particle- 81 is (training, test) (0, 10)  At (gamma, c):  [ 0.43109373  7.37598167]
# error of particle- 82 is (training, test) (3, 10)  At (gamma, c):  [ 0.08886993  7.06142409]
# error of particle- 83 is (training, test) (0, 15)  At (gamma, c):  [ 0.53252188  7.48123055]
# error of particle- 84 is (training, test) (7, 9)  At (gamma, c):  [ 0.05464281  7.10589448]
# error of particle- 85 is (training, test) (2, 10)  At (gamma, c):  [ 0.09639794  7.19140502]
# error of particle- 86 is (training, test) (0, 9)  At (gamma, c):  [ 0.23620036  7.06440368]
# error of particle- 87 is (training, test) (0, 21)  At (gamma, c):  [ 1.77182366  7.8810759 ]
# error of particle- 88 is (training, test) (0, 9)  At (gamma, c):  [ 0.31394494  6.99020444]
# error of particle- 89 is (training, test) (0, 10)  At (gamma, c):  [ 0.45220953  7.58099579]
# error of particle- 90 is (training, test) (0, 10)  At (gamma, c):  [ 0.32503991  7.1201857 ]
# error of particle- 91 is (training, test) (0, 15)  At (gamma, c):  [ 0.574676    6.85327995]
# error of particle- 92 is (training, test) (7, 9)  At (gamma, c):  [ 0.05245063  7.05716026]
# error of particle- 93 is (training, test) (0, 9)  At (gamma, c):  [ 0.30933247  6.38603332]
# error of particle- 94 is (training, test) (0, 10)  At (gamma, c):  [ 0.40139296  6.98695003]
# error of particle- 95 is (training, test) (0, 10)  At (gamma, c):  [ 0.39519146  6.80330918]
# error of particle- 96 is (training, test) (0, 10)  At (gamma, c):  [ 0.39935498  7.23968586]
# error of particle- 97 is (training, test) (0, 16)  At (gamma, c):  [ 0.63368457  7.38026541]
# error of particle- 98 is (training, test) (1, 10)  At (gamma, c):  [ 0.16925555  7.29268356]
# error of particle- 99 is (training, test) (3, 10)  At (gamma, c):  [ 0.08894885  7.16637658]
# The best position is  [ 0.02717908  7.07050221] in iteration number 10 with error (train, test): (19, 6)
